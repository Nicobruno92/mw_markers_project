# %%
import os
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

from scipy.special import expit 

import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyo
import plotly.io as pio
from plotly.subplots import make_subplots

pyo.init_notebook_mode(connected = True)


from sklearn.metrics import roc_auc_score, f1_score
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import (
    GridSearchCV,
    train_test_split,
    cross_val_score,
    GroupShuffleSplit,
    permutation_test_score,
    StratifiedKFold,
    KFold,
    cross_validate
)

from tqdm import tqdm 

from sklearn.ensemble import ExtraTreesClassifier, RandomForestRegressor

import optuna
from merf import MERF
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold, GroupKFold


import sys
sys.path.insert(0, '../')
# from utils import multivariate_classifier, correct_name_markers, plot_univariate
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# plotting parameters
grey = "#21201F"
green = "#9AC529"
lblue = "#42B9B2"
pink = "#DE237B"
orange = "#F38A31"

nt_colors = [green, lblue, pink, orange]

plt.style.use("ggplot")
fig_width = 12  # width in inches
fig_height = 9  # height in inches
fig_size = [fig_width, fig_height]
plt.rcParams["figure.figsize"] = fig_size
plt.rcParams["figure.autolayout"] = True

sns.set(
    style="white",
    context="notebook",
    font_scale=1,
    rc={
        "axes.labelcolor": grey,
        "text.color": grey,
        "axes.edgecolor": grey,
        "xtick.color": grey,
        "ytick.color": grey,
    },
)

sns.set_palette(sns.color_palette
(nt_colors))

# %% [markdown]
# # Load Data
# Loads data from the computed markers. From `Data` directory

# %%
data_path = "../../Data/"
results_path = "../../Results/"
fig_path = "../../Results/Figs/"

df = pd.read_csv(os.path.join(data_path, 'all_markers.csv'), index_col = 0)

# %%
markers = ['wSMI_1', 'wSMI_2', 'wSMI_4', 'wSMI_8', 'p_e_1', 'p_e_2',
       'p_e_4', 'p_e_8', 'k', 'se','msf', 'sef90', 'sef95', 'b', 'b_n', 'g',
       'g_n', 't', 't_n', 'd', 'd_n', 'a_n', 'a', 'CNV', 'P1', 'P3a', 'P3b',]

erps =['CNV', 'P1', 'P3a', 'P3b']

df_markers = (df
              .query("stimuli == 'go'") # only go trials
              .query("correct == 'correct'") #only correct trials
              .query('prev_trial < 5') # only last 5 trials before each probe. 
              .drop(['stimuli', 'correct', 'prev_trial', 'label', 'events',  'epoch_type', 'preproc', 'ft', 'ft_n'], axis = 1) # drop unnecessary columns
              .query("mind in ['on-task','dMW', 'sMW']") # only mind wandering and on-task trials
              .groupby(['segment', 'participant']).filter(lambda x: len(x) > 1) # drop participants with less than 2 trials per segment
             )

# %% [markdown]
# # By segment Mulivariate analysis

# %% [markdown]
# ## On-task Vs Mind- Wandering
# This can only be performed for PC probes  as they are the only ones with On-task reports.
#
#
# Prepares the dataframe for the analysis

# %%
agg_dict = {k:['mean', 'std'] for k in markers }
agg_dict.update({k:'first' for k in df_markers.drop(markers, axis=1).columns})

df_mind = (
    df_markers
    .query("probe == 'PC'")
    .groupby(['segment', 'participant'], as_index = False).agg(agg_dict)
    .assign(
    mind2 = lambda df: np.where(df.mind == 'on-task', 'on-task', 'mw'))
)


############################################################
################ Use normal names################
############################################################

df_mind.columns = df_mind.columns.map("_".join)

df_mind  = (df_mind
            .rename(columns = {'participant_first':'participant', 'probe_first':'probe', 'mind_first':'mind', 'segment_first':'segment', 'mind2_':'mind2'})
            # .query("mind != 'dMW'") #if you want to test against just one of the mw            
            .drop([ 'probe', 'mind',], axis = 1) 
           )

############################################################
################ Use latex command for nmaes################
############################################################

##it slow downs the computer, just for final figures.

# df_mind = correct_name_markers(df_mind)

# df_mind.columns = df_mind.columns.map("$_{".join).map(lambda x: x + '}$').map(lambda x: x.replace('$$', ''))

# df_mind  = (df_mind
#             .rename(columns = {'participant$_{first}$':'participant', 'probe$_{first}$':'probe', 'mind$_{first}$':'mind', 'segment$_{first}$':'segment', 'mind2$_{}$':'mind2'})
# #             .query("mind != 'dMW'") #if you want to test against just one of the mw            
#             .drop(['probe', 'mind', 'segment'], axis = 1) 
        #    )
        
df_mind['mind2_numeric'] = (df_mind['mind2'] == 'mw').astype(int)

# def filter_participants(group):
#     counts = group['mind2'].value_counts()
#     # Check if there is only one level of 'mind2' for the participant
#     if len(counts) == 1:
#         return False
#     return all(count >= 2 for count in counts)

# df_mind = df_mind.groupby('participant').filter(filter_participants)


from scipy.stats import zscore
def replace_outliers_with_participant_mean(df, columns, participant_column='participant', z_threshold=3):
    df_copy = df.copy()
    
    for col in columns:
        for participant in df[participant_column].unique():
            subset = df[df[participant_column] == participant]
            col_zscore = zscore(subset[col])
            mean_value = np.mean(subset[col][np.abs(col_zscore) < z_threshold])
            
            # Count the outliers for each participant
            outlier_count = np.sum(np.abs(col_zscore) >= z_threshold)
            total = len(col_zscore)
            
            # Replace outliers with the mean value for each participant
            subset_indices = subset.index[np.abs(col_zscore) >= z_threshold]
            df_copy.loc[subset_indices, col] = mean_value
            
            if outlier_count > 0:
                print(f"Replaced {outlier_count} outliers in column '{col}' out of {total} observations for participant {participant} with the mean value.")
    
    return df_copy
# Columns to remove outliers from
columns_to_check = df_mind.drop(['mind2', 'mind2_numeric', 'participant', 'segment'], axis = 1).columns

# Remove outliers
df_mind_filtered = replace_outliers_with_participant_mean(df_mind, columns_to_check, z_threshold=3)

df_mind = df_mind_filtered

def filter_participants(group):
    counts = group['mind2_numeric'].value_counts()
    # Check if there is only one level of 'mind2' for the participant
    if len(counts) == 1:
        return False
    return all(count >= 1 for count in counts)
# df_mind = df_mind.groupby('participant').filter(filter_participants)
# Out:
# Replaced 1 outliers in column 'msf_mean' out of 12 observations for participant 17 with the mean value.
# Replaced 1 outliers in column 't_std' out of 12 observations for participant 17 with the mean value.
# Replaced 1 outliers in column 'd_mean' out of 16 observations for participant 3 with the mean value.

# %%
# Initialize lists to store AUC and permutation scores
scores = []
perm_auc_scores_all = []
optimal_cutoffs = []

n_splits = 4
group_kfold = GroupKFold(n_splits=n_splits)

# Assuming df_mw['participant'] contains the participant IDs
# Prepare data
X = df_mind.drop(['mind2', 'mind2_numeric', 'participant','segment'], axis=1)
Z = np.ones((X.shape[0], 1))  # Random effects design matrix
groups = df_mind['participant']
y = df_mind['mind2_numeric']

# Global dictionary for storing trial data
trial_data = {}
def objective(trial):
    global trial_data
    # Hyperparameters to be optimized
    n_estimators = trial.suggest_int('n_estimators', 2, 100)
    max_depth = trial.suggest_int('max_depth', 2, 32, log=True)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    max_features = trial.suggest_uniform('max_features', 0.1, 1.0)

    scores = []
    
    feature_importances = None
    for train_index, test_index in group_kfold.split(X, y, groups.values):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        X_train = StandardScaler().fit_transform(X_train)
        X_test = StandardScaler().fit_transform(X_test)
        
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        clusters_train, clusters_test = groups.iloc[train_index], groups.iloc[test_index]
        
        # Initialize MERF with trial-suggested parameters
        merf = MERF(fixed_effects_model=RandomForestRegressor(
                    n_estimators=n_estimators,
                    max_depth=max_depth,
                    min_samples_leaf=min_samples_leaf,
                    max_features=max_features,
                    random_state=42,
                    n_jobs=-1
        ),
        gll_early_stop_threshold=1,
        max_iterations=50
        )
        
        merf.fit(X_train, Z[train_index], clusters_train, y_train)
        
        
        y_pred = merf.predict(X_test, Z[test_index], clusters_test)

        # Convert continuous outputs to probabilities
        y_pred_proba = expit(y_pred)
        
        # Find optimal cutoff point based on F1 score
        thresholds = np.linspace(0, 1, 100)
        f1_scores = [f1_score(y_test, (y_pred_proba > t).astype(int)) for t in thresholds]
        optimal_threshold = thresholds[np.argmax(f1_scores)]
        optimal_cutoffs.append(optimal_threshold)
        
        # Thresholding to get class labels
        y_pred_class = (y_pred_proba > optimal_threshold).astype(int)

        # Compute AUC for probabilities
        auc = roc_auc_score(y_test, y_pred_proba)
        scores.append(auc)
        
        # Get feature importances (only need to do this once per trial)
        if feature_importances is None:
            feature_importances = merf.fe_model.feature_importances_

    # Store trial data
    trial_data[trial.number] = {
        'fold_aucs': scores,
        'feature_importances': feature_importances
    }

    # Average AUC over all folds
    avg_auc = np.mean(scores)
    return avg_auc

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1000)


# Construct the file path for the study database
study_db_path = os.path.join(results_path, 'multivariate_merf_mind_study.db')
# Use the SQLite database at the specified path for storage
study = optuna.create_study(direction="maximize", study_name="mind_mvpa_study", storage=f'sqlite:///{study_db_path}', load_if_exists=True)

# Best hyperparameters.
# Save the best trial's parameters to a file
best_params_path = os.path.join(results_path, 'mvpa_merf_mind_best_params.txt')
with open(best_params_path, 'w') as file:
    for key, value in study.best_trial.params.items():
        file.write(f'{key}: {value}\n')

# print('Best trial:', study.best_trial.params)
study_df = study.trials_dataframe()
for trial_num in trial_data:
    study_df.loc[study_df.number == trial_num, 'fold_aucs'] = str(trial_data[trial_num]['fold_aucs'])
    study_df.loc[study_df.number == trial_num, 'feature_importances'] = str(trial_data[trial_num]['feature_importances'])
    
study_df.sort_values('value', ascending=False).to_csv(os.path.join(results_path, 'mvpa_merf_mind_opt_trials.csv'))



best_params = study.best_trial.params

# Initialize lists to store AUC and permutation scores
scores = []
perm_auc_scores_all = []
optimal_cutoffs = []

n_splits = 4
group_kfold = GroupKFold(n_splits=n_splits)


# Replace with your actual file path
best_params_path = os.path.join(results_path, 'mvpa_merf_mind_best_params.txt')

# Read the parameters from the file and store them in a dictionary
best_params = {}
with open(best_params_path, 'r') as file:
    for line in file:
        key, value = line.split(': ')
        best_params[key] = float(value.strip())

scores = []

for train_index, test_index in group_kfold.split(X, y, groups.values):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    X_train = StandardScaler().fit_transform(X_train)
    X_test = StandardScaler().fit_transform(X_test)
    
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clusters_train, clusters_test = groups.iloc[train_index], groups.iloc[test_index]
    
    # Create and configure the model with the best parameters
    merf = MERF(
        RandomForestRegressor(
            n_estimators=int(best_params["n_estimators"]),
            max_depth=int(best_params["max_depth"]),
            min_samples_leaf=int(best_params["min_samples_leaf"]),
            max_features=best_params["max_features"],
            random_state=42,  # Assuming you want to keep the random state fixed
            n_jobs=-1
            ),
        gll_early_stop_threshold=0.5,
        max_iterations=50
        )
    
    merf.fit(X_train, Z[train_index], clusters_train, y_train)
    
    
    y_pred = merf.predict(X_test, Z[test_index], clusters_test)

    # Convert continuous outputs to probabilities
    y_pred_proba = expit(y_pred)
    
    # Find optimal cutoff point based on F1 score
    thresholds = np.linspace(0, 1, 100)
    f1_scores = [f1_score(y_test, (y_pred_proba > t).astype(int)) for t in thresholds]
    optimal_threshold = thresholds[np.argmax(f1_scores)]
    optimal_cutoffs.append(optimal_threshold)
    
    # Thresholding to get class labels
    y_pred_class = (y_pred_proba > optimal_threshold).astype(int)

    # Compute AUC for probabilities
    auc = roc_auc_score(y_test, y_pred_proba)
    scores.append(auc)

# Average AUC over all folds
avg_auc = np.mean(scores)
print(scores)
print(avg_auc)
# Out:
# [I 2024-01-05 12:20:57,713] A new study created in memory with name: no-name-a0c6e071-e039-476a-9431-aef14730e9bf
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -136.67008978234202 at iteration 1.
# INFO     [merf.py:307] Training GLL is -162.80744685615008 at iteration 2.
# INFO     [merf.py:321] Gll -162.80744685615008 less than threshold 0.19124416407008937, stopping early ...
# INFO     [merf.py:307] Training GLL is -148.35718593464057 at iteration 1.
# INFO     [merf.py:307] Training GLL is -181.99552323287156 at iteration 2.
# INFO     [merf.py:321] Gll -181.99552323287156 less than threshold 0.22673884710276532, stopping early ...
# INFO     [merf.py:307] Training GLL is -133.0758801517491 at iteration 1.
# INFO     [merf.py:307] Training GLL is -159.95889636030262 at iteration 2.
# INFO     [merf.py:321] Gll -159.95889636030262 less than threshold 0.2020126876327873, stopping early ...
# INFO     [merf.py:307] Training GLL is -155.9707028843395 at iteration 1.
# INFO     [merf.py:307] Training GLL is -188.22047597694575 at iteration 2.
# INFO     [merf.py:321] Gll -188.22047597694575 less than threshold 0.20676814617243325, stopping early ...
# [I 2024-01-05 12:21:01,101] Trial 0 finished with value: 0.48522397741147744 and parameters: {'n_estimators': 67, 'max_depth': 2, 'min_samples_leaf': 1, 'max_features': 0.5298058746954621}. Best is trial 0 with value: 0.48522397741147744.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -149.88333321909826 at iteration 1.
# INFO     [merf.py:307] Training GLL is -190.54585686333186 at iteration 2.
# INFO     [merf.py:321] Gll -190.54585686333186 less than threshold 0.27129449799994404, stopping early ...
# INFO     [merf.py:307] Training GLL is -161.65997102198537 at iteration 1.
# INFO     [merf.py:307] Training GLL is -199.5656845938076 at iteration 2.
# INFO     [merf.py:321] Gll -199.5656845938076 less than threshold 0.23447804259885172, stopping early ...
# INFO     [merf.py:307] Training GLL is -151.19148532303984 at iteration 1.
# INFO     [merf.py:307] Training GLL is -187.33704464533457 at iteration 2.
# INFO     [merf.py:321] Gll -187.33704464533457 less than threshold 0.23907139509255526, stopping early ...
# INFO     [merf.py:307] Training GLL is -167.24803075810172 at iteration 1.
# INFO     [merf.py:307] Training GLL is -206.6180836456194 at iteration 2.
# INFO     [merf.py:321] Gll -206.6180836456194 less than threshold 0.23539920146779097, stopping early ...
# [I 2024-01-05 12:21:03,205] Trial 1 finished with value: 0.5028903388278388 and parameters: {'n_estimators': 23, 'max_depth': 8, 'min_samples_leaf': 11, 'max_features': 0.9824895004751139}. Best is trial 1 with value: 0.5028903388278388.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is
# INFO     [merf.py:307] Training GLL is -165.2593606574781 at iteration 1.
# INFO     [merf.py:307] Training GLL is -199.61547779803715 at iteration 2.
# INFO     [merf.py:321] Gll -199.61547779803715 less than threshold 0.20789210973511288, stopping early ...
# [I 2024-01-05 12:21:37,475] Trial 13 finished with value: 0.5185121591371591 and parameters: {'n_estimators': 95, 'max_depth': 16, 'min_samples_leaf': 12, 'max_features': 0.6857409597254944}. Best is trial 5 with value: 0.5526683964183964.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -162.676837318003 at iteration 1.
# INFO     [merf.py:307] Training GLL is -204.4860025105635 at iteration 2.
# INFO     [merf.py:321] Gll -204.4860025105635 less than threshold 0.2570074872480545, stopping early ...
# INFO     [merf.py:307] Training GLL is -171.81373241125834 at iteration 1.
# INFO     [merf.py:307] Training GLL is -214.95943093788372 at iteration 2.
# INFO     [merf.py:321] Gll -214.95943093788372 less than threshold 0.25111903409065456, stopping early ...
# INFO     [merf.py:307] Training GLL is -161.84036223049137 at iteration 1.
# INFO     [merf.py:307] Training GLL is -202.42806238162504 at iteration 2.
# INFO     [merf.py:321] Gll -202.42806238162504 less than threshold 0.250788490533215, stopping early ...
# INFO     [merf.py:307] Training GLL is -178.89627767867358 at iteration 1.
# INFO     [merf.py:307] Training GLL is -223.05421783718523 at iteration 2.
# INFO     [merf.py:321] Gll -223.05421783718523 less than threshold 0.24683543297544958, stopping early ...
# [I 2024-01-05 12:21:41,153] Trial 14 finished with value: 0.49742445054945045 and parameters: {'n_estimators': 84, 'max_depth': 14, 'min_samples_leaf': 9, 'max_features': 0.7375584124663915}. Best is trial 5 with value: 0.5526683964183964.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -136.67405623519258 at iteration 1.
# INFO     [merf.py:307] Training GLL is -164.8365239245834 at iteration 2.
# INFO     [merf.py:321] Gll -164.8365239245834 less than threshold 0.206055695317391, stopping early ...
# INFO     [merf.py:307] Training GLL is -150.5400098640957 at iteration 1.
# INFO     [merf.py:307] Training GLL is -181.41765099915256 at iteration 2.
# INFO     [merf.py:321] Gll -181.41765099915256 less than threshold 0.2051125223316547, stopping early ...
# INFO     [merf.py:307] Training GLL is -136.20443484718575 at iteration 1.
# INFO     [merf.py:307] Training GLL is -166.7602590872398 at iteration 2.
# INFO     [merf.py:321] Gll -166.7602590872398 less than threshold 0.22433795400521347, stopping early ...
# INFO     [merf.py:307] Training GLL is -157.14996267401418 at iteration 1.
# INFO     [merf.py:307] Training GLL is -188.8807116476491 at iteration 2.
# INFO     [merf.py:321] Gll -188.8807116476491 less than threshold 0.20191381807360628, stopping early ...
# [I 2024-01-05 12:21:44,038] Trial 15 finished with value: 0.4950746591371592 and parameters: {'n_estimators': 46, 'max_depth': 14, 'min_samples_leaf': 14, 'max_features': 0.6235143225409221}. Best is trial 5 with value: 0.5526683964183964.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -134.6482603007789 at iteration 1.
# INFO     [merf.py:307] Training GLL is -180.24580290259487 at iteration 2.
# INFO     [merf.py:321] Gll -180.24580290259487 less than threshold 0.3386418992711799, stopping early ...
# INFO     [merf.py:307] Training GLL is -144.38136515547203 at iteration 1.
# INFO     [merf.py:307] Training GLL is -208.69987167117802 at iteration 2.
# INFO     [merf.py:321] Gll -208.69987167117802 less than threshold 0.44547650901102687, stopping early ...
# INFO     [merf.py:307] Training GLL is -118.79335739330257 at iteration 1.
# INFO     [merf.py:307] Training GLL is -157.34731503449353 at iteration 2.
# INFO     [merf.py:321] Gll -157.34731503449353 less than threshold 0.3245464097251332, stopping early ...
# INFO     [merf.py:307] Training GLL is -151
# INFO     [merf.py:307] Training GLL is -253.2184182973058 at iteration 2.
# INFO     [merf.py:321] Gll -253.2184182973058 less than threshold 0.2746218551882515, stopping early ...
# INFO     [merf.py:307] Training GLL is -217.0173662371083 at iteration 1.
# INFO     [merf.py:307] Training GLL is -286.76023872693276 at iteration 2.
# INFO     [merf.py:321] Gll -286.76023872693276 less than threshold 0.3213700069220496, stopping early ...
# [I 2024-01-05 12:21:58,255] Trial 22 finished with value: 0.47314115282865277 and parameters: {'n_estimators': 29, 'max_depth': 7, 'min_samples_leaf': 4, 'max_features': 0.5982604215611187}. Best is trial 5 with value: 0.5526683964183964.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -165.4954920135022 at iteration 1.
# INFO     [merf.py:307] Training GLL is -207.8094722349148 at iteration 2.
# INFO     [merf.py:321] Gll -207.8094722349148 less than threshold 0.25568056088174507, stopping early ...
# INFO     [merf.py:307] Training GLL is -173.63020111116356 at iteration 1.
# INFO     [merf.py:307] Training GLL is -218.96255179084207 at iteration 2.
# INFO     [merf.py:321] Gll -218.96255179084207 less than threshold 0.2610856313565824, stopping early ...
# INFO     [merf.py:307] Training GLL is -164.9704391905205 at iteration 1.
# INFO     [merf.py:307] Training GLL is -206.57545007337157 at iteration 2.
# INFO     [merf.py:321] Gll -206.57545007337157 less than threshold 0.2521967637777967, stopping early ...
# INFO     [merf.py:307] Training GLL is -180.61168750271253 at iteration 1.
# INFO     [merf.py:307] Training GLL is -232.62455258785874 at iteration 2.
# INFO     [merf.py:321] Gll -232.62455258785874 less than threshold 0.28798172368753855, stopping early ...
# [I 2024-01-05 12:22:01,000] Trial 23 finished with value: 0.5351737382987383 and parameters: {'n_estimators': 44, 'max_depth': 6, 'min_samples_leaf': 8, 'max_features': 0.5675974695732362}. Best is trial 5 with value: 0.5526683964183964.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -164.94924891428383 at iteration 1.
# INFO     [merf.py:307] Training GLL is -205.99667624364147 at iteration 2.
# INFO     [merf.py:321] Gll -205.99667624364147 less than threshold 0.24884882834894273, stopping early ...
# INFO     [merf.py:307] Training GLL is -174.02264219521118 at iteration 1.
# INFO     [merf.py:307] Training GLL is -219.75058123875533 at iteration 2.
# INFO     [merf.py:321] Gll -219.75058123875533 less than threshold 0.2627700537511004, stopping early ...
# INFO     [merf.py:307] Training GLL is -163.7787761473912 at iteration 1.
# INFO     [merf.py:307] Training GLL is -206.80081125695528 at iteration 2.
# INFO     [merf.py:321] Gll -206.80081125695528 less than threshold 0.2626838233963038, stopping early ...
# INFO     [merf.py:307] Training GLL is -178.6716475659453 at iteration 1.
# INFO     [merf.py:307] Training GLL is -222.06187595846896 at iteration 2.
# INFO     [merf.py:321] Gll -222.06187595846896 less than threshold 0.24284898574357694, stopping early ...
# [I 2024-01-05 12:22:03,732] Trial 24 finished with value: 0.5036661833536833 and parameters: {'n_estimators': 46, 'max_depth': 10, 'min_samples_leaf': 8, 'max_features': 0.42359465733826307}. Best is trial 5 with value: 0.5526683964183964.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -138.30689392942287 at iteration 1.
# INFO     [merf.py:307] Training GLL is -170.50311253906006 at iteration 2.
# INFO     [merf.py:321] Gll -170.50311253906006 less than threshold 0.23278824138778442, stopping early ...
# INFO     [merf.py:307] Training GLL is -153.69085514653645 at iteration 1.
# INFO     [merf.py:307] Training GLL is -187.81628686681037 at iteration 2.
# INFO     [merf.py:321] Gll -187.81628686681037 less than threshold 0.22203944201974185, stopping early ...
# INFO     [merf.py:307] Training GLL is -141.22826142643578 at iteration 1.
# INFO     [merf.py:307] Training GLL is -170.34922607876604 at iteration 2.
# INFO     [merf.py:321] Gll -170.34922607876604 less than threshold 0.20619785557226478, stopping early ...
# INFO     [merf.py:307] Training GLL is -157.47879544864438 at iteration 1.
# INFO     [merf.py:307] Training GLL is -191.2596199542215 at iteration 2.
# INFO     [merf.py:321] Gll -191.2596199542215 less than threshold 0.21451030539913826, stopping early ...
# [I 2024-01-05 12:22:06,469] Trial 25 finished with value: 0.5211226851851851 and parameters: {'n_estimators': 47, 'max_depth': 7, 'min_samples_leaf': 13, 'max_features': 0.5410812703540293}. Best is trial 5 with value: 0.5526683964183964.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -129.69998901073328 at iteration 1.
# INFO     [merf.py:307] Training GLL is -156.6264929207633 at iteration 2.
# INFO     [merf.py:321] Gll -156.6264929207633 less than threshold 0.2076060616150224, stopping early ...
# INFO     [merf.py:307] Training GLL is -143.8634245175917 at iteration 1.
# INFO     [merf.py:307] Training GLL is -174.70203001513875 at iteration 2.
# INFO     [merf.py:321] Gll -174.70203001513875 less than threshold 0.2143602906781638, stopping early ...
# INFO     [merf.py:307] Training GLL is -130.85564921295835 at iteration 1.
# INFO     [merf.py:307] Training GLL is -158.15585896039943 at iteration 2.
# INFO     [merf.py:321] Gll -158.15585896039943 less than threshold 0.20862843837190326, stopping early ...
# INFO     [merf.py:307] Training GLL is -151.71991919743166 at iteration 1.
# INFO     [merf.py:307] Training GLL is -181.7296054464967 at iteration 2.
# INFO     [merf.py:321] Gll -181.7296054464967 less than threshold 0.1977966137064291, stopping early ...
# [I 2024-01-05 12:22:09,495] Trial 26 finished with value: 0.5439751221001221 and parameters: {'n_estimators': 56, 'max_depth': 11, 'min_samples_leaf': 16, 'max_features': 0.6561710055617823}. Best is trial 5 with value: 0.5526683964183964.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -127.85299056207482 at iteration 1.
# INFO     [merf.py:307] Training GLL is -157.2906835961657 at iteration 2.
# INFO     [merf.py:321] Gll -157.2906835961657 less than threshold 0.23024641742578855, stopping early ...
# INFO     [merf.py:307] Training GLL is -139.3277139042736 at iteration 1.
# INFO     [merf.py:307] Training GLL is -173.7248988928741 at iteration 2.
# INFO     [merf.py:321] Gll -173.7248988928741 less than threshold 0.24687970558559097, stopping early ...
# INFO     [merf.py:307] Training GLL is -129.64697419587677 at iteration 1.
# INFO     [merf.py:307] Training GLL is -157.69473176947292 at iteration 2.
# INFO     [merf.py:321] Gll -157.69473176947292 less than threshold 0.21633946914349333, stopping early ...
# INFO     [merf.py:307] Training GLL is -147.72973489945184 at iteration 1.
# INFO     [merf.py:307] Training GLL is -177.06948543763664 at iteration 2.
# INFO     [merf.py:321] Gll -177.06948543763664 less than threshold 0.1986042319655829, stopping early ...
# [I 2024-01-05 12:22:11,293] Trial 27 finished with value: 0.503402269027269 and parameters: {'n_estimators': 12, 'max_depth': 11, 'min_samples_leaf': 16, 'max_features': 0.6338335895124143}. Best is trial 5 with value: 0.5526683964183964.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is
. Best is trial 104 with value: 0.5655016280016281.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -145.71729290617998 at iteration 1.
# INFO     [merf.py:307] Training GLL is -182.65675415850544 at iteration 2.
# INFO     [merf.py:321] Gll -182.65675415850544 less than threshold 0.2535008749861207, stopping early ...
# INFO     [merf.py:307] Training GLL is -162.5868509525595 at iteration 1.
# INFO     [merf.py:307] Training GLL is -196.98951606802737 at iteration 2.
# INFO     [merf.py:321] Gll -196.98951606802737 less than threshold 0.21159561744329541, stopping early ...
# INFO     [merf.py:307] Training GLL is -148.72464883301907 at iteration 1.
# INFO     [merf.py:307] Training GLL is -182.47244321548155 at iteration 2.
# INFO     [merf.py:321] Gll -182.47244321548155 less than threshold 0.2269146012262761, stopping early ...
# INFO     [merf.py:307] Training GLL is -165.3025415518497 at iteration 1.
# INFO     [merf.py:307] Training GLL is -204.56341299671004 at iteration 2.
# INFO     [merf.py:321] Gll -204.56341299671004 less than threshold 0.237509182111066, stopping early ...
# [I 2024-01-05 12:30:47,815] Trial 205 finished with value: 0.5643187830687831 and parameters: {'n_estimators': 53, 'max_depth': 16, 'min_samples_leaf': 11, 'max_features': 0.5403171988114291}. Best is trial 104 with value: 0.5655016280016281.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -147.37509415715482 at iteration 1.
# INFO     [merf.py:307] Training GLL is -183.44319313831696 at iteration 2.
# INFO     [merf.py:321] Gll -183.44319313831696 less than threshold 0.24473673239998464, stopping early ...
# INFO     [merf.py:307] Training GLL is -159.3455430031295 at iteration 1.
# INFO     [merf.py:307] Training GLL is -199.3121214324479 at iteration 2.
# INFO     [merf.py:321] Gll -199.3121214324479 less than threshold 0.2508170462510737, stopping early ...
# INFO     [merf.py:307] Training GLL is -146.66321831602667 at iteration 1.
# INFO     [merf.py:307] Training GLL is -179.99332238272902 at iteration 2.
# INFO     [merf.py:321] Gll -179.99332238272902 less than threshold 0.22725605267220697, stopping early ...
# INFO     [merf.py:307] Training GLL is -164.8553917809319 at iteration 1.
# INFO     [merf.py:307] Training GLL is -203.28345480942176 at iteration 2.
# INFO     [merf.py:321] Gll -203.28345480942176 less than threshold 0.233101645104547, stopping early ...
# [I 2024-01-05 12:30:50,661] Trial 206 finished with value: 0.5229700854700855 and parameters: {'n_estimators': 53, 'max_depth': 13, 'min_samples_leaf': 11, 'max_features': 0.5086666825407289}. Best is trial 104 with value: 0.5655016280016281.
# /tmp/ipykernel_35104/2330284160.py:24: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -145.68764516632078 at iteration 1.
# INFO     [merf.py:307] Training GLL is -182.85696589422204 at iteration 2.
# INFO     [merf.py:321] Gll -182.85696589422204 less than threshold 0.2551302183892657, stopping early ...
# INFO     [merf.py:307] Training GLL is -162.42017445177666 at iteration 1.
# INFO     [merf.py:307] Training GLL is -196.91248017012947 at iteration 2.
# INFO     [merf.py:321] Gll -196.91248017012947 less than threshold 0.21236466365570703, stopping early ...
# INFO     [merf.py:307] Training GLL is -148.46855268611995 at iteration 1.
# INFO     [merf.py:307] Training GLL is -182.0554597284343 at iteration 2.
# INFO     [merf.py:321] Gll -182.0554597284343 less than threshold 0.2262223644984338, stopping early ...

# %%
# Extract feature importances
feature_importances = merf.fe_model.feature_importances_

features = df_mind.drop(['mind2', 'mind2_numeric', 'participant','segment'], axis=1).columns
# Combine names and importances into a DataFrame
importances_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

importances_df.to_csv(os.path.join(results_path, f'mvpa_merf_feat_imp.csv'))


fig = px.scatter(importances_df, x='Importance', y='Feature', orientation='h',
                title=f'Feat Imp MERF, AUC: {avg_auc:.3f}', template = "plotly_white",
                color_discrete_sequence = [pink],
                labels = {'value':'Feature importance', 'features': 'Markers'}

                )

fig.update_traces(marker=dict(size = 8))

fig.update_layout(
    width=650,
    height=900,
#     autosize = True, 
    template = 'plotly_white',
        font=dict(
        family="Times new roman",
        size=20,
        color="black"
    ),
    xaxis = dict(
            visible=True,
            # range = [0.37,0.63], 
            tickfont = {"size": 20},
            title = 'Feature Importance'
        ),
    yaxis = dict(
        categoryorder =  'total ascending',
        tickfont = {"size": 20},
        # autorange = False,    
        automargin = True,
        # range = [-1,len(feat_import_mw)],
        dtick = 1
        ),
    showlegend=True, 

)

fig.show()
# pio.write_json(fig, 'Figs/univariate_roc_mw_segment.plotly')
fig.write_image(os.path.join(fig_path, 'feat_importance_mind_optuna.png'))
fig.write_image(os.path.join(fig_path, 'feat_importance_mind_optuna.svg'))
# Out:
# <div>                            <div id="18d1c18a-f028-4c09-bb84-7f86940e5c3d" class="plotly-graph-div" style="height:900px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18d1c18a-f028-4c09-bb84-7f86940e5c3d")) {                    Plotly.newPlot(                        "18d1c18a-f028-4c09-bb84-7f86940e5c3d",                        [{"hovertemplate":"Importance=%{x}\u003cbr\u003eFeature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#DE237B","symbol":"circle","size":8},"mode":"markers","name":"","orientation":"h","showlegend":false,"x":[0.10770577015067943,0.06356966855373318,0.05765219212055071,0.039136845491346266,0.038458656953993774,0.03828374735867829,0.035876159468283986,0.035429104540504575,0.03035604131686125,0.0299280137418646,0.026081532762625384,0.02585492566434519,0.024328747321386398,0.02361592736311978,0.022759369436578008,0.02204220654840946,0.021711367339472397,0.021245600199638406,0.01965352111293975,0.018462045694103427,0.017313132659474807,0.017245185609996994,0.016262998108493246,0.01625264333017709,0.015946056599501216,0.015668113188984197,0.015431095844795165,0.014767710401997628,0.013745313931716461,0.013637813917347861,0.013274716789531096,0.012489592183635793,0.011670611847793208,0.011251062572684429,0.01109007827034704,0.008211353698257304,0.007550886475030738,0.007430546848360263,0.0070291751172025,0.006213006823493403,0.006116859569652931,0.005639236090685405,0.005390856522550617,0.005290167679214925,0.004934066222462831,0.004419857014430116,0.0040097157280995326,0.002953752793357703,0.002884198990274153,0.002435309861827304,0.0010813886602450084,0.0002120535092647461,0.0,0.0],"xaxis":"x","y":["t_n_mean","t_n_std","b_mean","P3b_mean","CNV_mean","a_n_mean","a_n_std","d_std","wSMI_4_mean","msf_mean","P1_mean","p_e_8_std","p_e_4_mean","d_n_mean","wSMI_8_mean","wSMI_2_std","g_std","sef90_std","msf_std","P1_std","d_mean","wSMI_8_std","wSMI_2_mean","CNV_std","P3a_std","wSMI_1_std","wSMI_4_std","a_std","t_mean","b_n_std","p_e_4_std","p_e_2_mean","k_std","sef95_mean","b_std","t_std","k_mean","b_n_mean","sef90_mean","p_e_8_mean","g_mean","p_e_1_std","se_mean","g_n_mean","p_e_1_mean","sef95_std","p_e_2_std","P3b_std","wSMI_1_mean","a_mean","P3a_mean","se_std","g_n_std","d_n_std"],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[ ...

# %% [markdown]
# ## dMW Vs sMW
# This will be only performed in SC as they have more trials

# %%
agg_dict = {k:['mean', 'std'] for k in markers }
agg_dict.update({k:'first' for k in df_markers.drop(markers, axis=1).columns})

df_mw = (
    df_markers
    .query("probe == 'PC'")
    .query("mind != 'on-task'")
    .groupby(['segment', 'participant'], as_index = False).agg(agg_dict)
)

############################################################
################ Use normal names################
############################################################
df_mw.columns = df_mw.columns.map("_".join)

df_mw  = (df_mw
            .rename(columns = {'participant_first':'participant', 'probe_first':'probe', 'mind_first':'mind', 'segment_first':'segment'})
            .drop([ 'probe',], axis = 1) 
           )


############################################################
################ Use latex command for nmaes################
############################################################

# df_mw = correct_name_markers(df_mw)

# df_mw.columns = df_mw.columns.map("$_{".join).map(lambda x: x + '}$').map(lambda x: x.replace('$$', ''))

# df_mw  = (df_mw
#             .rename(columns = {'participant$_{first}$':'participant', 'probe$_{first}$':'probe', 'mind$_{first}$':'mind', 'segment$_{first}$':'segment', 'mind$_{}$':'mind'})
# #             .query("mind != 'dMW'") #if you want to test against just one of the mw   
#             .drop(['participant', 'probe',  'segment'], axis = 1)

#            )


df_mw['mind_numeric'] = (df_mw['mind'] == 'sMW').astype(int)

df_mw.to_csv(os.path.join(results_path,'data_mw.csv'))

# Columns to remove outliers from
columns_to_check = df_mw.drop(['mind', 'mind_numeric', 'participant', 'segment'], axis = 1).columns

def filter_participants(group):
    counts = group['mind_numeric'].value_counts()
    # Check if there is only one level of 'mind2' for the participant
    if len(counts) == 1:
        return False
    return all(count >= 1 for count in counts)
df_mw = df_mw.groupby('participant').filter(filter_participants)
# Remove outliers
df_mw_filtered = replace_outliers_with_participant_mean(df_mw, columns_to_check, z_threshold=3)

# df_mw = df_mw_filtered

# %%
# Initialize lists to store AUC and permutation scores
scores = []
perm_auc_scores_all = []
optimal_cutoffs = []

n_splits = 4
group_kfold = GroupKFold(n_splits=n_splits)

# Assuming df_mw['participant'] contains the participant IDs
# Prepare data
X = df_mw.drop(['mind', 'mind_numeric', 'participant','segment'], axis=1)
Z = np.ones((X.shape[0], 1))  # Random effects design matrix
groups = df_mw['participant']
y = df_mw['mind_numeric']


# Global dictionary for storing trial data
trial_data = {}
def objective(trial):
    global trial_data
    # Hyperparameters to be optimized
    n_estimators = trial.suggest_int('n_estimators', 2, 100)
    max_depth = trial.suggest_int('max_depth', 2, 32, log=True)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    max_features = trial.suggest_uniform('max_features', 0.1, 1.0)

    scores = []
    
    feature_importances = None
    for train_index, test_index in group_kfold.split(X, y, groups.values):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        X_train = StandardScaler().fit_transform(X_train)
        X_test = StandardScaler().fit_transform(X_test)
        
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        clusters_train, clusters_test = groups.iloc[train_index], groups.iloc[test_index]
        
        # Initialize MERF with trial-suggested parameters
        merf = MERF(fixed_effects_model=RandomForestRegressor(
                    n_estimators=n_estimators,
                    max_depth=max_depth,
                    min_samples_leaf=min_samples_leaf,
                    max_features=max_features,
                    random_state=42,
                    n_jobs=-1
        ),
        gll_early_stop_threshold=1,
        max_iterations=50
        )
        
        merf.fit(X_train, Z[train_index], clusters_train, y_train)
        
        
        y_pred = merf.predict(X_test, Z[test_index], clusters_test)

        # Convert continuous outputs to probabilities
        y_pred_proba = expit(y_pred)
        
        # Find optimal cutoff point based on F1 score
        thresholds = np.linspace(0, 1, 100)
        f1_scores = [f1_score(y_test, (y_pred_proba > t).astype(int)) for t in thresholds]
        optimal_threshold = thresholds[np.argmax(f1_scores)]
        optimal_cutoffs.append(optimal_threshold)
        
        # Thresholding to get class labels
        y_pred_class = (y_pred_proba > optimal_threshold).astype(int)

        # Compute AUC for probabilities
        auc = roc_auc_score(y_test, y_pred_proba)
        scores.append(auc)
        
        # Get feature importances (only need to do this once per trial)
        if feature_importances is None:
            feature_importances = merf.fe_model.feature_importances_

    # Store trial data
    trial_data[trial.number] = {
        'fold_aucs': scores,
        'feature_importances': feature_importances
    }

    # Average AUC over all folds
    avg_auc = np.mean(scores)
    return avg_auc

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=1000)


# Construct the file path for the study database
study_db_path = os.path.join(results_path, 'multivariate_merf_mw_study.db')
# Use the SQLite database at the specified path for storage
study = optuna.create_study(direction="maximize", study_name="mw_mvpa_study", storage=f'sqlite:///{study_db_path}', load_if_exists=True)

# Best hyperparameters.
# Save the best trial's parameters to a file
best_params_path = os.path.join(results_path, 'mvpa_merf_mw_best_params.txt')
with open(best_params_path, 'w') as file:
    for key, value in study.best_trial.params.items():
        file.write(f'{key}: {value}\n')

# print('Best trial:', study.best_trial.params)
study_df = study.trials_dataframe()
for trial_num in trial_data:
    study_df.loc[study_df.number == trial_num, 'fold_aucs'] = str(trial_data[trial_num]['fold_aucs'])
    study_df.loc[study_df.number == trial_num, 'feature_importances'] = str(trial_data[trial_num]['feature_importances'])
    
study_df.sort_values('value', ascending=False).to_csv(os.path.join(results_path, 'mvpa_merf_mw_opt_trials.csv'))


best_params = study.best_trial.params

# Initialize lists to store AUC and permutation scores
scores = []
perm_auc_scores_all = []
optimal_cutoffs = []

n_splits = 4
group_kfold = GroupKFold(n_splits=n_splits)


# Replace with your actual file path
best_params_path = os.path.join(results_path, 'mvpa_merf_mw_best_params.txt')

# Read the parameters from the file and store them in a dictionary
best_params = {}
with open(best_params_path, 'r') as file:
    for line in file:
        key, value = line.split(': ')
        best_params[key] = float(value.strip())

scores = []

for train_index, test_index in group_kfold.split(X, y, groups.values):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    X_train = StandardScaler().fit_transform(X_train)
    X_test = StandardScaler().fit_transform(X_test)
    
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    clusters_train, clusters_test = groups.iloc[train_index], groups.iloc[test_index]
    
    # Create and configure the model with the best parameters
    merf = MERF(
        RandomForestRegressor(
            n_estimators=int(best_params["n_estimators"]),
            max_depth=int(best_params["max_depth"]),
            min_samples_leaf=int(best_params["min_samples_leaf"]),
            max_features=best_params["max_features"],
            random_state=42,  # Assuming you want to keep the random state fixed
            n_jobs=-1
            ),
        gll_early_stop_threshold=0.5,
        max_iterations=50
        )
    
    merf.fit(X_train, Z[train_index], clusters_train, y_train)
    
    
    y_pred = merf.predict(X_test, Z[test_index], clusters_test)

    # Convert continuous outputs to probabilities
    y_pred_proba = expit(y_pred)
    
    # Find optimal cutoff point based on F1 score
    thresholds = np.linspace(0, 1, 100)
    f1_scores = [f1_score(y_test, (y_pred_proba > t).astype(int)) for t in thresholds]
    optimal_threshold = thresholds[np.argmax(f1_scores)]
    optimal_cutoffs.append(optimal_threshold)
    
    # Thresholding to get class labels
    y_pred_class = (y_pred_proba > optimal_threshold).astype(int)

    # Compute AUC for probabilities
    auc = roc_auc_score(y_test, y_pred_proba)
    scores.append(auc)

# Average AUC over all folds
avg_auc = np.mean(scores)
print(scores)
print(avg_auc)
# Out:
# [I 2023-12-29 09:39:22,919] A new study created in memory with name: no-name-ed7c8306-e004-427d-bd50-4ba0e0ce10fc
# /tmp/ipykernel_13977/2584719334.py:21: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is
and parameters: {'n_estimators': 77, 'max_depth': 5, 'min_samples_leaf': 6, 'max_features': 0.8046410278768573}. Best is trial 22 with value: 0.7028769841269842.
# /tmp/ipykernel_13977/2584719334.py:21: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -48.380307930328584 at iteration 1.
# INFO     [merf.py:307] Training GLL is -64.79550716637988 at iteration 2.
# INFO     [merf.py:321] Gll -64.79550716637988 less than threshold 0.33929505491553424, stopping early ...
# INFO     [merf.py:307] Training GLL is -48.8542423762156 at iteration 1.
# INFO     [merf.py:307] Training GLL is -66.19579374988245 at iteration 2.
# INFO     [merf.py:321] Gll -66.19579374988245 less than threshold 0.3549651070243489, stopping early ...
# INFO     [merf.py:307] Training GLL is -48.74853758075083 at iteration 1.
# INFO     [merf.py:307] Training GLL is -65.99661542003211 at iteration 2.
# INFO     [merf.py:321] Gll -65.99661542003211 less than threshold 0.35381733884242667, stopping early ...
# INFO     [merf.py:307] Training GLL is -48.495986719189034 at iteration 1.
# INFO     [merf.py:307] Training GLL is -67.27425796274235 at iteration 2.
# INFO     [merf.py:321] Gll -67.27425796274235 less than threshold 0.3872128914973304, stopping early ...
# [I 2023-12-29 09:40:43,685] Trial 29 finished with value: 0.6116071428571429 and parameters: {'n_estimators': 62, 'max_depth': 7, 'min_samples_leaf': 9, 'max_features': 0.5133647848068498}. Best is trial 22 with value: 0.7028769841269842.
# /tmp/ipykernel_13977/2584719334.py:21: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -88.00448151741719 at iteration 1.
# INFO     [merf.py:307] Training GLL is -137.38030649627882 at iteration 2.
# INFO     [merf.py:321] Gll -137.38030649627882 less than threshold 0.5610603474675268, stopping early ...
# INFO     [merf.py:307] Training GLL is -87.26939708014497 at iteration 1.
# INFO     [merf.py:307] Training GLL is -130.6737623556709 at iteration 2.
# INFO     [merf.py:321] Gll -130.6737623556709 less than threshold 0.497360663964081, stopping early ...
# INFO     [merf.py:307] Training GLL is -82.8453552330422 at iteration 1.
# INFO     [merf.py:307] Training GLL is -125.1013879385655 at iteration 2.
# INFO     [merf.py:321] Gll -125.1013879385655 less than threshold 0.510059164894133, stopping early ...
# INFO     [merf.py:307] Training GLL is -89.47936695812925 at iteration 1.
# INFO     [merf.py:307] Training GLL is -135.04747560095524 at iteration 2.
# INFO     [merf.py:321] Gll -135.04747560095524 less than threshold 0.509258281455534, stopping early ...
# [I 2023-12-29 09:40:45,877] Trial 30 finished with value: 0.6279761904761905 and parameters: {'n_estimators': 35, 'max_depth': 8, 'min_samples_leaf': 1, 'max_features': 0.719133397296344}. Best is trial 22 with value: 0.7028769841269842.
# /tmp/ipykernel_13977/2584719334.py:21: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -74.79864685399674 at iteration 1.
# INFO     [merf.py:307] Training GLL is -108.22263433646133 at iteration 2.
# INFO     [merf.py:321] Gll -108.22263433646133 less than threshold 0.446852836090826, stopping early ...
# INFO     [merf.py:307] Training GLL is -74.41250779885706 at iteration 1.
# INFO     [merf.py:307] Training GLL is -105.05506198043678 at iteration 2.
# INFO     [merf.py:321] Gll -105.05506198043678 less than threshold 0.4117930585595768, stopping early ...
# INFO     [merf.py:307] Training GLL is -72.39566920272362 at iteration 1.
# INFO     [merf.py:307] Training GLL is -102.68297246469142 at iteration 2.
stopping early ...
# INFO     [merf.py:307] Training GLL is -66.2922951767052 at iteration 1.
# INFO     [merf.py:307] Training GLL is -92.71466219718891 at iteration 2.
# INFO     [merf.py:321] Gll -92.71466219718891 less than threshold 0.39857372489598786, stopping early ...
# INFO     [merf.py:307] Training GLL is -64.68194286096542 at iteration 1.
# INFO     [merf.py:307] Training GLL is -90.93657256319716 at iteration 2.
# INFO     [merf.py:321] Gll -90.93657256319716 less than threshold 0.4059035418689628, stopping early ...
# INFO     [merf.py:307] Training GLL is -67.4769062552095 at iteration 1.
# INFO     [merf.py:307] Training GLL is -95.18679916534654 at iteration 2.
# INFO     [merf.py:321] Gll -95.18679916534654 less than threshold 0.4106574300447825, stopping early ...
# [I 2023-12-29 09:48:50,735] Trial 198 finished with value: 0.6448412698412698 and parameters: {'n_estimators': 67, 'max_depth': 14, 'min_samples_leaf': 4, 'max_features': 0.331457821808393}. Best is trial 180 with value: 0.7390873015873016.
# /tmp/ipykernel_13977/2584719334.py:21: FutureWarning:
#
# suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#
# INFO     [merf.py:307] Training GLL is -68.14369864312509 at iteration 1.
# INFO     [merf.py:307] Training GLL is -97.21177099019346 at iteration 2.
# INFO     [merf.py:321] Gll -97.21177099019346 less than threshold 0.426570217435666, stopping early ...
# INFO     [merf.py:307] Training GLL is -67.77876329917194 at iteration 1.
# INFO     [merf.py:307] Training GLL is -97.28510303800294 at iteration 2.
# INFO     [merf.py:321] Gll -97.28510303800294 less than threshold 0.43533310881745585, stopping early ...
# INFO     [merf.py:307] Training GLL is -66.83065782960944 at iteration 1.
# INFO     [merf.py:307] Training GLL is -95.9040958862245 at iteration 2.
# INFO     [merf.py:321] Gll -95.9040958862245 less than threshold 0.4350314511453757, stopping early ...
# INFO     [merf.py:307] Training GLL is -68.22593513431205 at iteration 1.
# INFO     [merf.py:307] Training GLL is -96.11703244443845 at iteration 2.
# INFO     [merf.py:321] Gll -96.11703244443845 less than threshold 0.40880491055518653, stopping early ...
# [I 2023-12-29 09:48:53,892] Trial 199 finished with value: 0.6904761904761905 and parameters: {'n_estimators': 71, 'max_depth': 15, 'min_samples_leaf': 4, 'max_features': 0.36833527490339835}. Best is trial 180 with value: 0.7390873015873016.
# INFO     [merf.py:307] Training GLL is -65.424079095346 at iteration 1.
# INFO     [merf.py:307] Training GLL is -88.79235869522309 at iteration 2.
# INFO     [merf.py:321] Gll -88.79235869522309 less than threshold 0.35718163592064084, stopping early ...
# INFO     [merf.py:307] Training GLL is -62.16237746468657 at iteration 1.
# INFO     [merf.py:307] Training GLL is -87.16126200947973 at iteration 2.
# INFO     [merf.py:321] Gll -87.16126200947973 less than threshold 0.40215457587661624, stopping early ...
# INFO     [merf.py:307] Training GLL is -60.47235407581095 at iteration 1.
# INFO     [merf.py:307] Training GLL is -84.79761431057823 at iteration 2.
# INFO     [merf.py:321] Gll -84.79761431057823 less than threshold 0.40225423016064504, stopping early ...
# INFO     [merf.py:307] Training GLL is -62.498327288886074 at iteration 1.
# INFO     [merf.py:307] Training GLL is -86.69414539666337 at iteration 2.
# INFO     [merf.py:321] Gll -86.69414539666337 less than threshold 0.38714345099088726, stopping early ...
# [0.75, 0.746031746031746, 0.75, 0.6825396825396826]
# 0.7321428571428572

# %%
# Extract feature importances
feature_importances = merf.fe_model.feature_importances_

features = df_mw.drop(['mind', 'mind_numeric', 'participant','segment'], axis=1).columns
# Combine names and importances into a DataFrame
importances_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

importances_df.to_csv(os.path.join(results_path, f'mvpa_mw_merf_feat_imp.csv'))


fig = px.scatter(importances_df, x='Importance', y='Feature', orientation='h',
                title=f'Feat Imp MERF, AUC: {avg_auc:.3f}', template = "plotly_white",
                color_discrete_sequence = [lblue],
                labels = {'value':'Feature importance', 'features': 'Markers'}

                )

fig.update_traces(marker=dict(size = 8))

fig.update_layout(
    width=650,
    height=900,
#     autosize = True, 
    template = 'plotly_white',
        font=dict(
        family="Times new roman",
        size=20,
        color="black"
    ),
    xaxis = dict(
            visible=True,
            # range = [0.37,0.63], 
            tickfont = {"size": 20},
            title = 'Feature Importance'
        ),
    yaxis = dict(
        categoryorder =  'total ascending',
        tickfont = {"size": 20},
        # autorange = False,    
        automargin = True,
        # range = [-1,len(feat_import_mw)],
        dtick = 1
        ),
    showlegend=True, 

)

fig.show()
# pio.write_json(fig, 'Figs/univariate_roc_mw_segment.plotly')
fig.write_image(os.path.join(fig_path, 'feat_importance_mw.png'))
fig.write_image(os.path.join(fig_path, 'feat_importance_mw.svg'))
# Out:
# <div>                            <div id="b46bd6ad-caa3-4f1a-8c1c-d3ab4c75545c" class="plotly-graph-div" style="height:900px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b46bd6ad-caa3-4f1a-8c1c-d3ab4c75545c")) {                    Plotly.newPlot(                        "b46bd6ad-caa3-4f1a-8c1c-d3ab4c75545c",                        [{"hovertemplate":"Importance=%{x}\u003cbr\u003eFeature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#42B9B2","symbol":"circle","size":8},"mode":"markers","name":"","orientation":"h","showlegend":false,"x":[0.07177262637893025,0.06418749784137602,0.05171985581234453,0.04784760386696354,0.04275312790435208,0.03408638361675108,0.03151416885844593,0.030982853629295593,0.02861169769779725,0.027218199051767887,0.026137621838125315,0.02505977647622068,0.02505681755638149,0.024931890934517906,0.024559861904341236,0.023970640358379872,0.022602217258334816,0.021301797051942958,0.021177451258344946,0.021138448704012987,0.020099975317916782,0.018774245350464503,0.015951030780296697,0.015588416012632266,0.015342016451827136,0.015162883052815003,0.015094509523511435,0.01466443638061954,0.013922358767971673,0.013699234210560036,0.013624124066709231,0.012835906540239214,0.012784236822931918,0.012176886460571868,0.012173302950686334,0.012103938104329677,0.010691099637887332,0.008661611180010314,0.008309123176307179,0.007702802637557541,0.007560322862338738,0.006709948775518877,0.006513348495036855,0.0052497606736370645,0.005143977393058667,0.005063813076185422,0.004961158163613404,0.004910613331842837,0.00486545535895998,0.004499263148705441,0.004194001248150386,0.0027456871396053587,0.0008165796113012693,0.000773395297573808],"xaxis":"x","y":["msf_mean","g_n_mean","wSMI_2_std","sef95_mean","k_mean","sef90_mean","se_std","wSMI_1_std","t_n_mean","wSMI_8_std","p_e_2_std","wSMI_1_mean","P3b_mean","se_mean","a_std","b_std","a_n_std","d_n_std","b_n_std","g_std","P3a_std","d_mean","CNV_std","wSMI_4_std","t_n_std","t_std","P1_std","k_std","p_e_1_std","g_n_std","sef95_std","d_n_mean","P3b_std","CNV_mean","a_n_mean","p_e_4_std","p_e_8_mean","p_e_2_mean","g_mean","t_mean","p_e_4_mean","d_std","p_e_8_std","wSMI_2_mean","P1_mean","P3a_mean","wSMI_8_mean","sef90_std","p_e_1_mean","a_mean","b_n_mean","msf_std","wSMI_4_mean","b_mean"],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed79 ...
