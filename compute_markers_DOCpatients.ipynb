# %%
import os
import numpy as np
import pandas as pd
import mne 


from utils import make_str_label, all_markers
# Out:
# Using MNE with API > 0.19

# %% [markdown]
# # Load Data

# %%
all_participants = ['VP07','VP08','VP09', 'VP10','VP11','VP12','VP13','VP14','VP18','VP19','VP20','VP22','VP23','VP24','VP25','VP26','VP27','VP28','VP29','VP30','VP31','VP32','VP33','VP35','VP36','VP37']


path = '/media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/' #icm-linux
# path = '/Users/nicobruno/ownCloud/MW_eeg_data/minmarker/' #nico-mac

classes = os.listdir(path)

# %% [markdown]
# # Compute markers for all subjects

# %%
target = 'epochs'

for i in classes:
    files = os.listdir(path + i + '/')
    files.remove('markers')
    
    cat = i[2:4]
        
    print('#########################################')
    print(f'Computing markers for {cat} participants')
    print('#########################################')
    
    for file in files:
        
        participant = file[:7]
        
        print(f'####Computing participant {participant}####')

    
#         df_markers = pd.DataFrame()
#         df_markers['participant'] = participant

        #############################
        #### With ERP SUBTRACTED ####
        #############################
        epochs = mne.read_epochs(path + i + '/' + file) 
        epochs_subtracted = epochs.copy().subtract_evoked()
        
        

        df = pd.DataFrame.from_dict(all_markers(epochs_subtracted, 0, 0.6, target, epochs_erp = epochs))
        df['participant'] = participant
        df['category'] = cat
        

        df.to_csv(path + i + '/markers/' + participant + '_all_marker.csv')
# Out:
# #########################################
# Computing markers for VS participants
# #########################################
# ####Computing participant sub-047####
# Reading /media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/2_VS_patients/sub-047_icm-lg-egi-epo.fif ...
#     Read a total of 2 projection items:
#         Average EEG reference (1 x 235) active
#         Average EEG reference (1 x 256) active
#     Found the data of interest:
#         t =    -200.00 ...    1340.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 784 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 2)
# 2 projection items activated
# Subtracting Evoked from Epochs
# [done]
# Autodetected number of jobs 24
# Effective window size : 16.384 (s)
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   6 out of  24 | elapsed:   12.4s remaining:   37.3s
# [Parallel(n_jobs=24)]: Done  11 out of  24 | elapsed:   13.5s remaining:   16.0s
# [Parallel(n_jobs=24)]: Done  16 out of  24 | elapsed:   14.6s remaining:    7.3s
# [Parallel(n_jobs=24)]: Done  21 out of  24 | elapsed:   15.7s remaining:    2.2s
# [Parallel(n_jobs=24)]: Done  24 out of  24 | elapsed:   16.4s finished
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/gamma: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/summary_se: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_msf: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef90: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef95: ['channels']
# Running KolmogorovComplexity
# Elapsed time 4.569010496139526 sec
# Reduction order for nice/marker/KolmogorovComplexity/default: ['channels']
# Filtering  at 83.33 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: divide by zero encountered in log
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: invalid value encountered in multiply
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# Filtering  at 41.67 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 20.83 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 10.42 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=2)]: Done 784 out of 784 | elapsed:    6.3s finished
# Filtering  at 83.33 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=2)]: Done 784 out of 784 | elapsed:    4.6s finished
# Filtering  at 41.67 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=2)]: Done 784 out of 784 | elapsed:    4.4s finished
# Filtering  at 20.83 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 784 out of 784 | elapsed:    4.3s finished
# Filtering  at 10.42 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Reduction order for nice/marker/ContingentNegativeVariation/default: ['channels']
# Reduction order for nice/marker/TimeLockedTopography/p1: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3a: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3b: ['channels', 'times']
# ####Computing participant sub-092####
# Reading /media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/2_VS_patients/sub-092_icm-lg-egi-epo.fif ...
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
#     Read a total of 2 projection items:
#         Average EEG reference (1 x 230) active
#         Average EEG reference (1 x 256) active
#     Found the data of interest:
#         t =    -200.00 ...    1340.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 777 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 2)
# 2 projection items activated
# Subtracting Evoked from Epochs
# [done]
# Autodetected number of jobs 24
# Effective window size : 16.384 (s)
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   6 out of  24 | elapsed:   15.2s remaining:   45.6s
# [Parallel(n_jobs=24)]: Done  11 out of  24 | elapsed:   16.7s remaining:   19.7s
# [Parallel(n_jobs=24)]: Done  16 out of  24 | elapsed:   17.7s remaining:    8.8s
# [Parallel(n_jobs=24)]: Done  21 out of  24 | elapsed:   18.6s remaining:    2.7s
# [Parallel(n_jobs=24)]: Done  24 out of  24 | elapsed:   19.3s finished
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/gamma: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/summary_se: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_msf: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef90: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef95: ['channels']
# Running KolmogorovComplexity
# Elapsed time 4.47125768661499 sec
# Reduction order for nice/marker/KolmogorovComplexity/default: ['channels']
# Filtering  at 83.33 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: divide by zero encountered in log
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: invalid value encountered in multiply
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# Filtering  at 41.67 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 20.83 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 10.42 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=2)]: Done 777 out of 777 | elapsed:    6.1s finished
# Filtering  at 83.33 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  74 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=2)]: Done 777 out of 777 | elapsed:    3.9s finished
# Filtering  at 41.67 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 286 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=2)]: Done 777 out of 777 | elapsed:    6.6s finished
# Filtering  at 20.83 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 777 out of 777 | elapsed:    4.2s finished
# Filtering  at 10.42 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Reduction order for nice/marker/ContingentNegativeVariation/default: ['channels']
# Reduction order for nice/marker/TimeLockedTopography/p1: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3a: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3b: ['channels', 'times']
# ####Computing participant sub-011####
# Reading /media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/2_VS_patients/sub-011_icm-lg-egi-epo.fif ...
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
#     Read a total of 2 projection items:
#         Average EEG reference (1 x 224) active
#         Average EEG reference (1 x 256) active
#     Found the data of interest:
#         t =    -200.00 ...    1340.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 876 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 2)
# 2 projection items activated
# Subtracting Evoked from Epochs
# [done]
# Autodetected number of jobs 24
# Effective window size : 16.384 (s)
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   6 out of  24 | elapsed:   14.1s remaining:   42.4s
# [Parallel(n_jobs=24)]: Done  11 out of  24 | elapsed:   15.1s remaining:   17.9s
# [Parallel(n_jobs=24)]: Done  16 out of  24 | elapsed:   16.3s remaining:    8.2s
# [Parallel(n_jobs=24)]: Done  21 out of  24 | elapsed:   17.5s remaining:    2.5s
# [Parallel(n_jobs=24)]: Done  24 out of  24 | elapsed:   18.3s finished
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/gamma: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/summary_se: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_msf: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef90: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef95: ['channels']
# Running KolmogorovComplexity
# Elapsed time 5.127700090408325 sec
# Reduction order for nice/marker/KolmogorovComplexity/default: ['channels']
# Filtering  at 83.33 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: divide by zero encountered in log
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: invalid value encountered in multiply
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# Filtering  at 41.67 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 20.83 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 10.42 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=2)]: Done 414 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=2)]: Done 876 out of 876 | elapsed:   23.3s finished
# Filtering  at 83.33 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  94 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=2)]: Done 526 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=2)]: Done 876 out of 876 | elapsed:   18.8s finished
# Filtering  at 41.67 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  94 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=2)]: Done 526 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=2)]: Done 876 out of 876 | elapsed:   18.9s finished
# Filtering  at 20.83 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  94 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=2)]: Done 526 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=2)]: Done 876 out of 876 | elapsed:   19.1s finished
# Filtering  at 10.42 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Reduction order for nice/marker/ContingentNegativeVariation/default: ['channels']
# Reduction order for nice/marker/TimeLockedTopography/p1: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3a: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3b: ['channels', 'times']
# ####Computing participant sub-027####
# Reading /media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/2_VS_patients/sub-027_icm-lg-egi-epo.fif ...
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
#     Read a total of 2 projection items:
#         Average EEG reference (1 x 250) active
#         Average EEG reference (1 x 256) active
#     Found the data of interest:
#         t =    -200.00 ...    1340.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 825 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 2)
# 2 projection items activated
# Subtracting Evoked from Epochs
# [done]
# Autodetected number of jobs 24
# Effective window size : 16.384 (s)
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   6 out of  24 | elapsed:   38.4s remaining:  1.9min
# [Parallel(n_jobs=24)]: Done  11 out of  24 | elapsed:   40.2s remaining:   47.5s
# [Parallel(n_jobs=24)]: Done  16 out of  24 | elapsed:   42.1s remaining:   21.1s
# [Parallel(n_jobs=24)]: Done  21 out of  24 | elapsed:   44.4s remaining:    6.3s
# [Parallel(n_jobs=24)]: Done  24 out of  24 | elapsed:   45.8s finished
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/gamma: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/summary_se: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_msf: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef90: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef95: ['channels']
# Running KolmogorovComplexity
# Elapsed time 6.997821807861328 sec
# Reduction order for nice/marker/KolmogorovComplexity/default: ['channels']
# Filtering  at 83.33 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: divide by zero encountered in log
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: invalid value encountered in multiply
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# Filtering  at 41.67 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 20.83 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 10.42 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=2)]: Done 825 out of 825 | elapsed:    6.4s finished
# Filtering  at 83.33 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 825 out of 825 | elapsed:    4.6s finished
# Filtering  at 41.67 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 825 out of 825 | elapsed:    4.5s finished
# Filtering  at 20.83 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=2)]: Done 825 out of 825 | elapsed:    4.2s finished
# Filtering  at 10.42 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Reduction order for nice/marker/ContingentNegativeVariation/default: ['channels']
# Reduction order for nice/marker/TimeLockedTopography/p1: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3a: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3b: ['channels', 'times']
# ####Computing participant sub-045####
# Reading /media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/2_VS_patients/sub-045_icm-lg-egi-epo.fif ...
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
#     Read a total of 2 projection items:
#         Average EEG reference (1 x 242) active
#         Average EEG reference (1 x 256) active
#     Found the data of interest:
#         t =    -200.00 ...    1340.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 651 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 2)
# 2 projection items activated
# Subtracting Evoked from Epochs
# [done]
# Autodetected number of jobs 24
# Effective window size : 16.384 (s)
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   6 out of  24 | elapsed:   12.2s remaining:   36.6s
# [Parallel(n_jobs=24)]: Done  11 out of  24 | elapsed:   13.1s remaining:   15.5s
# [Parallel(n_jobs=24)]: Done  16 out of  24 | elapsed:   14.0s remaining:    7.0s
# [Parallel(n_jobs=24)]: Done  21 out of  24 | elapsed:   14.8s remaining:    2.1s
# [Parallel(n_jobs=24)]: Done  24 out of  24 | elapsed:   15.4s finished
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/gamma: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/summary_se: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_msf: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef90: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef95: ['channels']
# Running KolmogorovComplexity
# Elapsed time 3.6430535316467285 sec
# Reduction order for nice/marker/KolmogorovComplexity/default: ['channels']
# Filtering  at 83.33 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: divide by zero encountered in log
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: invalid value encountered in multiply
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# Filtering  at 41.67 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 20.83 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 10.42 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=2)]: Done 651 out of 651 | elapsed:    5.8s finished
# Filtering  at 83.33 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 651 out of 651 | elapsed:    3.6s finished
# Filtering  at 41.67 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 651 out of 651 | elapsed:    3.7s finished
# Filtering  at 20.83 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 651 out of 651 | elapsed:    3.7s finished
# Filtering  at 10.42 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Reduction order for nice/marker/ContingentNegativeVariation/default: ['channels']
# Reduction order for nice/marker/TimeLockedTopography/p1: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3a: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3b: ['channels', 'times']
# ####Computing participant sub-026####
# Reading /media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/2_VS_patients/sub-026_icm-lg-egi-epo.fif ...
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
#     Read a total of 2 projection items:
#         Average EEG reference (1 x 240) active
#         Average EEG reference (1 x 256) active
#     Found the data of interest:
#         t =    -200.00 ...    1340.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 971 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 2)
# 2 projection items activated
# Subtracting Evoked from Epochs
# [done]
# Autodetected number of jobs 24
# Effective window size : 16.384 (s)
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   6 out of  24 | elapsed:   16.2s remaining:   48.7s
# [Parallel(n_jobs=24)]: Done  11 out of  24 | elapsed:   17.5s remaining:   20.7s
# [Parallel(n_jobs=24)]: Done  16 out of  24 | elapsed:   18.8s remaining:    9.4s
# [Parallel(n_jobs=24)]: Done  21 out of  24 | elapsed:   20.1s remaining:    2.9s
# [Parallel(n_jobs=24)]: Done  24 out of  24 | elapsed:   20.9s finished
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/gamma: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/summary_se: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_msf: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef90: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef95: ['channels']
# Running KolmogorovComplexity
# Elapsed time 5.640264511108398 sec
# Reduction order for nice/marker/KolmogorovComplexity/default: ['channels']
# Filtering  at 83.33 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: divide by zero encountered in log
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: invalid value encountered in multiply
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# Filtering  at 41.67 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 20.83 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 10.42 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=2)]: Done 968 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=2)]: Done 971 out of 971 | elapsed:    7.4s finished
# Filtering  at 83.33 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 971 out of 971 | elapsed:    5.3s finished
# Filtering  at 41.67 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=2)]: Done 971 out of 971 | elapsed:    5.4s finished
# Filtering  at 20.83 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=2)]: Done 971 out of 971 | elapsed:    5.5s finished
# Filtering  at 10.42 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Reduction order for nice/marker/ContingentNegativeVariation/default: ['channels']
# Reduction order for nice/marker/TimeLockedTopography/p1: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3a: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3b: ['channels', 'times']
# ####Computing participant sub-018####
# Reading /media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/2_VS_patients/sub-018_icm-lg-egi-epo.fif ...
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
#     Read a total of 2 projection items:
#         Average EEG reference (1 x 239) active
#         Average EEG reference (1 x 256) active
#     Found the data of interest:
#         t =    -200.00 ...    1340.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 875 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 2)
# 2 projection items activated
# Subtracting Evoked from Epochs
# [done]
# Autodetected number of jobs 24
# Effective window size : 16.384 (s)
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   6 out of  24 | elapsed:   15.8s remaining:   47.4s
# [Parallel(n_jobs=24)]: Done  11 out of  24 | elapsed:   17.0s remaining:   20.1s
# [Parallel(n_jobs=24)]: Done  16 out of  24 | elapsed:   18.2s remaining:    9.1s
# [Parallel(n_jobs=24)]: Done  21 out of  24 | elapsed:   19.4s remaining:    2.8s
# [Parallel(n_jobs=24)]: Done  24 out of  24 | elapsed:   20.1s finished
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/gamma: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/summary_se: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_msf: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef90: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef95: ['channels']
# Running KolmogorovComplexity
# Elapsed time 5.2475266456604 sec
# Reduction order for nice/marker/KolmogorovComplexity/default: ['channels']
# Filtering  at 83.33 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: divide by zero encountered in log
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: invalid value encountered in multiply
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# Filtering  at 41.67 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 20.83 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 10.42 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=2)]: Done 866 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=2)]: Done 875 out of 875 | elapsed:    7.0s finished
# Filtering  at 83.33 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=2)]: Done 875 out of 875 | elapsed:    4.9s finished
# Filtering  at 41.67 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 875 out of 875 | elapsed:    4.8s finished
# Filtering  at 20.83 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=2)]: Done 875 out of 875 | elapsed:    4.8s finished
# Filtering  at 10.42 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Reduction order for nice/marker/ContingentNegativeVariation/default: ['channels']
# Reduction order for nice/marker/TimeLockedTopography/p1: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3a: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3b: ['channels', 'times']
# ####Computing participant sub-042####
# Reading /media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/2_VS_patients/sub-042_icm-lg-egi-epo.fif ...
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
#     Read a total of 2 projection items:
#         Average EEG reference (1 x 237) active
#         Average EEG reference (1 x 256) active
#     Found the data of interest:
#         t =    -200.00 ...    1340.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 794 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 2)
# 2 projection items activated
# Subtracting Evoked from Epochs
# [done]
# Autodetected number of jobs 24
# Effective window size : 16.384 (s)
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   6 out of  24 | elapsed:   15.0s remaining:   44.9s
# [Parallel(n_jobs=24)]: Done  11 out of  24 | elapsed:   15.8s remaining:   18.7s
# [Parallel(n_jobs=24)]: Done  16 out of  24 | elapsed:   16.7s remaining:    8.4s
# [Parallel(n_jobs=24)]: Done  21 out of  24 | elapsed:   17.8s remaining:    2.5s
# [Parallel(n_jobs=24)]: Done  24 out of  24 | elapsed:   18.4s finished
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/gamma: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/summary_se: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_msf: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef90: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef95: ['channels']
# Running KolmogorovComplexity
# Elapsed time 4.601041078567505 sec
# Reduction order for nice/marker/KolmogorovComplexity/default: ['channels']
# Filtering  at 83.33 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: divide by zero encountered in log
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: invalid value encountered in multiply
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# Filtering  at 41.67 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 20.83 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 10.42 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  16 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=2)]: Done 794 out of 794 | elapsed:    6.5s finished
# Filtering  at 83.33 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=2)]: Done 794 out of 794 | elapsed:    4.5s finished
# Filtering  at 41.67 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 794 out of 794 | elapsed:    4.3s finished
# Filtering  at 20.83 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 794 out of 794 | elapsed:    4.5s finished
# Filtering  at 10.42 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Reduction order for nice/marker/ContingentNegativeVariation/default: ['channels']
# Reduction order for nice/marker/TimeLockedTopography/p1: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3a: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3b: ['channels', 'times']
# ####Computing participant sub-040####
# Reading /media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/2_VS_patients/sub-040_icm-lg-egi-epo.fif ...
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
#     Read a total of 2 projection items:
#         Average EEG reference (1 x 236) active
#         Average EEG reference (1 x 256) active
#     Found the data of interest:
#         t =    -200.00 ...    1340.00 ms
#         0 CTF compensation matrices available
# ...
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/summary_se: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_msf: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef90: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef95: ['channels']
# Running KolmogorovComplexity
# Elapsed time 4.724677562713623 sec
# Reduction order for nice/marker/KolmogorovComplexity/default: ['channels']
# Filtering  at 83.33 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: divide by zero encountered in log
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: invalid value encountered in multiply
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# Filtering  at 41.67 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 20.83 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 10.42 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=2)]: Done 812 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=2)]: Done 816 out of 816 | elapsed:   22.4s finished
# Filtering  at 83.33 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 816 out of 816 | elapsed:    5.5s finished
# Filtering  at 41.67 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 816 out of 816 | elapsed:    7.5s finished
# Filtering  at 20.83 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=2)]: Done 816 out of 816 | elapsed:    5.0s finished
# Filtering  at 10.42 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Reduction order for nice/marker/ContingentNegativeVariation/default: ['channels']
# Reduction order for nice/marker/TimeLockedTopography/p1: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3a: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3b: ['channels', 'times']
# ####Computing participant sub-05_####
# Reading /media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/4_EMCS_patients/sub-05_icm-lg-egi-epo.fif ...
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
#     Read a total of 2 projection items:
#         Average EEG reference (1 x 247) active
#         Average EEG reference (1 x 256) active
#     Found the data of interest:
#         t =    -200.00 ...    1340.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 767 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 2)
# 2 projection items activated
# Subtracting Evoked from Epochs
# [done]
# Autodetected number of jobs 24
# Effective window size : 16.384 (s)
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   6 out of  24 | elapsed:   21.9s remaining:  1.1min
# [Parallel(n_jobs=24)]: Done  11 out of  24 | elapsed:   22.9s remaining:   27.0s
# [Parallel(n_jobs=24)]: Done  16 out of  24 | elapsed:   25.8s remaining:   12.9s
# [Parallel(n_jobs=24)]: Done  21 out of  24 | elapsed:   31.4s remaining:    4.5s
# [Parallel(n_jobs=24)]: Done  24 out of  24 | elapsed:   35.4s finished
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/gamma: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/summary_se: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_msf: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef90: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef95: ['channels']
# Running KolmogorovComplexity
# Elapsed time 4.356507778167725 sec
# Reduction order for nice/marker/KolmogorovComplexity/default: ['channels']
# Filtering  at 83.33 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: divide by zero encountered in log
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: invalid value encountered in multiply
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# Filtering  at 41.67 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 20.83 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 10.42 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  21 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=2)]: Done 458 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=2)]: Done 767 out of 767 | elapsed:   21.3s finished
# Filtering  at 83.33 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 158 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=2)]: Done 767 out of 767 | elapsed:    9.7s finished
# Filtering  at 41.67 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=2)]: Done 767 out of 767 | elapsed:    5.7s finished
# Filtering  at 20.83 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=2)]: Done 767 out of 767 | elapsed:    4.1s finished
# Filtering  at 10.42 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Reduction order for nice/marker/ContingentNegativeVariation/default: ['channels']
# Reduction order for nice/marker/TimeLockedTopography/p1: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3a: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3b: ['channels', 'times']
# ####Computing participant sub-03_####
# Reading /media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/DOC patients/LG/4_EMCS_patients/sub-03_icm-lg-egi-epo.fif ...
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
#     Read a total of 2 projection items:
#         Average EEG reference (1 x 249) active
#         Average EEG reference (1 x 256) active
#     Found the data of interest:
#         t =    -200.00 ...    1340.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 808 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 2)
# 2 projection items activated
# Subtracting Evoked from Epochs
# [done]
# Autodetected number of jobs 24
# Effective window size : 16.384 (s)
# [Parallel(n_jobs=24)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=24)]: Done   6 out of  24 | elapsed:   22.0s remaining:  1.1min
# [Parallel(n_jobs=24)]: Done  11 out of  24 | elapsed:   23.1s remaining:   27.3s
# [Parallel(n_jobs=24)]: Done  16 out of  24 | elapsed:   29.6s remaining:   14.8s
# [Parallel(n_jobs=24)]: Done  21 out of  24 | elapsed:   35.8s remaining:    5.1s
# [Parallel(n_jobs=24)]: Done  24 out of  24 | elapsed:   39.4s finished
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/alpha: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/delta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/gamma: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/theta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/beta: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensity/summary_se: ['frequency', 'channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_msf: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef90: ['channels']
# Reduction order for nice/marker/PowerSpectralDensitySummary/summary_sef95: ['channels']
# Running KolmogorovComplexity
# Elapsed time 4.623490333557129 sec
# Reduction order for nice/marker/KolmogorovComplexity/default: ['channels']
# Filtering  at 83.33 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: divide by zero encountered in log
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/nice-0.1.dev0-py3.7.egg/nice/algorithms/information_theory/permutation_entropy.py:75: RuntimeWarning: invalid value encountered in multiply
#   pe = np.nan_to_num(-np.nansum(count * np.log(count), axis=1))
# Filtering  at 41.67 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 20.83 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Filtering  at 10.42 Hz
# Performing symbolic transformation
# Reduction order for nice/marker/PermutationEntropy/default: ['channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  18 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=2)]: Done 804 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=2)]: Done 808 out of 808 | elapsed:   20.9s finished
# Filtering  at 83.33 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  74 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=2)]: Done 808 out of 808 | elapsed:    6.6s finished
# Filtering  at 41.67 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=2)]: Done 808 out of 808 | elapsed:    5.7s finished
# Filtering  at 20.83 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Autodetected number of jobs 2
# Computing CSD
# Using EGI 256 locations for CSD
# Using 2 jobs
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done 254 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=2)]: Done 808 out of 808 | elapsed:    4.3s finished
# Filtering  at 10.42 Hz
# Reduction order for nice/marker/SymbolicMutualInformation/default: ['channels_y', 'channels']
# Reduction order for nice/marker/ContingentNegativeVariation/default: ['channels']
# Reduction order for nice/marker/TimeLockedTopography/p1: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3a: ['channels', 'times']
# Reduction order for nice/marker/TimeLockedTopography/p3b: ['channels', 'times']
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3420: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nicolas.bruno/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
