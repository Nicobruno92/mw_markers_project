# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statannot import add_stat_annotation

# %%
epoch_type = 'evoked'
# epoch_type = 'pseudo-rs'

# %%
all_participants = ['VP07','VP08','VP09', 'VP10','VP11','VP12','VP13','VP14','VP18','VP19','VP20','VP22','VP23','VP24','VP25','VP26','VP27','VP28','VP29','VP30','VP31','VP32','VP33','VP35','VP36','VP37']
# participant = all_participants[1]

path = '/media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/MW_eeg_data/minmarker/' #icm-linux
# path = '/Users/nicobruno/ownCloud/MW_eeg_data/minmarker/' #nico-mac

# %%
SC_mean = pd.DataFrame()
PC_mean = pd.DataFrame()

df_markers = pd.DataFrame()

for i,v in enumerate(all_participants): 
    participant = v
    
    folder = path + participant +'/'
    
    df_ = pd.read_csv(folder+ participant + '_' + epoch_type + '_all_marker.csv', index_col = 0)
    df_['participant'] = i
    df_markers = df_markers.append(df_)

# %%
df_markers
# Out:
#         wSMI       p_e         k    b  b_n    g  g_n    t  t_n    d  d_n  a_n  \
# 0   0.110304  0.900582  0.761483 -inf  NaN -inf  NaN -inf  NaN -inf  NaN  NaN
# 1   0.106861  0.882868  0.759346 -inf  NaN -inf  NaN -inf  NaN -inf  NaN  NaN
# 2   0.110973  0.873343  0.754006 -inf  NaN -inf  NaN -inf  NaN -inf  NaN  NaN
# 3   0.115402  0.906897  0.760842 -inf  NaN -inf  NaN -inf  NaN -inf  NaN  NaN
# 0   0.104991  0.872812  0.735954 -inf  NaN -inf  NaN -inf  NaN -inf  NaN  NaN
# ..       ...       ...       ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 10  0.110014  0.868771  0.747559 -inf  NaN -inf  NaN -inf  NaN -inf  NaN  NaN
# 11  0.103649  0.914974  0.747334 -inf  NaN -inf  NaN -inf  NaN -inf  NaN  NaN
# 12  0.111862  0.913750  0.721967 -inf  NaN -inf  NaN -inf  NaN -inf  NaN  NaN
# 13  0.100811  0.925550  0.744416 -inf  NaN -inf  NaN -inf  NaN -inf  NaN  NaN
# 14  0.112345  0.939523  0.749579 -inf  NaN -inf  NaN -inf  NaN -inf  NaN  NaN
#
#       a probe     mind  participant
# 0  -inf    SC      dMW            0
# 1  -inf    SC      dMW            0
# 2  -inf    SC      dMW            0
# 3  -inf    SC      dMW            0
# 0  -inf    PC      dMW            0
# ..  ...   ...      ...          ...
# 10 -inf    PC  on-task           25
# 11 -inf    PC  on-task           25
# 12 -inf    PC  on-task           25
# 13 -inf    PC  on-task           25
# 14 -inf    PC  on-task           25
#
# [2880 rows x 16 columns]

# %%
df_markers.groupby(['probe', 'mind', 'participant']).agg('mean')
# Out:
#                                wSMI       p_e         k    b  b_n    g  g_n  \
# probe mind    participant
# PC    dMW     0            0.110898  0.890233  0.755186 -inf  NaN -inf  NaN
#               3            0.118349  0.949993  0.751963 -inf  NaN -inf  NaN
#               4            0.104905  0.888775  0.735951 -inf  NaN -inf  NaN
#               6            0.108251  0.908396  0.749904 -inf  NaN -inf  NaN
#               7            0.108105  0.923655  0.763379 -inf  NaN -inf  NaN
#               8            0.104270  0.864519  0.735858 -inf  NaN -inf  NaN
#               9            0.110060  0.901501  0.759192 -inf  NaN -inf  NaN
#               11           0.096448  0.854602  0.745440 -inf  NaN -inf  NaN
#               12           0.104819  0.923222  0.752918 -inf  NaN -inf  NaN
#               13           0.112333  0.925519  0.746003 -inf  NaN -inf  NaN
#               14           0.104416  0.878667  0.749158 -inf  NaN -inf  NaN
#       on-task 0            0.111546  0.897810  0.754315 -inf  NaN -inf  NaN
#               1            0.113913  0.913556  0.751895 -inf  NaN -inf  NaN
#               2            0.108746  0.898972  0.753101 -inf  NaN -inf  NaN
#               3            0.115210  0.944608  0.751699 -inf  NaN -inf  NaN
#               4            0.105775  0.898660  0.736341 -inf  NaN -inf  NaN
#               5            0.120674  0.932629  0.733876 -inf  NaN -inf  NaN
#               6            0.103609  0.896041  0.753709 -inf  NaN -inf  NaN
#               7            0.107454  0.908499  0.759624 -inf  NaN -inf  NaN
#               8            0.100261  0.839098  0.740663 -inf  NaN -inf  NaN
#               10           0.108611  0.873287  0.762157 -inf  NaN -inf  NaN
#               11           0.097263  0.855039  0.746509 -inf  NaN -inf  NaN
#               13           0.110810  0.930195  0.748277 -inf  NaN -inf  NaN
#               14           0.108413  0.903716  0.750219 -inf  NaN -inf  NaN
#       sMW     0            0.106926  0.889674  0.748024 -inf  NaN -inf  NaN
#               2            0.105877  0.903426  0.754750 -inf  NaN -inf  NaN
#               3            0.110172  0.936984  0.756154 -inf  NaN -inf  NaN
#               4            0.109912  0.913746  0.747620 -inf  NaN -inf  NaN
#               6            0.107534  0.892726  0.763651 -inf  NaN -inf  NaN
#               9            0.109497  0.906138  0.759208 -inf  NaN -inf  NaN
#               10           0.107377  0.898253  0.766250 -inf  NaN -inf  NaN
#               11           0.100648  0.859437  0.758441 -inf  NaN -inf  NaN
#               12           0.112187  0.912408  0.756089 -inf  NaN -inf  NaN
#               13           0.116857  0.930254  0.746397 -inf  NaN -inf  NaN
# SC    dMW     0            0.110885  0.890923  0.758919 -inf  NaN -inf  NaN
#               1            0.112516  0.913342  0.750166 -inf  NaN -inf  NaN
#               2            0.109165  0.900838  0.751874 -inf  NaN -inf  NaN
#               5            0.117853  0.936852  0.734701 -inf  NaN -inf  NaN
#               6            0.107991  0.890376  0.761715 -inf  NaN -inf  NaN
#               7            0.109312  0.916163  0.758891 -inf  NaN -inf  NaN
#               8            0.102854  0.856057  0.733029 -inf  NaN -inf  NaN
#               9            0.109288  0.896205  0.759462 -inf  NaN -inf  NaN
#               10           0.108205  0.877602  0.773627 -inf  NaN -inf  NaN
#               12           0.110338  0.913276  0.753445 -inf  NaN -inf  NaN
#               13           0.111290  0.901544  0.744544 -inf  NaN -inf  NaN
#               14           0.108183  0.904791  0.746245 -inf  NaN -inf  NaN
#       sMW     1            0.113225  0.921719  0.748361 -inf  NaN -inf  NaN
#               2            0.109112  0.907906  0.749501 -inf  NaN -inf  NaN
#               5            0.123227  0.932830  0.738573 -inf  NaN -inf  NaN
#               6            0.106787  0.889182  0.760107 -inf  NaN -inf  NaN
#               7            0.108003  0.909364  0.759409 -inf  NaN -inf  NaN
#               8            0.104110  0.854546  0.733644 -inf  NaN -inf  NaN
#               9            0.108496  0.896051  0.761437 -inf  NaN -inf  NaN
#               10           0.109461  0.884911  0.771129 -inf  NaN -inf  NaN
#               12           0.111710  0.915696  0.753702 -inf  NaN -inf  NaN
#               13           0.112980  0.917010  0.744200 -inf  NaN -inf  NaN
#               14           0.110326  0.895438  0.750066 -inf  NaN -inf  NaN
#
#                              t  t_n    d  d_n  a_n    a
# probe mind    participant
# PC    dMW     0           -inf  NaN -inf  NaN  NaN -inf
#               3           -inf  NaN -inf  NaN  NaN -inf
#               4           -inf  NaN -inf  NaN  NaN -inf
#               6           -inf  NaN -inf  NaN  NaN -inf
#               7           -inf  NaN -inf  NaN  NaN -inf
#               8           -inf  NaN -inf  NaN  NaN -inf
#               9           -inf  NaN -inf  NaN  NaN -inf
#               11          -inf  NaN -inf  NaN  NaN -inf
#               12          -inf  NaN -inf  NaN  NaN -inf
#               13          -inf  NaN -inf  NaN  NaN -inf
#               14          -inf  NaN -inf  NaN  NaN -inf
#       on-task 0           -inf  NaN -inf  NaN  NaN -inf
#               1           -inf  NaN -inf  NaN  NaN -inf
#               2           -inf  NaN -inf  NaN  NaN -inf
#               3           -inf  NaN -inf  NaN  NaN -inf
#               4           -inf  NaN -inf  NaN  NaN -inf
#               5           -inf  NaN -inf  NaN  NaN -inf
#               6           -inf  NaN -inf  NaN  NaN -inf
#               7           -inf  NaN -inf  NaN  NaN -inf
#               8           -inf  NaN -inf  NaN  NaN -inf
#               10          -inf  NaN -inf  NaN  NaN -inf
#               11          -inf  NaN -inf  NaN  NaN -inf
#               13          -inf  NaN -inf  NaN  NaN -inf
#               14          -inf  NaN -inf  NaN  NaN -inf
#       sMW     0           -inf  NaN -inf  NaN  NaN -inf
#               2           -inf  NaN -inf  NaN  NaN -inf
#               3           -inf  NaN -inf  NaN  NaN -inf
#               4           -inf  NaN -inf  NaN  NaN -inf
#               6           -inf  NaN -inf  NaN  NaN -inf
#               9           -inf  NaN -inf  NaN  NaN -inf
#               10          -inf  NaN -inf  NaN  NaN -inf
#               11          -inf  NaN -inf  NaN  NaN -inf
#               12          -inf  NaN -inf  NaN  NaN -inf
#               13          -inf  NaN -inf  NaN  NaN -inf
# SC    dMW     0           -inf  NaN -inf  NaN  NaN -inf
#               1           -inf  NaN -inf  NaN  NaN -inf
#               2           -inf  NaN -inf  NaN  NaN -inf
#               5           -inf  NaN -inf  NaN  NaN -inf
#               6           -inf  NaN -inf  NaN  NaN -inf
#               7           -inf  NaN -inf  NaN  NaN -inf
#               8           -inf  NaN -inf  NaN  NaN -inf
#               9           -inf  NaN -inf  NaN  NaN -inf
#               10          -inf  NaN -inf  NaN  NaN -inf
#               12          -inf  NaN -inf  NaN  NaN -inf
#               13          -inf  NaN -inf  NaN  NaN -inf
#               14          -inf  NaN -inf  NaN  NaN -inf
#       sMW     1           -inf  NaN -inf  NaN  NaN -inf
#               2           -inf  NaN -inf  NaN  NaN -inf
#               5           -inf  NaN -inf  NaN  NaN -inf
#               6           -inf  NaN -inf  NaN  NaN -inf
#               7           -inf  NaN -inf  NaN  NaN -inf
#               8           -inf  NaN -inf  NaN  NaN -inf
#               9           -inf  NaN -inf  NaN  NaN -inf
#               10          -inf  NaN -inf  NaN  NaN -inf
#               12          -inf  NaN -inf  NaN  NaN -inf
#               13          -inf  NaN -inf  NaN  NaN -inf
#               14          -inf  NaN -inf  NaN  NaN -inf

# %%
PC_mean['probe'] = 'PC'
SC_mean['probe'] = 'SC'
df_probe = PC_mean.append(SC_mean)
df_probe['markers'] = df_probe.index
df_probe.rename(columns={0:'val'},inplace=True)

# %%
g = sns.FacetGrid(df_probe, col='markers', sharey = False)
g.map_dataframe(sns.boxplot, x='probe', y = 'val')
plt.show()
g = sns.FacetGrid(df_probe, col='markers', sharey = False)
ax = g.map_dataframe(sns.violinplot, x='probe', y = 'val')

plt.show()

# %%
spectral = df_probe[df_probe['markers'].isin(["d_n", 't_n', 'a_n', 'b_n', 'g_n'])]

ax = sns.boxplot(x="markers", y="val", hue='probe', data=spectral);

test_pairs = [(('d_n', 'PC'), ('d_n', 'SC')), (('t_n', 'PC'), ('t_n', 'SC')), 
              (('a_n', 'PC'), ('a_n', 'SC')), (('b_n', 'PC'), ('b_n', 'SC')), 
              (('g_n', 'PC'), ('g_n', 'SC'))]

add_stat_annotation(ax, data=df_probe, x="markers", y="val", hue='probe', 
                                   box_pairs=test_pairs,
                                   test='Wilcoxon', text_format='star',
                                   loc='outside', verbose=2)

plt.show()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Using zero_method  wilcox
# d_n_PC v.s. d_n_SC: Wilcoxon test (paired samples) with Bonferroni correction, P_val=1.000e+00 stat=1.690e+02
# Using zero_method  wilcox
# a_n_PC v.s. a_n_SC: Wilcoxon test (paired samples) with Bonferroni correction, P_val=1.000e+00 stat=1.740e+02
# Using zero_method  wilcox
# t_n_PC v.s. t_n_SC: Wilcoxon test (paired samples) with Bonferroni correction, P_val=1.000e+00 stat=1.460e+02
# Using zero_method  wilcox
# b_n_PC v.s. b_n_SC: Wilcoxon test (paired samples) with Bonferroni correction, P_val=1.000e+00 stat=1.270e+02
# Using zero_method  wilcox
# g_n_PC v.s. g_n_SC: Wilcoxon test (paired samples) with Bonferroni correction, P_val=1.000e+00 stat=1.730e+02

# %%
markers = ['k', 'p_e', 'wSMI']

for m in markers:
    df_ = df_probe[df_probe['markers'] == m]
    
    ax = sns.boxplot(x="markers", y="val", hue='probe', data=df_)
    
    add_stat_annotation(ax, data=df_, x="markers", y="val", hue='probe', 
                                   box_pairs=[((m, 'PC'), (m, 'SC'))],
                                   test='Wilcoxon', text_format='star',
                                   loc='outside', verbose=2)
    plt.show()
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Using zero_method  wilcox
# k_PC v.s. k_SC: Wilcoxon test (paired samples) with Bonferroni correction, P_val=1.909e-01 stat=1.240e+02
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Using zero_method  wilcox
# p_e_PC v.s. p_e_SC: Wilcoxon test (paired samples) with Bonferroni correction, P_val=3.539e-01 stat=1.390e+02
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Using zero_method  wilcox
# wSMI_PC v.s. wSMI_SC: Wilcoxon test (paired samples) with Bonferroni correction, P_val=5.506e-01 stat=1.520e+02
