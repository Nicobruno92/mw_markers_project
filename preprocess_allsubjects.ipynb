# %%
# %matplotlib qt
import mne
import utils
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# from cleaner.report import create_ica_report 
# from cleaner import reject

# from nice_ext.algorithms.adaptive import _adaptive_egi

from autoreject import AutoReject, get_rejection_threshold

# %%
# epoch_type = 'evoked'
epoch_type = 'pseudo-rs'

all_participants = ['VP07','VP08','VP09', 'VP10','VP11','VP12','VP13','VP14','VP18','VP19','VP20','VP22','VP23','VP24','VP25','VP26','VP27','VP28','VP29','VP30','VP31','VP32','VP33','VP35','VP36','VP37']
participant = all_participants[9]


# path = '/media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/MW_eeg_data/minmarker/' #icm-linux
path = '/Users/nicobruno/ownCloud/MW_eeg_data/minmarker/' #nico-mac

# %% [raw]
# for i in all_participants[:]:
#     participant = i
#
#
#     raw = mne.io.read_raw_eeglab(folder+file, preload = True, eog = ['EXG3','EXG4','EXG5','EXG6',],verbose = False)
#
#     # raw.set_channel_types({'EXG3': 'eog', 'EXG4': 'eog', 'EXG5': 'eog','EXG6': 'eog'})
#
#
#     raw = raw.pick_types(eeg = True, eog = True, exclude = ['EXG1', 'EXG2', 'EXG7', 'EXG8'])
#
#     raw = raw.set_montage('biosemi64') # ask if biosemi or 10-20 montage
#
# #     print(raw.info)
#
#     raw_downsampled = raw.copy().resample(sfreq=250)
#
#     hpass = 0.5
#     lpass = 45
#
#     raw_filtered = raw_downsampled.copy().filter(l_freq=hpass, h_freq=lpass)
#
#     raw_filtered.plot()
#
#     ### Save filtered data
#     raw_filtered.save(folder + participant + 'filt_raw.fif', overwrite = True)

# %%
rejection = []

for i in all_participants:
    participant = i

    folder = path + participant +'/'
    raw_filtered = mne.io.read_raw(folder + participant + 'filt_raw.fif', preload = True)

    events, event_dict = utils.make_correct_labels(raw_filtered)

    # Create Epochs <a name="epochs"></a>

    epochs = utils.create_epochs(epoch_type = epoch_type, raw = raw_filtered, events =  events, event_id = event_dict)
    epochs.save(folder +  participant + '_' + epoch_type + '_' +  '_epo.fif', overwrite = True)

    # Reject Bad Epochs and Channels <a name="reject"></a>

    ar = AutoReject(thresh_method = 'random_search', random_state=42)
    epochs_clean = ar.fit_transform(epochs)  
    reject = get_rejection_threshold(epochs)  

    epochs_clean.save(folder +  participant + '_' + epoch_type + '_' +  'ar_clean_epo.fif', overwrite = True)
    
    rejection.append((len(epochs) - len(epochs_clean)) *100/len(epochs))
    
print(rejection)
# Out:
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP07/VP07filt_raw.fif...
#     Range : 0 ... 1047329 =      0.000 ...  4189.316 secs
# Ready.
# Reading 0 ... 1047329  =      0.000 ...  4189.316 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '12', '161', '166', '167', '169', '17', '176', '180', '190', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '251', '252', '253', '255', '3', '4', '5', '6', '62', '68', '7', '74', '80', '86', '9', '92', '98', '99']
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 2 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:  10%|▉         | 6/62 [00:00<00:00, 57.39it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 62/62 [00:00<00:00, 77.66it/s]
# Computing thresholds ...: 100%|██████████| 62/62 [00:11<00:00,  5.45it/s]
#
#
# Repairing epochs:   0%|          | 0/130 [00:00<?, ?it/s]
#
# Repairing epochs:  30%|███       | 39/130 [00:00<00:00, 382.14it/s]
#
# Repairing epochs:  60%|██████    | 78/130 [00:00<00:00, 364.79it/s]
#
# Repairing epochs: 100%|██████████| 130/130 [00:00<00:00, 361.27it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/130 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 11/130 [00:00<00:01, 104.66it/s]
#
# Repairing epochs:  17%|█▋        | 22/130 [00:00<00:01, 104.45it/s]
#
# Repairing epochs:  25%|██▌       | 33/130 [00:00<00:00, 99.09it/s]
#
# Repairing epochs:  33%|███▎      | 43/130 [00:00<00:00, 99.35it/s]
#
# Repairing epochs:  41%|████      | 53/130 [00:00<00:00, 87.30it/s]
#
# Repairing epochs:  48%|████▊     | 62/130 [00:00<00:00, 81.89it/s]
#
# Repairing epochs:  55%|█████▍    | 71/130 [00:00<00:00, 81.24it/s]
#
# Repairing epochs:  64%|██████▍   | 83/130 [00:00<00:00, 89.97it/s]
#
# Repairing epochs:  73%|███████▎  | 95/130 [00:01<00:00, 97.61it/s]
#
# Repairing epochs:  82%|████████▏ | 106/130 [00:01<00:00, 100.17it/s]
#
# Repairing epochs:  92%|█████████▏| 119/130 [00:01<00:00, 107.24it/s]
#
# Repairing epochs: 100%|██████████| 130/130 [00:01<00:00, 97.73it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  8.74it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:00,  8.90it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:00,  8.66it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  8.85it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  8.94it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  9.00it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:00<00:00,  8.97it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00,  9.00it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  9.05it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  8.97it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:02<00:05,  2.57s/it]
#
# Repairing epochs:   0%|          | 0/130 [00:00<?, ?it/s]
#
# Repairing epochs:  10%|█         | 13/130 [00:00<00:00, 121.72it/s]
#
# Repairing epochs:  21%|██        | 27/130 [00:00<00:00, 127.09it/s]
#
# Repairing epochs:  31%|███       | 40/130 [00:00<00:00, 121.11it/s]
#
# Repairing epochs:  41%|████      | 53/130 [00:00<00:00, 121.93it/s]
#
# Repairing epochs:  51%|█████     | 66/130 [00:00<00:00, 116.38it/s]
#
# Repairing epochs:  60%|██████    | 78/130 [00:00<00:00, 115.26it/s]
#
# Repairing epochs:  70%|███████   | 91/130 [00:00<00:00, 117.80it/s]
#
# Repairing epochs:  80%|████████  | 104/130 [00:00<00:00, 121.34it/s]
#
# Repairing epochs:  90%|█████████ | 117/130 [00:00<00:00, 122.01it/s]
#
# Repairing epochs: 100%|██████████| 130/130 [00:01<00:00, 120.01it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:00,  9.24it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:00,  9.07it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:00,  9.04it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  9.01it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  8.63it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  8.61it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:00<00:00,  8.77it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00,  8.91it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  8.94it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  8.88it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:04<00:02,  2.41s/it]
#
# Repairing epochs:   0%|          | 0/130 [00:00<?, ?it/s]
#
# Repairing epochs:  10%|█         | 13/130 [00:00<00:00, 125.06it/s]
#
# Repairing epochs:  21%|██        | 27/130 [00:00<00:00, 127.71it/s]
#
# Repairing epochs:  31%|███       | 40/130 [00:00<00:00, 122.01it/s]
#
# Repairing epochs:  41%|████      | 53/130 [00:00<00:00, 118.96it/s]
#
# Repairing epochs:  50%|█████     | 65/130 [00:00<00:00, 117.43it/s]
#
# Repairing epochs:  59%|█████▉    | 77/130 [00:00<00:00, 117.01it/s]
#
# Repairing epochs:  70%|███████   | 91/130 [00:00<00:00, 122.61it/s]
#
# Repairing epochs:  80%|████████  | 104/130 [00:00<00:00, 124.86it/s]
#
# Repairing epochs:  90%|█████████ | 117/130 [00:00<00:00, 122.02it/s]
#
# Repairing epochs: 100%|██████████| 130/130 [00:01<00:00, 120.03it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:00, 18.85it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00, 17.20it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00, 16.61it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00, 16.51it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:00<00:00, 16.74it/s]
#
# n_interp: 100%|██████████| 3/3 [00:06<00:00,  2.20s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 2 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
#
#
# Repairing epochs:   0%|          | 0/130 [00:00<?, ?it/s]
#
# Repairing epochs:   9%|▉         | 12/130 [00:00<00:01, 112.51it/s]
# Estimated consensus=0.30 and n_interpolate=4
# Repairing epochs:  18%|█▊        | 24/130 [00:00<00:00, 113.13it/s]
#
# Repairing epochs:  28%|██▊       | 36/130 [00:00<00:00, 103.31it/s]
#
# Repairing epochs:  36%|███▌      | 47/130 [00:00<00:00, 105.38it/s]
#
# Repairing epochs:  45%|████▍     | 58/130 [00:00<00:00, 104.25it/s]
#
# Repairing epochs:  53%|█████▎    | 69/130 [00:00<00:00, 102.88it/s]
#
# Repairing epochs:  62%|██████▏   | 80/130 [00:00<00:00, 104.04it/s]
#
# Repairing epochs:  71%|███████   | 92/130 [00:00<00:00, 103.51it/s]
#
# Repairing epochs:  79%|███████▉  | 103/130 [00:01<00:00, 90.12it/s]
#
# Repairing epochs:  87%|████████▋ | 113/130 [00:01<00:00, 83.26it/s]
#
# Repairing epochs: 100%|██████████| 130/130 [00:01<00:00, 90.26it/s]
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP08/VP08filt_raw.fif...
#     Range : 0 ... 963688 =      0.000 ...  3854.752 secs
# Ready.
# Reading 0 ... 963688  =      0.000 ...  3854.752 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '111', '12', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '17', '171', '173', '181', '191', '192', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '251', '252', '253', '255', '3', '4', '5', '6', '7', '74', '80', '86', '9', '92', '99']
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 4 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:   7%|▋         | 4/60 [00:00<00:01, 39.24it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 60/60 [00:01<00:00, 43.09it/s]
# Computing thresholds ...: 100%|██████████| 60/60 [00:21<00:00,  2.80it/s]
#
#
# Repairing epochs:   0%|          | 0/443 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 36/443 [00:00<00:01, 359.12it/s]
#
# Repairing epochs:  17%|█▋        | 74/443 [00:00<00:00, 369.13it/s]
#
# Repairing epochs:  25%|██▌       | 111/443 [00:00<00:00, 363.20it/s]
#
# Repairing epochs:  33%|███▎      | 148/443 [00:00<00:00, 360.48it/s]
#
# Repairing epochs:  42%|████▏     | 185/443 [00:00<00:00, 361.19it/s]
#
# Repairing epochs:  50%|█████     | 222/443 [00:00<00:00, 346.37it/s]
#
# Repairing epochs:  58%|█████▊    | 258/443 [00:00<00:00, 348.36it/s]
#
# Repairing epochs:  66%|██████▌   | 293/443 [00:00<00:00, 307.00it/s]
#
# Repairing epochs:  73%|███████▎  | 325/443 [00:01<00:00, 264.12it/s]
#
# Repairing epochs:  81%|████████  | 357/443 [00:01<00:00, 276.85it/s]
#
# Repairing epochs:  87%|████████▋ | 386/443 [00:01<00:00, 266.80it/s]
#
# Repairing epochs: 100%|██████████| 443/443 [00:01<00:00, 303.73it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/443 [00:00<?, ?it/s]
#
# Repairing epochs:   2%|▏         | 10/443 [00:00<00:04, 98.11it/s]
#
# Repairing epochs:   5%|▍         | 20/443 [00:00<00:05, 75.38it/s]
#
# Repairing epochs:   6%|▋         | 28/443 [00:00<00:07, 52.94it/s]
#
# Repairing epochs:   8%|▊         | 37/443 [00:00<00:06, 62.22it/s]
#
# Repairing epochs:  11%|█         | 49/443 [00:00<00:05, 76.55it/s]
#
# Repairing epochs:  14%|█▎        | 60/443 [00:00<00:04, 84.34it/s]
#
# Repairing epochs:  16%|█▌        | 71/443 [00:00<00:04, 90.85it/s]
#
# Repairing epochs:  18%|█▊        | 81/443 [00:01<00:04, 90.40it/s]
#
# Repairing epochs:  21%|██        | 93/443 [00:01<00:03, 97.42it/s]
#
# Repairing epochs:  24%|██▎       | 105/443 [00:01<00:03, 102.40it/s]
#
# Repairing epochs:  26%|██▋       | 117/443 [00:01<00:03, 105.66it/s]
#
# Repairing epochs:  29%|██▉       | 128/443 [00:01<00:02, 106.86it/s]
#
# Repairing epochs:  32%|███▏      | 140/443 [00:01<00:02, 108.72it/s]
#
# Repairing epochs:  34%|███▍      | 152/443 [00:01<00:02, 110.98it/s]
#
# Repairing epochs:  37%|███▋      | 164/443 [00:01<00:02, 112.40it/s]
#
# Repairing epochs:  40%|███▉      | 176/443 [00:01<00:02, 111.31it/s]
#
# Repairing epochs:  42%|████▏     | 188/443 [00:01<00:02, 109.36it/s]
#
# Repairing epochs:  45%|████▌     | 200/443 [00:02<00:02, 110.41it/s]
#
# Repairing epochs:  48%|████▊     | 212/443 [00:02<00:02, 108.46it/s]
#
# Repairing epochs:  50%|█████     | 223/443 [00:02<00:02, 99.82it/s]
#
# Repairing epochs:  53%|█████▎    | 234/443 [00:02<00:02, 99.85it/s]
#
# Repairing epochs:  55%|█████▌    | 245/443 [00:02<00:02, 91.28it/s]
#
# Repairing epochs:  58%|█████▊    | 255/443 [00:02<00:02, 91.21it/s]
#
# Repairing epochs:  60%|█████▉    | 265/443 [00:02<00:01, 91.91it/s]
#
# Repairing epochs:  62%|██████▏   | 275/443 [00:02<00:01, 84.96it/s]
#
# Repairing epochs:  64%|██████▍   | 284/443 [00:03<00:01, 83.83it/s]
#
# Repairing epochs:  66%|██████▋   | 294/443 [00:03<00:01, 86.07it/s]
#
# Repairing epochs:  69%|██████▊   | 304/443 [00:03<00:01, 88.76it/s]
#
# Repairing epochs:  71%|███████   | 314/443 [00:03<00:01, 91.26it/s]
#
# Repairing epochs:  74%|███████▎  | 326/443 [00:03<00:01, 95.63it/s]
#
# Repairing epochs:  76%|███████▌  | 336/443 [00:03<00:01, 91.48it/s]
#
# Repairing epochs:  78%|███████▊  | 346/443 [00:03<00:01, 84.93it/s]
#
# Repairing epochs:  80%|████████  | 355/443 [00:04<00:01, 49.40it/s]
#
# Repairing epochs:  83%|████████▎ | 367/443 [00:04<00:01, 61.17it/s]
#
# Repairing epochs:  85%|████████▌ | 377/443 [00:04<00:00, 68.41it/s]
#
# Repairing epochs:  87%|████████▋ | 387/443 [00:04<00:00, 74.30it/s]
#
# Repairing epochs:  90%|████████▉ | 397/443 [00:04<00:00, 79.79it/s]
#
# Repairing epochs:  92%|█████████▏| 407/443 [00:04<00:00, 84.17it/s]
#
# Repairing epochs:  95%|█████████▍| 419/443 [00:04<00:00, 92.54it/s]
#
# Repairing epochs:  97%|█████████▋| 431/443 [00:04<00:00, 99.77it/s]
#
# Repairing epochs: 100%|██████████| 443/443 [00:04<00:00, 89.47it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:04,  1.91it/s]
#
#
# Fold:  20%|██        | 2/10 [00:01<00:04,  2.00it/s]
#
#
# Fold:  30%|███       | 3/10 [00:01<00:03,  2.03it/s]
#
#
# Fold:  40%|████      | 4/10 [00:01<00:02,  2.03it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:02<00:02,  2.04it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:02<00:01,  2.06it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:03<00:01,  2.07it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:03<00:00,  2.07it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:04<00:00,  2.07it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:04<00:00,  2.06it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:10<00:20, 10.42s/it]
#
# Repairing epochs:   0%|          | 0/443 [00:00<?, ?it/s]
#
# Repairing epochs:   2%|▏         | 11/443 [00:00<00:03, 109.91it/s]
#
# Repairing epochs:   5%|▌         | 23/443 [00:00<00:03, 113.34it/s]
#
# Repairing epochs:   8%|▊         | 35/443 [00:00<00:03, 115.45it/s]
#
# Repairing epochs:  11%|█         | 48/443 [00:00<00:03, 117.46it/s]
#
# Repairing epochs:  14%|█▎        | 60/443 [00:00<00:03, 115.46it/s]
#
# Repairing epochs:  16%|█▋        | 72/443 [00:00<00:03, 113.85it/s]
#
# Repairing epochs:  19%|█▉        | 85/443 [00:00<00:03, 116.28it/s]
#
# Repairing epochs:  22%|██▏       | 97/443 [00:00<00:02, 115.47it/s]
#
# Repairing epochs:  25%|██▍       | 109/443 [00:00<00:02, 114.92it/s]
#
# Repairing epochs:  27%|██▋       | 121/443 [00:01<00:02, 113.88it/s]
#
# Repairing epochs:  30%|███       | 133/443 [00:01<00:02, 112.73it/s]
#
# Repairing epochs:  33%|███▎      | 145/443 [00:01<00:02, 113.02it/s]
#
# Repairing epochs:  35%|███▌      | 157/443 [00:01<00:02, 112.73it/s]
#
# Repairing epochs:  38%|███▊      | 169/443 [00:01<00:02, 112.60it/s]
#
# Repairing epochs:  41%|████      | 181/443 [00:01<00:02, 113.05it/s]
#
# Repairing epochs:  44%|████▎     | 193/443 [00:01<00:02, 112.23it/s]
#
# Repairing epochs:  46%|████▋     | 205/443 [00:01<00:02, 112.45it/s]
#
# Repairing epochs:  49%|████▉     | 217/443 [00:01<00:02, 107.55it/s]
#
# Repairing epochs:  51%|█████▏    | 228/443 [00:02<00:02, 106.84it/s]
#
# Repairing epochs:  54%|█████▍    | 240/443 [00:02<00:01, 107.65it/s]
#
# Repairing epochs:  57%|█████▋    | 251/443 [00:02<00:01, 108.22it/s]
#
# Repairing epochs:  60%|█████▉    | 264/443 [00:02<00:01, 111.83it/s]
#
# Repairing epochs:  62%|██████▏   | 276/443 [00:02<00:01, 112.62it/s]
#
# Repairing epochs:  65%|██████▌   | 288/443 [00:02<00:01, 113.00it/s]
#
# Repairing epochs:  68%|██████▊   | 300/443 [00:02<00:01, 113.09it/s]
#
# Repairing epochs:  70%|███████   | 312/443 [00:02<00:01, 113.09it/s]
#
# Repairing epochs:  73%|███████▎  | 325/443 [00:02<00:01, 115.79it/s]
#
# Repairing epochs:  76%|███████▋  | 338/443 [00:02<00:00, 116.92it/s]
#
# Repairing epochs:  79%|███████▉  | 350/443 [00:03<00:00, 115.43it/s]
#
# Repairing epochs:  82%|████████▏ | 362/443 [00:03<00:00, 116.16it/s]
#
# Repairing epochs:  84%|████████▍ | 374/443 [00:03<00:00, 114.43it/s]
#
# Repairing epochs:  87%|████████▋ | 386/443 [00:03<00:00, 114.07it/s]
#
# Repairing epochs:  90%|████████▉ | 398/443 [00:03<00:00, 107.97it/s]
#
# Repairing epochs:  92%|█████████▏| 409/443 [00:03<00:00, 105.67it/s]
#
# Repairing epochs:  95%|█████████▍| 420/443 [00:03<00:00, 105.21it/s]
#
# Repairing epochs:  98%|█████████▊| 432/443 [00:03<00:00, 108.40it/s]
#
# Repairing epochs: 100%|██████████| 443/443 [00:03<00:00, 111.90it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:04,  2.16it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:03,  2.10it/s]
#
#
# Fold:  30%|███       | 3/10 [00:01<00:03,  2.12it/s]
#
#
# Fold:  40%|████      | 4/10 [00:01<00:02,  2.11it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:02<00:02,  2.11it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:02<00:01,  2.10it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:03<00:01,  2.07it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:03<00:00,  2.07it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:04<00:00,  1.93it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:05<00:00,  2.00it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:19<00:09,  9.80s/it]
#
# Repairing epochs:   0%|          | 0/443 [00:00<?, ?it/s]
#
# Repairing epochs:   2%|▏         | 10/443 [00:00<00:04, 98.22it/s]
#
# Repairing epochs:   5%|▌         | 23/443 [00:00<00:03, 113.35it/s]
#
# Repairing epochs:   8%|▊         | 36/443 [00:00<00:03, 116.78it/s]
#
# Repairing epochs:  11%|█         | 49/443 [00:00<00:03, 119.47it/s]
#
# Repairing epochs:  14%|█▍        | 61/443 [00:00<00:03, 119.32it/s]
#
# Repairing epochs:  16%|█▋        | 73/443 [00:00<00:03, 119.23it/s]
#
# Repairing epochs:  19%|█▉        | 85/443 [00:00<00:03, 116.06it/s]
#
# Repairing epochs:  22%|██▏       | 97/443 [00:00<00:03, 114.51it/s]
#
# Repairing epochs:  25%|██▍       | 109/443 [00:00<00:02, 115.56it/s]
#
# Repairing epochs:  27%|██▋       | 121/443 [00:01<00:02, 116.31it/s]
#
# Repairing epochs:  30%|███       | 134/443 [00:01<00:02, 117.73it/s]
#
# Repairing epochs:  33%|███▎      | 146/443 [00:01<00:02, 118.33it/s]
#
# Repairing epochs:  36%|███▌      | 158/443 [00:01<00:02, 117.34it/s]
#
# Repairing epochs:  38%|███▊      | 170/443 [00:01<00:02, 118.05it/s]
#
# Repairing epochs:  41%|████      | 182/443 [00:01<00:02, 118.34it/s]
#
# Repairing epochs:  44%|████▍     | 195/443 [00:01<00:02, 119.31it/s]
#
# Repairing epochs:  47%|████▋     | 207/443 [00:01<00:02, 117.30it/s]
#
# Repairing epochs:  49%|████▉     | 219/443 [00:01<00:02, 109.04it/s]
#
# Repairing epochs:  52%|█████▏    | 231/443 [00:02<00:02, 97.41it/s]
#
# Repairing epochs:  55%|█████▍    | 242/443 [00:02<00:02, 86.24it/s]
#
# Repairing epochs:  57%|█████▋    | 252/443 [00:02<00:02, 88.10it/s]
#
# Repairing epochs:  60%|█████▉    | 264/443 [00:02<00:01, 95.24it/s]
#
# Repairing epochs:  62%|██████▏   | 276/443 [00:02<00:01, 100.41it/s]
#
# Repairing epochs:  65%|██████▍   | 287/443 [00:02<00:01, 99.33it/s]
#
# Repairing epochs:  67%|██████▋   | 298/443 [00:02<00:01, 90.36it/s]
#
# Repairing epochs:  70%|██████▉   | 308/443 [00:02<00:01, 83.19it/s]
#
# Repairing epochs:  72%|███████▏  | 317/443 [00:03<00:01, 78.93it/s]
#
# Repairing epochs:  74%|███████▍  | 330/443 [00:03<00:01, 89.78it/s]
#
# Repairing epochs:  77%|███████▋  | 342/443 [00:03<00:01, 97.51it/s]
#
# Repairing epochs:  80%|███████▉  | 354/443 [00:03<00:00, 102.02it/s]
#
# Repairing epochs:  82%|████████▏ | 365/443 [00:03<00:00, 102.35it/s]
#
# Repairing epochs:  85%|████████▌ | 377/443 [00:03<00:00, 106.04it/s]
#
# Repairing epochs:  88%|████████▊ | 388/443 [00:03<00:00, 106.51it/s]
#
# Repairing epochs:  90%|█████████ | 399/443 [00:03<00:00, 104.98it/s]
#
# Repairing epochs:  93%|█████████▎| 410/443 [00:03<00:00, 105.63it/s]
#
# Repairing epochs:  95%|█████████▌| 421/443 [00:04<00:00, 106.83it/s]
#
# Repairing epochs:  98%|█████████▊| 432/443 [00:04<00:00, 104.50it/s]
#
# Repairing epochs: 100%|██████████| 443/443 [00:04<00:00, 104.17it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:02,  3.71it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:02,  3.63it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  3.54it/s]
#
#
# Fold:  40%|████      | 4/10 [00:01<00:01,  3.61it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:01<00:01,  3.66it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:01,  3.71it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  3.71it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:02<00:00,  3.59it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:02<00:00,  3.17it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
#
# n_interp: 100%|██████████| 3/3 [00:27<00:00,  9.05s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 4 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
#
#
# Repairing epochs:   0%|          | 0/443 [00:00<?, ?it/s]
# Estimated consensus=1.00 and n_interpolate=32
# Repairing epochs:   1%|          | 3/443 [00:00<00:15, 27.89it/s]
#
# Repairing epochs:   2%|▏         | 9/443 [00:00<00:11, 38.56it/s]
#
# Repairing epochs:   4%|▎         | 16/443 [00:00<00:08, 51.07it/s]
#
# Repairing epochs:   5%|▌         | 23/443 [00:00<00:07, 57.64it/s]
#
# Repairing epochs:   8%|▊         | 34/443 [00:00<00:05, 74.47it/s]
#
# Repairing epochs:  10%|█         | 46/443 [00:00<00:04, 87.74it/s]
#
# Repairing epochs:  13%|█▎        | 57/443 [00:00<00:04, 93.90it/s]
#
# Repairing epochs:  16%|█▌        | 69/443 [00:00<00:03, 101.23it/s]
#
# Repairing epochs:  19%|█▊        | 82/443 [00:00<00:03, 108.61it/s]
#
# Repairing epochs:  21%|██        | 94/443 [00:01<00:03, 111.87it/s]
#
# Repairing epochs:  24%|██▍       | 106/443 [00:01<00:02, 113.36it/s]
#
# Repairing epochs:  27%|██▋       | 118/443 [00:01<00:02, 112.58it/s]
#
# Repairing epochs:  29%|██▉       | 130/443 [00:01<00:02, 113.83it/s]
#
# Repairing epochs:  32%|███▏      | 142/443 [00:01<00:02, 105.54it/s]
#
# Repairing epochs:  35%|███▍      | 153/443 [00:01<00:02, 104.72it/s]
#
# Repairing epochs:  37%|███▋      | 164/443 [00:01<00:02, 105.07it/s]
#
# Repairing epochs:  40%|███▉      | 175/443 [00:01<00:02, 99.45it/s]
#
# Repairing epochs:  42%|████▏     | 186/443 [00:01<00:02, 101.47it/s]
#
# Repairing epochs:  44%|████▍     | 197/443 [00:02<00:03, 76.30it/s]
#
# Repairing epochs:  47%|████▋     | 206/443 [00:02<00:05, 47.22it/s]
#
# Repairing epochs:  49%|████▉     | 216/443 [00:02<00:04, 55.74it/s]
#
# Repairing epochs:  51%|█████     | 225/443 [00:02<00:03, 61.97it/s]
#
# Repairing epochs:  53%|█████▎    | 234/443 [00:02<00:03, 66.30it/s]
#
# Repairing epochs:  56%|█████▌    | 246/443 [00:02<00:02, 77.31it/s]
#
# Repairing epochs:  58%|█████▊    | 258/443 [00:03<00:02, 86.60it/s]
#
# Repairing epochs:  60%|██████    | 268/443 [00:03<00:01, 88.24it/s]
#
# Repairing epochs:  63%|██████▎   | 278/443 [00:03<00:01, 85.24it/s]
#
# Repairing epochs:  65%|██████▌   | 288/443 [00:03<00:01, 85.17it/s]
#
# Repairing epochs:  67%|██████▋   | 297/443 [00:03<00:01, 83.10it/s]
#
# Repairing epochs:  69%|██████▉   | 307/443 [00:03<00:01, 86.75it/s]
#
# Repairing epochs:  72%|███████▏  | 318/443 [00:03<00:01, 92.41it/s]
#
# Repairing epochs:  74%|███████▍  | 330/443 [00:03<00:01, 99.01it/s]
#
# Repairing epochs:  77%|███████▋  | 341/443 [00:04<00:01, 89.99it/s]
#
# Repairing epochs:  79%|███████▉  | 351/443 [00:04<00:01, 85.09it/s]
#
# Repairing epochs:  81%|████████▏ | 360/443 [00:04<00:01, 82.66it/s]
#
# Repairing epochs:  83%|████████▎ | 369/443 [00:04<00:00, 80.48it/s]
#
# Repairing epochs:  86%|████████▌ | 380/443 [00:04<00:00, 87.67it/s]
#
# Repairing epochs:  88%|████████▊ | 391/443 [00:04<00:00, 93.10it/s]
#
# Repairing epochs:  91%|█████████ | 402/443 [00:04<00:00, 96.31it/s]
#
# Repairing epochs:  93%|█████████▎| 412/443 [00:04<00:00, 94.14it/s]
#
# Repairing epochs:  95%|█████████▌| 422/443 [00:04<00:00, 86.73it/s]
#
# Repairing epochs:  97%|█████████▋| 431/443 [00:05<00:00, 85.24it/s]
#
# Repairing epochs: 100%|██████████| 443/443 [00:05<00:00, 84.83it/s]
# No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP09/VP09filt_raw.fif...
#     Range : 0 ... 1079154 =      0.000 ...  4316.616 secs
# Ready.
# Reading 0 ... 1079154  =      0.000 ...  4316.616 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '110', '111', '12', '154', '155', '157', '158', '160', '161', '162', '163', '165', '167', '169', '17', '170', '171', '172', '173', '174', '175', '177', '179', '181', '188', '192', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '243', '251', '252', '253', '3', '4', '5', '6', '62', '68', '7', '74', '80', '86', '9', '92', '98', '99']
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 3 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:   7%|▋         | 4/61 [00:00<00:01, 39.92it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 61/61 [00:01<00:00, 45.94it/s]
# Computing thresholds ...: 100%|██████████| 61/61 [00:12<00:00,  4.78it/s]
#
#
# Repairing epochs:   0%|          | 0/246 [00:00<?, ?it/s]
#
# Repairing epochs:  15%|█▌        | 38/246 [00:00<00:00, 377.66it/s]
#
# Repairing epochs:  33%|███▎      | 80/246 [00:00<00:00, 398.11it/s]
#
# Repairing epochs:  50%|████▉     | 122/246 [00:00<00:00, 404.16it/s]
#
# Repairing epochs:  66%|██████▋   | 163/246 [00:00<00:00, 397.69it/s]
#
# Repairing epochs:  83%|████████▎ | 203/246 [00:00<00:00, 397.34it/s]
#
# Repairing epochs: 100%|██████████| 246/246 [00:00<00:00, 389.94it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/246 [00:00<?, ?it/s]
#
# Repairing epochs:   4%|▍         | 11/246 [00:00<00:02, 104.56it/s]
#
# Repairing epochs:   9%|▉         | 22/246 [00:00<00:02, 100.38it/s]
#
# Repairing epochs:  13%|█▎        | 33/246 [00:00<00:02, 100.28it/s]
#
# Repairing epochs:  18%|█▊        | 44/246 [00:00<00:02, 100.39it/s]
#
# Repairing epochs:  22%|██▏       | 55/246 [00:00<00:01, 99.75it/s]
#
# Repairing epochs:  26%|██▋       | 65/246 [00:00<00:01, 99.15it/s]
#
# Repairing epochs:  31%|███       | 76/246 [00:00<00:01, 99.63it/s]
#
# Repairing epochs:  35%|███▍      | 86/246 [00:00<00:01, 92.97it/s]
#
# Repairing epochs:  39%|███▉      | 96/246 [00:00<00:01, 92.82it/s]
#
# Repairing epochs:  43%|████▎     | 106/246 [00:01<00:01, 94.53it/s]
#
# Repairing epochs:  48%|████▊     | 117/246 [00:01<00:01, 97.14it/s]
#
# Repairing epochs:  52%|█████▏    | 127/246 [00:01<00:01, 95.48it/s]
#
# Repairing epochs:  56%|█████▌    | 137/246 [00:01<00:01, 96.51it/s]
#
# Repairing epochs:  60%|██████    | 148/246 [00:01<00:01, 97.92it/s]
#
# Repairing epochs:  65%|██████▍   | 159/246 [00:01<00:00, 99.40it/s]
#
# Repairing epochs:  69%|██████▊   | 169/246 [00:01<00:00, 98.71it/s]
#
# Repairing epochs:  73%|███████▎  | 179/246 [00:01<00:00, 98.43it/s]
#
# Repairing epochs:  77%|███████▋  | 189/246 [00:01<00:00, 96.83it/s]
#
# Repairing epochs:  81%|████████  | 199/246 [00:02<00:00, 94.92it/s]
#
# Repairing epochs:  85%|████████▍ | 209/246 [00:02<00:00, 92.18it/s]
#
# Repairing epochs:  89%|████████▉ | 219/246 [00:02<00:00, 81.52it/s]
#
# Repairing epochs:  93%|█████████▎| 228/246 [00:02<00:00, 83.35it/s]
#
# Repairing epochs: 100%|██████████| 246/246 [00:02<00:00, 93.49it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:02,  3.44it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:02,  3.52it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  3.55it/s]
#
#
# Fold:  40%|████      | 4/10 [00:01<00:01,  3.56it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:01<00:01,  3.54it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:01,  3.51it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  3.47it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:02<00:00,  3.44it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:02<00:00,  3.41it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:02<00:00,  3.46it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:05<00:11,  5.75s/it]
#
# Repairing epochs:   0%|          | 0/246 [00:00<?, ?it/s]
#
# Repairing epochs:   4%|▍         | 11/246 [00:00<00:02, 108.08it/s]
#
# Repairing epochs:   9%|▉         | 22/246 [00:00<00:02, 107.29it/s]
#
# Repairing epochs:  13%|█▎        | 33/246 [00:00<00:02, 101.96it/s]
#
# Repairing epochs:  18%|█▊        | 44/246 [00:00<00:01, 103.07it/s]
#
# Repairing epochs:  22%|██▏       | 55/246 [00:00<00:01, 103.09it/s]
#
# Repairing epochs:  27%|██▋       | 66/246 [00:00<00:01, 104.88it/s]
#
# Repairing epochs:  31%|███▏      | 77/246 [00:00<00:01, 104.70it/s]
#
# Repairing epochs:  36%|███▌      | 88/246 [00:00<00:01, 104.73it/s]
#
# Repairing epochs:  40%|████      | 99/246 [00:00<00:01, 105.30it/s]
#
# Repairing epochs:  45%|████▍     | 110/246 [00:01<00:01, 105.73it/s]
#
# Repairing epochs:  49%|████▉     | 121/246 [00:01<00:01, 105.73it/s]
#
# Repairing epochs:  54%|█████▍    | 133/246 [00:01<00:01, 108.27it/s]
#
# Repairing epochs:  59%|█████▊    | 144/246 [00:01<00:00, 105.74it/s]
#
# Repairing epochs:  63%|██████▎   | 155/246 [00:01<00:00, 105.07it/s]
#
# Repairing epochs:  68%|██████▊   | 167/246 [00:01<00:00, 106.81it/s]
#
# Repairing epochs:  73%|███████▎  | 179/246 [00:01<00:00, 108.83it/s]
#
# Repairing epochs:  78%|███████▊  | 191/246 [00:01<00:00, 109.78it/s]
#
# Repairing epochs:  82%|████████▏ | 202/246 [00:01<00:00, 109.03it/s]
#
# Repairing epochs:  87%|████████▋ | 213/246 [00:02<00:00, 105.81it/s]
#
# Repairing epochs:  91%|█████████ | 224/246 [00:02<00:00, 105.60it/s]
#
# Repairing epochs:  96%|█████████▌| 235/246 [00:02<00:00, 106.21it/s]
#
# Repairing epochs: 100%|██████████| 246/246 [00:02<00:00, 105.84it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:02,  3.50it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:02,  3.49it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:02,  3.48it/s]
#
#
# Fold:  40%|████      | 4/10 [00:01<00:01,  3.48it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:01<00:01,  3.50it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:01,  3.49it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:02<00:00,  3.50it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:02<00:00,  3.52it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:02<00:00,  3.54it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:02<00:00,  3.51it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:11<00:05,  5.51s/it]
#
# Repairing epochs:   0%|          | 0/246 [00:00<?, ?it/s]
#
# Repairing epochs:   4%|▍         | 10/246 [00:00<00:02, 98.64it/s]
#
# Repairing epochs:   9%|▊         | 21/246 [00:00<00:02, 101.36it/s]
#
# Repairing epochs:  13%|█▎        | 32/246 [00:00<00:02, 99.56it/s]
#
# Repairing epochs:  17%|█▋        | 43/246 [00:00<00:02, 100.64it/s]
#
# Repairing epochs:  22%|██▏       | 54/246 [00:00<00:01, 101.46it/s]
#
# Repairing epochs:  26%|██▋       | 65/246 [00:00<00:01, 102.91it/s]
#
# Repairing epochs:  31%|███       | 76/246 [00:00<00:01, 102.56it/s]
#
# Repairing epochs:  35%|███▌      | 87/246 [00:00<00:01, 103.74it/s]
#
# Repairing epochs:  40%|███▉      | 98/246 [00:00<00:01, 104.98it/s]
#
# Repairing epochs:  44%|████▍     | 109/246 [00:01<00:01, 105.40it/s]
#
# Repairing epochs:  49%|████▉     | 120/246 [00:01<00:01, 102.77it/s]
#
# Repairing epochs:  54%|█████▎    | 132/246 [00:01<00:01, 106.13it/s]
#
# Repairing epochs:  58%|█████▊    | 143/246 [00:01<00:00, 104.95it/s]
#
# Repairing epochs:  63%|██████▎   | 154/246 [00:01<00:00, 102.40it/s]
#
# Repairing epochs:  67%|██████▋   | 165/246 [00:01<00:00, 104.20it/s]
#
# Repairing epochs:  72%|███████▏  | 177/246 [00:01<00:00, 106.74it/s]
#
# Repairing epochs:  76%|███████▋  | 188/246 [00:01<00:00, 107.64it/s]
#
# Repairing epochs:  81%|████████  | 199/246 [00:01<00:00, 107.77it/s]
#
# Repairing epochs:  86%|████████▌ | 211/246 [00:02<00:00, 109.48it/s]
#
# Repairing epochs:  90%|█████████ | 222/246 [00:02<00:00, 107.71it/s]
#
# Repairing epochs:  95%|█████████▍| 233/246 [00:02<00:00, 107.34it/s]
#
# Repairing epochs: 100%|██████████| 246/246 [00:02<00:00, 104.79it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  7.16it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  7.03it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  6.89it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  6.86it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  6.90it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  6.87it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  6.74it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  6.69it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  6.66it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  6.74it/s]
#
# n_interp: 100%|██████████| 3/3 [00:14<00:00,  4.98s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 3 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
#
#
# Repairing epochs:   0%|          | 0/246 [00:00<?, ?it/s]
# Estimated consensus=0.20 and n_interpolate=4
# Repairing epochs:   4%|▍         | 11/246 [00:00<00:02, 104.10it/s]
#
# Repairing epochs:   9%|▉         | 22/246 [00:00<00:02, 83.39it/s]
#
# Repairing epochs:  13%|█▎        | 31/246 [00:00<00:03, 58.57it/s]
#
# Repairing epochs:  16%|█▋        | 40/246 [00:00<00:03, 65.74it/s]
#
# Repairing epochs:  20%|█▉        | 48/246 [00:00<00:02, 69.40it/s]
#
# Repairing epochs:  23%|██▎       | 56/246 [00:00<00:02, 72.25it/s]
#
# Repairing epochs:  27%|██▋       | 66/246 [00:00<00:02, 79.98it/s]
#
# Repairing epochs:  31%|███▏      | 77/246 [00:00<00:01, 86.66it/s]
#
# Repairing epochs:  36%|███▌      | 88/246 [00:01<00:01, 92.28it/s]
#
# Repairing epochs:  40%|████      | 99/246 [00:01<00:01, 94.90it/s]
#
# Repairing epochs:  45%|████▍     | 110/246 [00:01<00:01, 97.90it/s]
#
# Repairing epochs:  49%|████▉     | 121/246 [00:01<00:01, 99.63it/s]
#
# Repairing epochs:  54%|█████▍    | 133/246 [00:01<00:01, 103.46it/s]
#
# Repairing epochs:  59%|█████▊    | 144/246 [00:01<00:00, 103.39it/s]
#
# Repairing epochs:  63%|██████▎   | 155/246 [00:01<00:00, 104.71it/s]
#
# Repairing epochs:  68%|██████▊   | 167/246 [00:01<00:00, 106.86it/s]
#
# Repairing epochs:  72%|███████▏  | 178/246 [00:01<00:00, 107.32it/s]
#
# Repairing epochs:  77%|███████▋  | 190/246 [00:02<00:00, 109.10it/s]
#
# Repairing epochs:  82%|████████▏ | 201/246 [00:02<00:00, 108.16it/s]
#
# Repairing epochs:  87%|████████▋ | 213/246 [00:02<00:00, 109.74it/s]
#
# Repairing epochs:  91%|█████████ | 224/246 [00:02<00:00, 108.11it/s]
#
# Repairing epochs:  96%|█████████▌| 235/246 [00:02<00:00, 107.91it/s]
#
# Repairing epochs: 100%|██████████| 246/246 [00:02<00:00, 95.70it/s]
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP10/VP10filt_raw.fif...
#     Range : 0 ... 1046095 =      0.000 ...  4184.380 secs
# Ready.
# Reading 0 ... 1046095  =      0.000 ...  4184.380 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '12', '17', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '243', '251', '252', '253', '255', '3', '4', '5', '6', '62', '68', '7', '74', '80', '86', '9', '92', '98', '99']
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 3 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:  11%|█▏        | 7/61 [00:00<00:00, 65.09it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 61/61 [00:00<00:00, 74.36it/s]
# Computing thresholds ...: 100%|██████████| 61/61 [00:09<00:00,  6.70it/s]
#
#
# Repairing epochs:   0%|          | 0/135 [00:00<?, ?it/s]
#
# Repairing epochs:  22%|██▏       | 30/135 [00:00<00:00, 296.42it/s]
#
# Repairing epochs:  52%|█████▏    | 70/135 [00:00<00:00, 352.79it/s]
#
# Repairing epochs: 100%|██████████| 135/135 [00:00<00:00, 373.60it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/135 [00:00<?, ?it/s]
#
# Repairing epochs:  11%|█         | 15/135 [00:00<00:00, 142.70it/s]
#
# Repairing epochs:  22%|██▏       | 30/135 [00:00<00:00, 135.76it/s]
#
# Repairing epochs:  33%|███▎      | 44/135 [00:00<00:00, 136.06it/s]
#
# Repairing epochs:  43%|████▎     | 58/135 [00:00<00:00, 120.15it/s]
#
# Repairing epochs:  53%|█████▎    | 71/135 [00:00<00:00, 116.51it/s]
#
# Repairing epochs:  61%|██████▏   | 83/135 [00:00<00:00, 113.51it/s]
#
# Repairing epochs:  73%|███████▎  | 99/135 [00:00<00:00, 125.14it/s]
#
# Repairing epochs:  83%|████████▎ | 112/135 [00:00<00:00, 120.06it/s]
#
# Repairing epochs: 100%|██████████| 135/135 [00:01<00:00, 120.29it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  6.38it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  6.45it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  6.57it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  6.61it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  6.58it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  6.49it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  6.53it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  6.52it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  6.52it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  6.52it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:02<00:05,  2.78s/it]
#
# Repairing epochs:   0%|          | 0/135 [00:00<?, ?it/s]
#
# Repairing epochs:  11%|█         | 15/135 [00:00<00:00, 148.78it/s]
#
# Repairing epochs:  22%|██▏       | 30/135 [00:00<00:00, 140.41it/s]
#
# Repairing epochs:  33%|███▎      | 45/135 [00:00<00:00, 138.24it/s]
#
# Repairing epochs:  44%|████▎     | 59/135 [00:00<00:00, 126.25it/s]
#
# Repairing epochs:  53%|█████▎    | 72/135 [00:00<00:00, 123.64it/s]
#
# Repairing epochs:  63%|██████▎   | 85/135 [00:00<00:00, 120.20it/s]
#
# Repairing epochs:  74%|███████▍  | 100/135 [00:00<00:00, 128.30it/s]
#
# Repairing epochs:  84%|████████▎ | 113/135 [00:00<00:00, 123.52it/s]
#
# Repairing epochs: 100%|██████████| 135/135 [00:01<00:00, 124.31it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  6.66it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  6.58it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  6.36it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  6.45it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  6.45it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  6.44it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  6.49it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  6.50it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  6.48it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  6.48it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:05<00:02,  2.75s/it]
#
# Repairing epochs:   0%|          | 0/135 [00:00<?, ?it/s]
#
# Repairing epochs:  11%|█         | 15/135 [00:00<00:00, 140.00it/s]
#
# Repairing epochs:  22%|██▏       | 30/135 [00:00<00:00, 138.37it/s]
#
# Repairing epochs:  33%|███▎      | 45/135 [00:00<00:00, 140.11it/s]
#
# Repairing epochs:  44%|████▍     | 60/135 [00:00<00:00, 128.45it/s]
#
# Repairing epochs:  54%|█████▍    | 73/135 [00:00<00:00, 125.07it/s]
#
# Repairing epochs:  64%|██████▎   | 86/135 [00:00<00:00, 124.61it/s]
#
# Repairing epochs:  75%|███████▍  | 101/135 [00:00<00:00, 129.51it/s]
#
# Repairing epochs:  84%|████████▍ | 114/135 [00:00<00:00, 121.44it/s]
#
# Repairing epochs: 100%|██████████| 135/135 [00:01<00:00, 124.37it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:00, 13.08it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00, 12.98it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00, 12.86it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00, 12.85it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:00<00:00, 12.76it/s]
#
# n_interp: 100%|██████████| 3/3 [00:07<00:00,  2.47s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 3 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
#
#
# Repairing epochs:   0%|          | 0/135 [00:00<?, ?it/s]
# Estimated consensus=0.30 and n_interpolate=4
# Repairing epochs:  11%|█         | 15/135 [00:00<00:00, 139.53it/s]
#
# Repairing epochs:  21%|██▏       | 29/135 [00:00<00:00, 139.49it/s]
#
# Repairing epochs:  32%|███▏      | 43/135 [00:00<00:00, 139.14it/s]
#
# Repairing epochs:  42%|████▏     | 57/135 [00:00<00:00, 127.35it/s]
#
# Repairing epochs:  52%|█████▏    | 70/135 [00:00<00:00, 123.74it/s]
#
# Repairing epochs:  61%|██████▏   | 83/135 [00:00<00:00, 119.64it/s]
#
# Repairing epochs:  73%|███████▎  | 99/135 [00:00<00:00, 129.89it/s]
#
# Repairing epochs:  84%|████████▎ | 113/135 [00:00<00:00, 122.90it/s]
#
# Repairing epochs: 100%|██████████| 135/135 [00:01<00:00, 121.56it/s]
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP11/VP11filt_raw.fif...
#     Range : 0 ... 1018724 =      0.000 ...  4074.896 secs
# Ready.
# Reading 0 ... 1018724  =      0.000 ...  4074.896 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '12', '17', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '243', '251', '252', '253', '255', '3', '4', '5', '6', '62', '68', '7', '74', '8', '80', '86', '9', '92', '98', '99']
# Creating augmented epochs:  12%|█▎        | 8/64 [00:00<00:00, 78.81it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 64/64 [00:00<00:00, 75.34it/s]
# Computing thresholds ...: 100%|██████████| 64/64 [00:09<00:00,  6.40it/s]
#
#
# Repairing epochs:   0%|          | 0/145 [00:00<?, ?it/s]
#
# Repairing epochs:  27%|██▋       | 39/145 [00:00<00:00, 382.99it/s]
#
# Repairing epochs:  56%|█████▌    | 81/145 [00:00<00:00, 401.95it/s]
#
# Repairing epochs: 100%|██████████| 145/145 [00:00<00:00, 401.66it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/145 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 11/145 [00:00<00:01, 102.07it/s]
#
# Repairing epochs:  15%|█▌        | 22/145 [00:00<00:01, 103.41it/s]
#
# Repairing epochs:  23%|██▎       | 33/145 [00:00<00:01, 106.24it/s]
#
# Repairing epochs:  31%|███       | 45/145 [00:00<00:00, 108.22it/s]
#
# Repairing epochs:  39%|███▉      | 57/145 [00:00<00:00, 110.10it/s]
#
# Repairing epochs:  48%|████▊     | 69/145 [00:00<00:00, 111.34it/s]
#
# Repairing epochs:  56%|█████▌    | 81/145 [00:00<00:00, 107.95it/s]
#
# Repairing epochs:  63%|██████▎   | 92/145 [00:00<00:00, 108.30it/s]
#
# Repairing epochs:  72%|███████▏  | 104/145 [00:00<00:00, 109.57it/s]
#
# Repairing epochs:  79%|███████▉  | 115/145 [00:01<00:00, 108.61it/s]
#
# Repairing epochs:  87%|████████▋ | 126/145 [00:01<00:00, 96.23it/s]
#
# Repairing epochs: 100%|██████████| 145/145 [00:01<00:00, 106.36it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  7.15it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  7.45it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:00,  7.52it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  7.56it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  7.45it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  7.10it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:00<00:00,  6.97it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  6.81it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  6.80it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  7.02it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:02<00:05,  2.88s/it]
#
# Repairing epochs:   0%|          | 0/145 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 12/145 [00:00<00:01, 114.24it/s]
#
# Repairing epochs:  17%|█▋        | 24/145 [00:00<00:01, 112.90it/s]
#
# Repairing epochs:  25%|██▍       | 36/145 [00:00<00:00, 114.60it/s]
#
# Repairing epochs:  33%|███▎      | 48/145 [00:00<00:00, 104.14it/s]
#
# Repairing epochs:  41%|████      | 59/145 [00:00<00:00, 99.98it/s]
#
# Repairing epochs:  48%|████▊     | 70/145 [00:00<00:00, 101.63it/s]
#
# Repairing epochs:  56%|█████▌    | 81/145 [00:00<00:00, 97.31it/s]
#
# Repairing epochs:  64%|██████▍   | 93/145 [00:00<00:00, 101.67it/s]
#
# Repairing epochs:  72%|███████▏  | 105/145 [00:01<00:00, 105.08it/s]
#
# Repairing epochs:  80%|████████  | 116/145 [00:01<00:00, 105.87it/s]
#
# Repairing epochs:  89%|████████▉ | 129/145 [00:01<00:00, 110.33it/s]
#
# Repairing epochs: 100%|██████████| 145/145 [00:01<00:00, 106.96it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  5.80it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  5.83it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  5.81it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:01,  5.78it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  5.55it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:00,  5.80it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  6.11it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  6.33it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  6.46it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  6.14it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:05<00:02,  2.99s/it]
#
# Repairing epochs:   0%|          | 0/145 [00:00<?, ?it/s]
#
# Repairing epochs:   7%|▋         | 10/145 [00:00<00:01, 92.13it/s]
#
# Repairing epochs:  14%|█▍        | 21/145 [00:00<00:01, 98.47it/s]
#
# Repairing epochs:  22%|██▏       | 32/145 [00:00<00:01, 102.00it/s]
#
# Repairing epochs:  30%|███       | 44/145 [00:00<00:00, 106.97it/s]
#
# Repairing epochs:  39%|███▊      | 56/145 [00:00<00:00, 109.69it/s]
#
# Repairing epochs:  48%|████▊     | 69/145 [00:00<00:00, 113.47it/s]
#
# Repairing epochs:  56%|█████▌    | 81/145 [00:00<00:00, 111.07it/s]
#
# Repairing epochs:  64%|██████▍   | 93/145 [00:00<00:00, 111.76it/s]
#
# Repairing epochs:  72%|███████▏  | 105/145 [00:00<00:00, 113.40it/s]
#
# Repairing epochs:  81%|████████  | 117/145 [00:01<00:00, 112.98it/s]
#
# Repairing epochs:  90%|████████▉ | 130/145 [00:01<00:00, 116.62it/s]
#
# Repairing epochs: 100%|██████████| 145/145 [00:01<00:00, 111.68it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:00, 11.67it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00, 11.63it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00, 12.26it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00, 13.25it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:00<00:00, 13.13it/s]
#
# n_interp: 100%|██████████| 3/3 [00:08<00:00,  2.68s/it]
#
#
# Repairing epochs:   0%|          | 0/145 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 12/145 [00:00<00:01, 112.43it/s]
# Estimated consensus=0.40 and n_interpolate=4
# Repairing epochs:  17%|█▋        | 24/145 [00:00<00:01, 104.93it/s]
#
# Repairing epochs:  26%|██▌       | 37/145 [00:00<00:00, 112.83it/s]
#
# Repairing epochs:  34%|███▍      | 49/145 [00:00<00:00, 113.98it/s]
#
# Repairing epochs:  42%|████▏     | 61/145 [00:00<00:00, 112.40it/s]
#
# Repairing epochs:  50%|█████     | 73/145 [00:00<00:00, 113.32it/s]
#
# Repairing epochs:  59%|█████▊    | 85/145 [00:00<00:00, 111.39it/s]
#
# Repairing epochs:  67%|██████▋   | 97/145 [00:00<00:00, 111.27it/s]
#
# Repairing epochs:  75%|███████▌  | 109/145 [00:00<00:00, 109.43it/s]
#
# Repairing epochs:  83%|████████▎ | 120/145 [00:01<00:00, 108.72it/s]
#
# Repairing epochs: 100%|██████████| 145/145 [00:01<00:00, 113.04it/s]
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP12/VP12filt_raw.fif...
#     Range : 0 ... 326222 =      0.000 ...  1304.888 secs
# Ready.
# Reading 0 ... 326222  =      0.000 ...  1304.888 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '111', '12', '168', '17', '177', '185', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '243', '251', '252', '253', '255', '3', '4', '5', '6', '74', '8', '80', '86', '9', '92', '99']
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 3 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:  16%|█▋        | 10/61 [00:00<00:00, 94.41it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 61/61 [00:00<00:00, 105.87it/s]
# Computing thresholds ...: 100%|██████████| 61/61 [00:06<00:00,  9.73it/s]
#
#
# Repairing epochs:   0%|          | 0/45 [00:00<?, ?it/s]
#
# Repairing epochs: 100%|██████████| 45/45 [00:00<00:00, 379.72it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/45 [00:00<?, ?it/s]
#
# Repairing epochs:  24%|██▍       | 11/45 [00:00<00:00, 108.65it/s]
#
# Repairing epochs:  51%|█████     | 23/45 [00:00<00:00, 114.11it/s]
#
# Repairing epochs: 100%|██████████| 45/45 [00:00<00:00, 112.25it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:00, 26.24it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00, 25.28it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:00<00:00, 24.26it/s][A
#
# n_interp:  33%|███▎      | 1/3 [00:00<00:01,  1.16it/s]
#
# Repairing epochs:   0%|          | 0/45 [00:00<?, ?it/s]
#
# Repairing epochs:  24%|██▍       | 11/45 [00:00<00:00, 104.00it/s]
#
# Repairing epochs:  51%|█████     | 23/45 [00:00<00:00, 111.71it/s]
#
# Repairing epochs: 100%|██████████| 45/45 [00:00<00:00, 110.27it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:00, 24.11it/s]
#
#
# ...
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  5.22it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:01,  5.27it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  5.29it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:00,  5.30it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  5.31it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  5.32it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  5.22it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  5.24it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:03<00:07,  3.71s/it]
#
# Repairing epochs:   0%|          | 0/148 [00:00<?, ?it/s]
#
# Repairing epochs:   7%|▋         | 10/148 [00:00<00:01, 97.73it/s]
#
# Repairing epochs:  14%|█▎        | 20/148 [00:00<00:01, 96.94it/s]
#
# Repairing epochs:  20%|██        | 30/148 [00:00<00:01, 96.88it/s]
#
# Repairing epochs:  27%|██▋       | 40/148 [00:00<00:01, 96.32it/s]
#
# Repairing epochs:  34%|███▍      | 51/148 [00:00<00:00, 98.72it/s]
#
# Repairing epochs:  42%|████▏     | 62/148 [00:00<00:00, 100.59it/s]
#
# Repairing epochs:  49%|████▉     | 73/148 [00:00<00:00, 98.66it/s]
#
# Repairing epochs:  57%|█████▋    | 84/148 [00:00<00:00, 100.53it/s]
#
# Repairing epochs:  64%|██████▍   | 95/148 [00:00<00:00, 99.07it/s]
#
# Repairing epochs:  71%|███████   | 105/148 [00:01<00:00, 97.69it/s]
#
# Repairing epochs:  78%|███████▊  | 115/148 [00:01<00:00, 96.01it/s]
#
# Repairing epochs:  84%|████████▍ | 125/148 [00:01<00:00, 95.11it/s]
#
# Repairing epochs:  91%|█████████ | 135/148 [00:01<00:00, 95.01it/s]
#
# Repairing epochs: 100%|██████████| 148/148 [00:01<00:00, 96.42it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  5.33it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  5.28it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  5.27it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:01,  5.26it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  5.27it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:00,  5.30it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  5.30it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  5.28it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  5.26it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  5.26it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:07<00:03,  3.66s/it]
#
# Repairing epochs:   0%|          | 0/148 [00:00<?, ?it/s]
#
# Repairing epochs:   7%|▋         | 10/148 [00:00<00:01, 98.08it/s]
#
# Repairing epochs:  14%|█▎        | 20/148 [00:00<00:01, 97.53it/s]
#
# Repairing epochs:  20%|██        | 30/148 [00:00<00:01, 89.32it/s]
#
# Repairing epochs:  27%|██▋       | 40/148 [00:00<00:02, 49.19it/s]
#
# Repairing epochs:  34%|███▍      | 51/148 [00:00<00:01, 61.70it/s]
#
# Repairing epochs:  42%|████▏     | 62/148 [00:00<00:01, 71.47it/s]
#
# Repairing epochs:  48%|████▊     | 71/148 [00:01<00:01, 70.59it/s]
#
# Repairing epochs:  55%|█████▌    | 82/148 [00:01<00:00, 79.84it/s]
#
# Repairing epochs:  62%|██████▏   | 92/148 [00:01<00:00, 84.33it/s]
#
# Repairing epochs:  69%|██████▉   | 102/148 [00:01<00:00, 86.36it/s]
#
# Repairing epochs:  76%|███████▌  | 112/148 [00:01<00:00, 89.27it/s]
#
# Repairing epochs:  82%|████████▏ | 122/148 [00:01<00:00, 64.86it/s]
#
# Repairing epochs:  89%|████████▉ | 132/148 [00:01<00:00, 70.63it/s]
#
# Repairing epochs: 100%|██████████| 148/148 [00:01<00:00, 74.91it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:00,  9.36it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:00,  9.33it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:00,  9.24it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  9.26it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  9.27it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  9.29it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:00<00:00,  9.30it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00,  9.31it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:00<00:00,  9.29it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  9.13it/s]
#
# n_interp: 100%|██████████| 3/3 [00:10<00:00,  3.50s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 1 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
#
#
# Repairing epochs:   0%|          | 0/148 [00:00<?, ?it/s]
#
# Repairing epochs:   5%|▍         | 7/148 [00:00<00:02, 64.23it/s]
# Estimated consensus=0.60 and n_interpolate=32
# Repairing epochs:  11%|█▏        | 17/148 [00:00<00:01, 80.72it/s]
#
# Repairing epochs:  18%|█▊        | 27/148 [00:00<00:01, 86.81it/s]
#
# Repairing epochs:  25%|██▌       | 37/148 [00:00<00:01, 89.76it/s]
#
# Repairing epochs:  32%|███▏      | 47/148 [00:00<00:01, 92.90it/s]
#
# Repairing epochs:  39%|███▉      | 58/148 [00:00<00:00, 97.27it/s]
#
# Repairing epochs:  46%|████▌     | 68/148 [00:00<00:00, 90.65it/s]
#
# Repairing epochs:  53%|█████▎    | 78/148 [00:00<00:00, 89.79it/s]
#
# Repairing epochs:  59%|█████▉    | 88/148 [00:00<00:00, 91.59it/s]
#
# Repairing epochs:  66%|██████▌   | 98/148 [00:01<00:00, 89.06it/s]
#
# Repairing epochs:  73%|███████▎  | 108/148 [00:01<00:00, 90.19it/s]
#
# Repairing epochs:  80%|███████▉  | 118/148 [00:01<00:00, 89.79it/s]
#
# Repairing epochs:  86%|████████▋ | 128/148 [00:01<00:00, 90.55it/s]
#
# Repairing epochs:  93%|█████████▎| 138/148 [00:01<00:00, 88.14it/s]
#
# Repairing epochs: 100%|██████████| 148/148 [00:01<00:00, 88.91it/s]
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP37/VP37filt_raw.fif...
#     Range : 0 ... 970885 =      0.000 ...  3883.540 secs
# Ready.
# Reading 0 ... 970885  =      0.000 ...  3883.540 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '110', '12', '160', '161', '163', '164', '165', '167', '168', '169', '17', '170', '172', '174', '175', '176', '177', '178', '179', '183', '187', '189', '190', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '237', '238', '239', '243', '251', '252', '253', '255', '3', '4', '5', '6', '62', '7', '74', '86', '9', '92', '98', '99']
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 5 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:  12%|█▏        | 7/59 [00:00<00:00, 64.32it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 59/59 [00:00<00:00, 72.98it/s]
# Computing thresholds ...: 100%|██████████| 59/59 [00:21<00:00,  2.76it/s]
#
#
# Repairing epochs:   0%|          | 0/220 [00:00<?, ?it/s]
#
# Repairing epochs:  20%|█▉        | 43/220 [00:00<00:00, 423.23it/s]
#
# Repairing epochs:  39%|███▉      | 86/220 [00:00<00:00, 419.39it/s]
#
# Repairing epochs:  58%|█████▊    | 128/220 [00:00<00:00, 418.53it/s]
#
# Repairing epochs:  77%|███████▋  | 170/220 [00:00<00:00, 414.47it/s]
#
# Repairing epochs: 100%|██████████| 220/220 [00:00<00:00, 413.37it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/220 [00:00<?, ?it/s]
#
# Repairing epochs:   5%|▌         | 11/220 [00:00<00:01, 108.92it/s]
#
# Repairing epochs:  10%|█         | 22/220 [00:00<00:01, 101.46it/s]
#
# Repairing epochs:  15%|█▌        | 33/220 [00:00<00:01, 97.62it/s]
#
# Repairing epochs:  20%|██        | 44/220 [00:00<00:01, 101.50it/s]
#
# Repairing epochs:  25%|██▌       | 55/220 [00:00<00:01, 104.07it/s]
#
# Repairing epochs:  30%|███       | 66/220 [00:00<00:01, 101.06it/s]
#
# Repairing epochs:  35%|███▌      | 77/220 [00:00<00:01, 98.88it/s]
#
# Repairing epochs:  40%|████      | 88/220 [00:00<00:01, 100.36it/s]
#
# Repairing epochs:  45%|████▌     | 99/220 [00:00<00:01, 102.14it/s]
#
# Repairing epochs:  50%|█████     | 110/220 [00:01<00:01, 103.56it/s]
#
# Repairing epochs:  55%|█████▌    | 121/220 [00:01<00:00, 104.99it/s]
#
# Repairing epochs:  60%|██████    | 132/220 [00:01<00:00, 104.69it/s]
#
# Repairing epochs:  65%|██████▌   | 143/220 [00:01<00:00, 105.23it/s]
#
# Repairing epochs:  70%|███████   | 154/220 [00:01<00:00, 105.62it/s]
#
# Repairing epochs:  75%|███████▌  | 165/220 [00:01<00:00, 105.71it/s]
#
# Repairing epochs:  80%|████████  | 176/220 [00:01<00:00, 105.29it/s]
#
# Repairing epochs:  85%|████████▌ | 187/220 [00:01<00:00, 103.86it/s]
#
# Repairing epochs:  90%|█████████ | 198/220 [00:01<00:00, 105.09it/s]
#
# Repairing epochs:  95%|█████████▌| 209/220 [00:02<00:00, 105.36it/s]
#
# Repairing epochs: 100%|██████████| 220/220 [00:02<00:00, 103.39it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:02,  3.89it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  4.13it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  4.27it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:01,  4.33it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:01<00:01,  4.34it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:00,  4.32it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  4.29it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  4.30it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:02<00:00,  4.30it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:02<00:00,  4.26it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:04<00:09,  4.68s/it]
#
# Repairing epochs:   0%|          | 0/220 [00:00<?, ?it/s]
#
# Repairing epochs:   5%|▍         | 10/220 [00:00<00:02, 95.52it/s]
#
# Repairing epochs:   9%|▉         | 20/220 [00:00<00:02, 93.71it/s]
#
# Repairing epochs:  14%|█▎        | 30/220 [00:00<00:02, 92.15it/s]
#
# Repairing epochs:  18%|█▊        | 40/220 [00:00<00:01, 92.69it/s]
#
# Repairing epochs:  23%|██▎       | 50/220 [00:00<00:01, 91.43it/s]
#
# Repairing epochs:  27%|██▋       | 60/220 [00:00<00:01, 93.72it/s]
#
# Repairing epochs:  32%|███▏      | 70/220 [00:00<00:01, 93.43it/s]
#
# Repairing epochs:  36%|███▋      | 80/220 [00:00<00:01, 93.20it/s]
#
# Repairing epochs:  41%|████      | 90/220 [00:00<00:01, 93.15it/s]
#
# Repairing epochs:  45%|████▌     | 100/220 [00:01<00:01, 92.33it/s]
#
# Repairing epochs:  50%|█████     | 110/220 [00:01<00:01, 94.39it/s]
#
# Repairing epochs:  55%|█████▍    | 120/220 [00:01<00:01, 93.63it/s]
#
# Repairing epochs:  59%|█████▉    | 130/220 [00:01<00:00, 94.04it/s]
#
# Repairing epochs:  64%|██████▎   | 140/220 [00:01<00:00, 91.53it/s]
#
# Repairing epochs:  69%|██████▊   | 151/220 [00:01<00:00, 93.99it/s]
#
# Repairing epochs:  73%|███████▎  | 161/220 [00:01<00:00, 92.81it/s]
#
# Repairing epochs:  78%|███████▊  | 171/220 [00:01<00:00, 91.46it/s]
#
# Repairing epochs:  82%|████████▏ | 181/220 [00:01<00:00, 90.59it/s]
#
# Repairing epochs:  87%|████████▋ | 191/220 [00:02<00:00, 91.14it/s]
#
# Repairing epochs:  91%|█████████▏| 201/220 [00:02<00:00, 91.51it/s]
#
# Repairing epochs: 100%|██████████| 220/220 [00:02<00:00, 92.45it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:02,  3.68it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:02,  3.72it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  3.74it/s]
#
#
# Fold:  40%|████      | 4/10 [00:01<00:01,  3.74it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:01<00:01,  3.73it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:01,  3.73it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  3.73it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:02<00:00,  3.74it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:02<00:00,  3.74it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:02<00:00,  3.73it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:09<00:05,  5.04s/it]
#
# Repairing epochs:   0%|          | 0/220 [00:00<?, ?it/s]
#
# Repairing epochs:   5%|▌         | 11/220 [00:00<00:02, 100.52it/s]
#
# Repairing epochs:  10%|█         | 22/220 [00:00<00:02, 93.90it/s]
#
# Repairing epochs:  15%|█▍        | 32/220 [00:00<00:02, 93.08it/s]
#
# Repairing epochs:  19%|█▉        | 42/220 [00:00<00:02, 88.10it/s]
#
# Repairing epochs:  23%|██▎       | 51/220 [00:00<00:01, 88.68it/s]
#
# Repairing epochs:  28%|██▊       | 62/220 [00:00<00:01, 92.99it/s]
#
# Repairing epochs:  33%|███▎      | 72/220 [00:00<00:01, 91.90it/s]
#
# Repairing epochs:  37%|███▋      | 82/220 [00:00<00:01, 92.72it/s]
#
# Repairing epochs:  42%|████▏     | 92/220 [00:00<00:01, 92.27it/s]
#
# Repairing epochs:  46%|████▋     | 102/220 [00:01<00:01, 92.94it/s]
#
# Repairing epochs:  51%|█████     | 112/220 [00:01<00:01, 93.82it/s]
#
# Repairing epochs:  55%|█████▌    | 122/220 [00:01<00:01, 93.24it/s]
#
# Repairing epochs:  60%|██████    | 132/220 [00:01<00:00, 94.24it/s]
#
# Repairing epochs:  65%|██████▍   | 142/220 [00:01<00:00, 95.03it/s]
#
# Repairing epochs:  70%|██████▉   | 153/220 [00:01<00:00, 96.75it/s]
#
# Repairing epochs:  74%|███████▍  | 163/220 [00:01<00:00, 95.24it/s]
#
# Repairing epochs:  79%|███████▊  | 173/220 [00:01<00:00, 93.66it/s]
#
# Repairing epochs:  83%|████████▎ | 183/220 [00:01<00:00, 93.22it/s]
#
# Repairing epochs:  88%|████████▊ | 193/220 [00:02<00:00, 93.40it/s]
#
# Repairing epochs:  93%|█████████▎| 204/220 [00:02<00:00, 97.47it/s]
#
# Repairing epochs: 100%|██████████| 220/220 [00:02<00:00, 93.85it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  6.74it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  6.85it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  6.88it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  6.90it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  6.90it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  6.90it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  6.90it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  6.90it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  6.90it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  6.88it/s]
#
# n_interp: 100%|██████████| 3/3 [00:13<00:00,  4.62s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 5 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Estimated consensus=1.00 and n_interpolate=4
# Repairing epochs:   0%|          | 0/220 [00:00<?, ?it/s]
#
# Repairing epochs:   5%|▍         | 10/220 [00:00<00:02, 91.35it/s]
#
# Repairing epochs:   9%|▉         | 20/220 [00:00<00:02, 89.80it/s]
#
# Repairing epochs:  13%|█▎        | 29/220 [00:00<00:02, 88.23it/s]
#
# Repairing epochs:  18%|█▊        | 39/220 [00:00<00:02, 89.44it/s]
#
# Repairing epochs:  22%|██▏       | 48/220 [00:00<00:01, 88.42it/s]
#
# Repairing epochs:  26%|██▌       | 57/220 [00:00<00:01, 86.54it/s]
#
# Repairing epochs:  30%|███       | 67/220 [00:00<00:01, 88.70it/s]
#
# Repairing epochs:  35%|███▍      | 76/220 [00:00<00:01, 87.81it/s]
#
# Repairing epochs:  39%|███▉      | 86/220 [00:00<00:01, 88.66it/s]
#
# Repairing epochs:  43%|████▎     | 95/220 [00:01<00:01, 88.36it/s]
#
# Repairing epochs:  47%|████▋     | 104/220 [00:01<00:01, 87.77it/s]
#
# Repairing epochs:  52%|█████▏    | 114/220 [00:01<00:01, 88.73it/s]
#
# Repairing epochs:  56%|█████▌    | 123/220 [00:01<00:01, 89.05it/s]
#
# Repairing epochs:  60%|██████    | 132/220 [00:01<00:00, 88.77it/s]
#
# Repairing epochs:  64%|██████▍   | 141/220 [00:01<00:00, 88.24it/s]
#
# Repairing epochs:  69%|██████▊   | 151/220 [00:01<00:00, 90.12it/s]
#
# Repairing epochs:  73%|███████▎  | 161/220 [00:01<00:00, 89.57it/s]
#
# Repairing epochs:  77%|███████▋  | 170/220 [00:01<00:00, 89.01it/s]
#
# Repairing epochs:  82%|████████▏ | 180/220 [00:02<00:00, 89.83it/s]
#
# Repairing epochs:  86%|████████▌ | 189/220 [00:02<00:00, 88.73it/s]
#
# Repairing epochs:  90%|█████████ | 199/220 [00:02<00:00, 90.31it/s]
#
# Repairing epochs:  95%|█████████▌| 209/220 [00:02<00:00, 89.92it/s]
#
# Repairing epochs: 100%|██████████| 220/220 [00:02<00:00, 88.81it/s]
# No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# [5.384615384615385, 0.0, 4.471544715447155, 16.296296296296298, 3.4482758620689653, 0.0, 16.8646080760095, 0.5208333333333334, 24.796747967479675, 14.414414414414415, 14.887640449438202, 12.142857142857142, 5.360824742268041, 7.878787878787879, 4.119850187265918, 9.170305676855895, 1.6, 3.5714285714285716, 11.868686868686869, 16.03448275862069, 15.942028985507246, 1.2727272727272727, 18.43003412969283, 20.118343195266274, 8.108108108108109, 0.0]
