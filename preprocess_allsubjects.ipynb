# %%
# %matplotlib qt
import mne
import utils
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# from cleaner.report import create_ica_report 
# from cleaner import reject

# from nice_ext.algorithms.adaptive import _adaptive_egi

from autoreject import AutoReject, get_rejection_threshold

# %%
epoch_type = 'evoked'
# epoch_type = 'pseudo-rs'

all_participants = ['VP07','VP08','VP09', 'VP10','VP11','VP12','VP13','VP14','VP18','VP19','VP20','VP23','VP24','VP25','VP26','VP27','VP28','VP29','VP30','VP31','VP32','VP33','VP35','VP36','VP37']
participant = all_participants[9]


# path = '/media/nicolas.bruno/63f8a366-34b7-4896-a7ce-b5fb4ee78535/Nico/MW_eeg_data/minmarker/' #icm-linux
path = '/Users/nicobruno/ownCloud/MW_eeg_data/minmarker/' #nico-mac

# %% [raw]
# for i in all_participants[:]:
#     participant = i
#
#
#     raw = mne.io.read_raw_eeglab(folder+file, preload = True, eog = ['EXG3','EXG4','EXG5','EXG6',],verbose = False)
#
#     # raw.set_channel_types({'EXG3': 'eog', 'EXG4': 'eog', 'EXG5': 'eog','EXG6': 'eog'})
#
#
#     raw = raw.pick_types(eeg = True, eog = True, exclude = ['EXG1', 'EXG2', 'EXG7', 'EXG8'])
#
#     raw = raw.set_montage('biosemi64') # ask if biosemi or 10-20 montage
#
# #     print(raw.info)
#
#     raw_downsampled = raw.copy().resample(sfreq=250)
#
#     hpass = 0.5
#     lpass = 45
#
#     raw_filtered = raw_downsampled.copy().filter(l_freq=hpass, h_freq=lpass)
#
#     raw_filtered.plot()
#
#     ### Save filtered data
#     raw_filtered.save(folder + participant + 'filt_raw.fif', overwrite = True)

# %%
rejection = []

for i in all_participants[:13]:
    participant = i

    folder = path + participant +'/'
    file = participant + '_crop_rMean_minmarker.set'
    raw_filtered = mne.io.read_raw(folder + participant + 'filt_raw.fif', preload = True)

    events, event_dict = utils.make_correct_labels(raw_filtered)

    # Create Epochs <a name="epochs"></a>

    epochs = utils.create_epochs(epoch_type = epoch_type, raw = raw_filtered, events =  events, event_id = event_dict)
    epochs.save(folder + participant + epoch_type + '_epo.fif', overwrite = True)

    # Reject Bad Epochs and Channels <a name="reject"></a>

    ar = AutoReject(thresh_method = 'random_search', random_state=42)
    epochs_clean = ar.fit_transform(epochs)  
    reject = get_rejection_threshold(epochs)  

    epochs_clean.save(folder + participant + epoch_type + 'ar-clean_epo.fif', overwrite = True)
    
    rejection.append((len(epochs) - len(epochs_clean)) *100/len(epochs))
    
print(rejection)
# Out:
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP07/VP07filt_raw.fif...
#     Range : 0 ... 1047329 =      0.000 ...  4189.316 secs
# Ready.
# Reading 0 ... 1047329  =      0.000 ...  4189.316 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '12', '161', '166', '167', '169', '17', '176', '180', '190', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '251', '252', '253', '255', '3', '4', '5', '6', '62', '68', '7', '74', '80', '86', '9', '92', '98', '99']
# Overwriting existing file.
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 2 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:  13%|█▎        | 8/62 [00:00<00:00, 79.56it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 62/62 [00:00<00:00, 88.82it/s]
# Computing thresholds ...: 100%|██████████| 62/62 [00:09<00:00,  6.40it/s]
#
#
# Repairing epochs:   0%|          | 0/130 [00:00<?, ?it/s]
#
# Repairing epochs:  31%|███       | 40/130 [00:00<00:00, 395.64it/s]
#
# Repairing epochs:  65%|██████▍   | 84/130 [00:00<00:00, 407.33it/s]
#
# Repairing epochs: 100%|██████████| 130/130 [00:00<00:00, 396.00it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/130 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 10/130 [00:00<00:01, 98.35it/s]
#
# Repairing epochs:  15%|█▌        | 20/130 [00:00<00:01, 97.74it/s]
#
# Repairing epochs:  24%|██▍       | 31/130 [00:00<00:00, 99.98it/s]
#
# Repairing epochs:  32%|███▏      | 41/130 [00:00<00:00, 99.09it/s]
#
# Repairing epochs:  41%|████      | 53/130 [00:00<00:00, 102.64it/s]
#
# Repairing epochs:  48%|████▊     | 63/130 [00:00<00:00, 101.27it/s]
#
# Repairing epochs:  57%|█████▋    | 74/130 [00:00<00:00, 101.53it/s]
#
# Repairing epochs:  65%|██████▍   | 84/130 [00:00<00:00, 98.91it/s]
#
# Repairing epochs:  72%|███████▏  | 94/130 [00:00<00:00, 97.38it/s]
#
# Repairing epochs:  80%|████████  | 104/130 [00:01<00:00, 97.02it/s]
#
# Repairing epochs:  90%|█████████ | 117/130 [00:01<00:00, 103.81it/s]
#
# Repairing epochs: 100%|██████████| 130/130 [00:01<00:00, 102.89it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  8.14it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:00,  8.18it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:00,  8.19it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  8.28it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  8.21it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  8.23it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:00<00:00,  8.23it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00,  8.22it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  8.24it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  8.23it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:02<00:05,  2.57s/it]
#
# Repairing epochs:   0%|          | 0/130 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 11/130 [00:00<00:01, 103.47it/s]
#
# Repairing epochs:  17%|█▋        | 22/130 [00:00<00:01, 103.66it/s]
#
# Repairing epochs:  25%|██▌       | 33/130 [00:00<00:00, 103.49it/s]
#
# Repairing epochs:  34%|███▍      | 44/130 [00:00<00:00, 104.87it/s]
#
# Repairing epochs:  42%|████▏     | 55/130 [00:00<00:00, 105.94it/s]
#
# Repairing epochs:  50%|█████     | 65/130 [00:00<00:00, 103.03it/s]
#
# Repairing epochs:  58%|█████▊    | 75/130 [00:00<00:00, 99.74it/s]
#
# Repairing epochs:  65%|██████▌   | 85/130 [00:00<00:00, 98.18it/s]
#
# Repairing epochs:  73%|███████▎  | 95/130 [00:00<00:00, 96.62it/s]
#
# Repairing epochs:  82%|████████▏ | 107/130 [00:01<00:00, 102.43it/s]
#
# Repairing epochs: 100%|██████████| 130/130 [00:01<00:00, 105.07it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  7.83it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  7.93it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:00,  8.04it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  8.10it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  8.05it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  8.02it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:00<00:00,  8.05it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00,  8.11it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  8.09it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  8.08it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:05<00:02,  2.57s/it]
#
# Repairing epochs:   0%|          | 0/130 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 10/130 [00:00<00:01, 99.75it/s]
#
# Repairing epochs:  15%|█▌        | 20/130 [00:00<00:01, 98.90it/s]
#
# Repairing epochs:  24%|██▍       | 31/130 [00:00<00:00, 101.30it/s]
#
# Repairing epochs:  33%|███▎      | 43/130 [00:00<00:00, 103.00it/s]
#
# Repairing epochs:  41%|████      | 53/130 [00:00<00:00, 101.27it/s]
#
# Repairing epochs:  48%|████▊     | 62/130 [00:00<00:00, 82.95it/s]
#
# Repairing epochs:  54%|█████▍    | 70/130 [00:00<00:00, 78.73it/s]
#
# Repairing epochs:  62%|██████▏   | 80/130 [00:00<00:00, 83.42it/s]
#
# Repairing epochs:  69%|██████▉   | 90/130 [00:00<00:00, 87.15it/s]
#
# Repairing epochs:  76%|███████▌  | 99/130 [00:01<00:00, 86.12it/s]
#
# Repairing epochs:  84%|████████▍ | 109/130 [00:01<00:00, 89.26it/s]
#
# Repairing epochs: 100%|██████████| 130/130 [00:01<00:00, 93.85it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:00, 16.88it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00, 16.79it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00, 16.62it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00, 16.18it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:00<00:00, 16.21it/s]
#
# n_interp: 100%|██████████| 3/3 [00:07<00:00,  2.39s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 2 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
#
#
# Repairing epochs:   0%|          | 0/130 [00:00<?, ?it/s]
#
# Repairing epochs:   9%|▉         | 12/130 [00:00<00:01, 116.74it/s]
# Estimated consensus=0.30 and n_interpolate=4
# Repairing epochs:  17%|█▋        | 22/130 [00:00<00:01, 107.67it/s]
#
# Repairing epochs:  25%|██▌       | 33/130 [00:00<00:00, 108.16it/s]
#
# Repairing epochs:  35%|███▍      | 45/130 [00:00<00:00, 109.40it/s]
#
# Repairing epochs:  43%|████▎     | 56/130 [00:00<00:00, 109.47it/s]
#
# Repairing epochs:  52%|█████▏    | 67/130 [00:00<00:00, 107.78it/s]
#
# Repairing epochs:  60%|██████    | 78/130 [00:00<00:00, 105.98it/s]
#
# Repairing epochs:  68%|██████▊   | 89/130 [00:00<00:00, 104.94it/s]
#
# Repairing epochs:  77%|███████▋  | 100/130 [00:00<00:00, 104.17it/s]
#
# Repairing epochs:  88%|████████▊ | 115/130 [00:01<00:00, 114.05it/s]
#
# Repairing epochs: 100%|██████████| 130/130 [00:01<00:00, 106.75it/s]
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Overwriting existing file.
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP08/VP08filt_raw.fif...
#     Range : 0 ... 963688 =      0.000 ...  3854.752 secs
# Ready.
# Reading 0 ... 963688  =      0.000 ...  3854.752 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '111', '12', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '17', '171', '173', '181', '191', '192', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '251', '252', '253', '255', '3', '4', '5', '6', '7', '74', '80', '86', '9', '92', '99']
# Overwriting existing file.
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 4 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:   0%|          | 0/60 [00:00<?, ?it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 60/60 [00:01<00:00, 36.45it/s]
# Computing thresholds ...: 100%|██████████| 60/60 [00:21<00:00,  2.77it/s]
#
#
# Repairing epochs:   0%|          | 0/443 [00:00<?, ?it/s]
#
# Repairing epochs:   9%|▉         | 40/443 [00:00<00:01, 397.42it/s]
#
# Repairing epochs:  18%|█▊        | 79/443 [00:00<00:00, 394.94it/s]
#
# Repairing epochs:  27%|██▋       | 120/443 [00:00<00:00, 397.20it/s]
#
# Repairing epochs:  36%|███▌      | 160/443 [00:00<00:00, 395.16it/s]
#
# Repairing epochs:  45%|████▌     | 200/443 [00:00<00:00, 395.33it/s]
#
# Repairing epochs:  53%|█████▎    | 237/443 [00:00<00:00, 384.92it/s]
#
# Repairing epochs:  62%|██████▏   | 276/443 [00:00<00:00, 384.90it/s]
#
# Repairing epochs:  71%|███████▏  | 316/443 [00:00<00:00, 387.70it/s]
#
# Repairing epochs:  80%|████████  | 356/443 [00:00<00:00, 389.04it/s]
#
# Repairing epochs:  89%|████████▉ | 396/443 [00:01<00:00, 390.97it/s]
#
# Repairing epochs: 100%|██████████| 443/443 [00:01<00:00, 388.51it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/443 [00:00<?, ?it/s]
#
# Repairing epochs:   3%|▎         | 13/443 [00:00<00:03, 129.36it/s]
#
# Repairing epochs:   6%|▌         | 27/443 [00:00<00:03, 132.22it/s]
#
# Repairing epochs:  10%|█         | 45/443 [00:00<00:02, 142.62it/s]
#
# Repairing epochs:  13%|█▎        | 56/443 [00:00<00:02, 129.52it/s]
#
# Repairing epochs:  16%|█▌        | 70/443 [00:00<00:02, 130.04it/s]
#
# Repairing epochs:  20%|█▉        | 87/443 [00:00<00:02, 139.75it/s]
#
# Repairing epochs:  23%|██▎       | 101/443 [00:00<00:02, 138.78it/s]
#
# Repairing epochs:  26%|██▌       | 116/443 [00:00<00:02, 141.40it/s]
#
# Repairing epochs:  30%|██▉       | 132/443 [00:00<00:02, 143.69it/s]
#
# Repairing epochs:  34%|███▎      | 149/443 [00:01<00:01, 150.26it/s]
#
# Repairing epochs:  37%|███▋      | 164/443 [00:01<00:02, 138.23it/s]
#
# Repairing epochs:  41%|████▏     | 183/443 [00:01<00:01, 148.56it/s]
#
# Repairing epochs:  45%|████▍     | 199/443 [00:01<00:01, 149.45it/s]
#
# Repairing epochs:  49%|████▉     | 217/443 [00:01<00:01, 153.96it/s]
#
# Repairing epochs:  53%|█████▎    | 233/443 [00:01<00:01, 144.08it/s]
#
# Repairing epochs:  56%|█████▌    | 248/443 [00:01<00:01, 141.30it/s]
#
# Repairing epochs:  59%|█████▉    | 263/443 [00:01<00:01, 141.40it/s]
#
# Repairing epochs:  63%|██████▎   | 279/443 [00:01<00:01, 145.40it/s]
#
# Repairing epochs:  66%|██████▋   | 294/443 [00:02<00:01, 137.29it/s]
#
# Repairing epochs:  70%|██████▉   | 310/443 [00:02<00:00, 141.14it/s]
#
# Repairing epochs:  73%|███████▎  | 325/443 [00:02<00:00, 138.48it/s]
#
# Repairing epochs:  77%|███████▋  | 343/443 [00:02<00:00, 146.85it/s]
#
# Repairing epochs:  81%|████████  | 358/443 [00:02<00:00, 146.87it/s]
#
# Repairing epochs:  84%|████████▍ | 373/443 [00:02<00:00, 136.80it/s]
#
# Repairing epochs:  87%|████████▋ | 387/443 [00:02<00:00, 128.76it/s]
#
# Repairing epochs:  91%|█████████ | 401/443 [00:02<00:00, 120.92it/s]
#
# Repairing epochs:  93%|█████████▎| 414/443 [00:02<00:00, 122.07it/s]
#
# Repairing epochs: 100%|██████████| 443/443 [00:03<00:00, 140.83it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:04,  1.84it/s]
#
#
# Fold:  20%|██        | 2/10 [00:01<00:04,  1.86it/s]
#
#
# Fold:  30%|███       | 3/10 [00:01<00:03,  1.88it/s]
#
#
# Fold:  40%|████      | 4/10 [00:02<00:03,  1.88it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:02<00:02,  1.89it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:03<00:02,  1.89it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:03<00:01,  1.90it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:04<00:01,  1.90it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:04<00:00,  1.90it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:05<00:00,  1.90it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:08<00:17,  8.64s/it]
#
# Repairing epochs:   0%|          | 0/443 [00:00<?, ?it/s]
#
# Repairing epochs:   3%|▎         | 14/443 [00:00<00:03, 127.36it/s]
#
# Repairing epochs:   7%|▋         | 32/443 [00:00<00:02, 137.52it/s]
#
# Repairing epochs:  11%|█         | 48/443 [00:00<00:02, 142.37it/s]
#
# Repairing epochs:  14%|█▍        | 62/443 [00:00<00:02, 141.36it/s]
#
# Repairing epochs:  17%|█▋        | 77/443 [00:00<00:02, 141.38it/s]
#
# Repairing epochs:  21%|██        | 91/443 [00:00<00:02, 137.23it/s]
#
# Repairing epochs:  24%|██▍       | 107/443 [00:00<00:02, 140.22it/s]
#
# Repairing epochs:  28%|██▊       | 125/443 [00:00<00:02, 150.01it/s]
#
# Repairing epochs:  32%|███▏      | 140/443 [00:00<00:02, 147.19it/s]
#
# Repairing epochs:  35%|███▍      | 155/443 [00:01<00:02, 141.01it/s]
#
# Repairing epochs:  38%|███▊      | 169/443 [00:01<00:02, 135.88it/s]
#
# Repairing epochs:  42%|████▏     | 188/443 [00:01<00:01, 146.24it/s]
#
# Repairing epochs:  46%|████▌     | 204/443 [00:01<00:01, 147.45it/s]
#
# Repairing epochs:  50%|████▉     | 221/443 [00:01<00:01, 151.90it/s]
#
# Repairing epochs:  53%|█████▎    | 237/443 [00:01<00:01, 140.03it/s]
#
# Repairing epochs:  57%|█████▋    | 252/443 [00:01<00:01, 141.61it/s]
#
# Repairing epochs:  60%|██████    | 267/443 [00:01<00:01, 132.00it/s]
#
# Repairing epochs:  64%|██████▍   | 283/443 [00:01<00:01, 138.90it/s]
#
# Repairing epochs:  67%|██████▋   | 298/443 [00:02<00:01, 141.34it/s]
#
# Repairing epochs:  71%|███████   | 313/443 [00:02<00:00, 138.91it/s]
#
# Repairing epochs:  74%|███████▍  | 329/443 [00:02<00:00, 144.07it/s]
#
# Repairing epochs:  78%|███████▊  | 344/443 [00:02<00:00, 145.70it/s]
#
# Repairing epochs:  81%|████████  | 359/443 [00:02<00:00, 141.10it/s]
#
# Repairing epochs:  84%|████████▍ | 374/443 [00:02<00:00, 132.57it/s]
#
# Repairing epochs:  88%|████████▊ | 388/443 [00:02<00:00, 126.12it/s]
#
# Repairing epochs:  91%|█████████ | 401/443 [00:02<00:00, 117.85it/s]
#
# Repairing epochs:  93%|█████████▎| 414/443 [00:02<00:00, 120.11it/s]
#
# Repairing epochs: 100%|██████████| 443/443 [00:03<00:00, 139.80it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:04,  1.93it/s]
#
#
# Fold:  20%|██        | 2/10 [00:01<00:04,  1.93it/s]
#
#
# Fold:  30%|███       | 3/10 [00:01<00:03,  1.93it/s]
#
#
# Fold:  40%|████      | 4/10 [00:02<00:03,  1.92it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:02<00:02,  1.91it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:03<00:02,  1.90it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:03<00:01,  1.90it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:04<00:01,  1.90it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:04<00:00,  1.90it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:05<00:00,  1.90it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:17<00:08,  8.63s/it]
#
# Repairing epochs:   0%|          | 0/443 [00:00<?, ?it/s]
#
# Repairing epochs:   3%|▎         | 12/443 [00:00<00:03, 117.31it/s]
#
# Repairing epochs:   6%|▌         | 27/443 [00:00<00:03, 124.77it/s]
#
# Repairing epochs:  10%|█         | 45/443 [00:00<00:02, 136.13it/s]
#
# Repairing epochs:  12%|█▏        | 55/443 [00:00<00:03, 120.96it/s]
#
# Repairing epochs:  16%|█▌        | 71/443 [00:00<00:02, 129.17it/s]
#
# Repairing epochs:  20%|█▉        | 88/443 [00:00<00:02, 138.13it/s]
#
# Repairing epochs:  23%|██▎       | 102/443 [00:00<00:02, 137.50it/s]
#
# Repairing epochs:  27%|██▋       | 120/443 [00:00<00:02, 147.44it/s]
#
# Repairing epochs:  30%|███       | 135/443 [00:00<00:02, 139.01it/s]
#
# Repairing epochs:  34%|███▍      | 151/443 [00:01<00:02, 142.79it/s]
#
# Repairing epochs:  37%|███▋      | 166/443 [00:01<00:02, 134.87it/s]
#
# Repairing epochs:  42%|████▏     | 184/443 [00:01<00:01, 144.30it/s]
#
# Repairing epochs:  45%|████▍     | 199/443 [00:01<00:01, 125.54it/s]
#
# Repairing epochs:  49%|████▉     | 217/443 [00:01<00:01, 135.99it/s]
#
# Repairing epochs:  52%|█████▏    | 232/443 [00:01<00:01, 129.93it/s]
#
# Repairing epochs:  56%|█████▌    | 246/443 [00:01<00:01, 127.65it/s]
#
# Repairing epochs:  59%|█████▉    | 261/443 [00:01<00:01, 131.31it/s]
#
# Repairing epochs:  63%|██████▎   | 277/443 [00:01<00:01, 138.32it/s]
#
# Repairing epochs:  66%|██████▌   | 292/443 [00:02<00:01, 132.16it/s]
#
# Repairing epochs:  69%|██████▉   | 307/443 [00:02<00:00, 136.61it/s]
#
# Repairing epochs:  72%|███████▏  | 321/443 [00:02<00:00, 131.56it/s]
#
# Repairing epochs:  77%|███████▋  | 339/443 [00:02<00:00, 141.44it/s]
#
# Repairing epochs:  80%|███████▉  | 354/443 [00:02<00:00, 136.86it/s]
#
# Repairing epochs:  83%|████████▎ | 368/443 [00:02<00:00, 128.19it/s]
#
# Repairing epochs:  86%|████████▌ | 382/443 [00:02<00:00, 128.87it/s]
#
# Repairing epochs:  89%|████████▉ | 396/443 [00:02<00:00, 120.12it/s]
#
# Repairing epochs:  92%|█████████▏| 409/443 [00:03<00:00, 120.40it/s]
#
# Repairing epochs:  95%|█████████▌| 423/443 [00:03<00:00, 123.55it/s]
#
# Repairing epochs: 100%|██████████| 443/443 [00:03<00:00, 134.30it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:02,  3.66it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:02,  3.67it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  3.68it/s]
#
#
# Fold:  40%|████      | 4/10 [00:01<00:01,  3.66it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:01<00:01,  3.67it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:01,  3.66it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  3.64it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:02<00:00,  3.63it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:02<00:00,  3.65it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:02<00:00,  3.65it/s]
#
# n_interp: 100%|██████████| 3/3 [00:23<00:00,  7.78s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 4 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
#
#
# Repairing epochs:   0%|          | 0/443 [00:00<?, ?it/s]
# Estimated consensus=0.10 and n_interpolate=4
# Repairing epochs:   3%|▎         | 13/443 [00:00<00:03, 118.96it/s]
#
# Repairing epochs:   7%|▋         | 30/443 [00:00<00:03, 130.14it/s]
#
# Repairing epochs:  11%|█         | 47/443 [00:00<00:02, 139.42it/s]
#
# Repairing epochs:  14%|█▎        | 60/443 [00:00<00:02, 134.26it/s]
#
# Repairing epochs:  17%|█▋        | 77/443 [00:00<00:02, 140.64it/s]
#
# Repairing epochs:  21%|██        | 91/443 [00:00<00:02, 140.14it/s]
#
# Repairing epochs:  24%|██▍       | 107/443 [00:00<00:02, 143.72it/s]
#
# Repairing epochs:  28%|██▊       | 125/443 [00:00<00:02, 152.06it/s]
#
# Repairing epochs:  32%|███▏      | 140/443 [00:00<00:02, 149.63it/s]
#
# Repairing epochs:  35%|███▍      | 155/443 [00:01<00:01, 144.38it/s]
#
# Repairing epochs:  38%|███▊      | 170/443 [00:01<00:01, 140.18it/s]
#
# Repairing epochs:  42%|████▏     | 188/443 [00:01<00:01, 147.54it/s]
#
# Repairing epochs:  46%|████▌     | 204/443 [00:01<00:01, 150.52it/s]
#
# Repairing epochs:  50%|████▉     | 221/443 [00:01<00:01, 153.60it/s]
#
# Repairing epochs:  53%|█████▎    | 237/443 [00:01<00:01, 143.46it/s]
#
# Repairing epochs:  57%|█████▋    | 252/443 [00:01<00:01, 144.34it/s]
#
# Repairing epochs:  60%|██████    | 267/443 [00:01<00:01, 133.78it/s]
#
# Repairing epochs:  63%|██████▎   | 281/443 [00:01<00:01, 133.28it/s]
#
# Repairing epochs:  67%|██████▋   | 296/443 [00:02<00:01, 137.12it/s]
#
# Repairing epochs:  70%|██████▉   | 310/443 [00:02<00:01, 132.61it/s]
#
# Repairing epochs:  73%|███████▎  | 324/443 [00:02<00:00, 129.10it/s]
#
# Repairing epochs:  77%|███████▋  | 343/443 [00:02<00:00, 141.12it/s]
#
# Repairing epochs:  81%|████████  | 358/443 [00:02<00:00, 143.58it/s]
#
# Repairing epochs:  84%|████████▍ | 373/443 [00:02<00:00, 130.76it/s]
#
# Repairing epochs:  87%|████████▋ | 387/443 [00:02<00:00, 124.17it/s]
#
# Repairing epochs:  90%|█████████ | 400/443 [00:02<00:00, 119.51it/s]
#
# Repairing epochs:  93%|█████████▎| 414/443 [00:02<00:00, 123.21it/s]
#
# Repairing epochs: 100%|██████████| 443/443 [00:03<00:00, 140.25it/s]
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Overwriting existing file.
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP09/VP09filt_raw.fif...
#     Range : 0 ... 1079154 =      0.000 ...  4316.616 secs
# Ready.
# Reading 0 ... 1079154  =      0.000 ...  4316.616 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '110', '111', '12', '154', '155', '157', '158', '160', '161', '162', '163', '165', '167', '169', '17', '170', '171', '172', '173', '174', '175', '177', '179', '181', '188', '192', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '243', '251', '252', '253', '3', '4', '5', '6', '62', '68', '7', '74', '80', '86', '9', '92', '98', '99']
# Overwriting existing file.
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 3 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:  10%|▉         | 6/61 [00:00<00:00, 57.10it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 61/61 [00:01<00:00, 53.30it/s]
# Computing thresholds ...: 100%|██████████| 61/61 [00:13<00:00,  4.40it/s]
#
#
# Repairing epochs:   0%|          | 0/246 [00:00<?, ?it/s]
#
# Repairing epochs:  17%|█▋        | 42/246 [00:00<00:00, 413.31it/s]
#
# Repairing epochs:  33%|███▎      | 81/246 [00:00<00:00, 405.91it/s]
#
# Repairing epochs:  49%|████▉     | 120/246 [00:00<00:00, 400.59it/s]
#
# Repairing epochs:  65%|██████▌   | 160/246 [00:00<00:00, 399.81it/s]
#
# Repairing epochs:  82%|████████▏ | 201/246 [00:00<00:00, 402.58it/s]
#
# Repairing epochs: 100%|██████████| 246/246 [00:00<00:00, 395.09it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/246 [00:00<?, ?it/s]
#
# Repairing epochs:   4%|▍         | 11/246 [00:00<00:02, 103.44it/s]
#
# Repairing epochs:   9%|▉         | 22/246 [00:00<00:02, 103.98it/s]
#
# Repairing epochs:  13%|█▎        | 32/246 [00:00<00:02, 101.48it/s]
#
# Repairing epochs:  17%|█▋        | 42/246 [00:00<00:02, 99.92it/s]
#
# Repairing epochs:  22%|██▏       | 54/246 [00:00<00:01, 104.72it/s]
#
# Repairing epochs:  26%|██▋       | 65/246 [00:00<00:01, 103.55it/s]
#
# Repairing epochs:  30%|███       | 75/246 [00:00<00:01, 101.28it/s]
#
# Repairing epochs:  35%|███▍      | 86/246 [00:00<00:01, 101.48it/s]
#
# Repairing epochs:  39%|███▉      | 96/246 [00:00<00:01, 98.24it/s]
#
# Repairing epochs:  44%|████▍     | 109/246 [00:01<00:01, 104.14it/s]
#
# Repairing epochs:  49%|████▉     | 120/246 [00:01<00:01, 102.33it/s]
#
# Repairing epochs:  53%|█████▎    | 131/246 [00:01<00:01, 101.03it/s]
#
# Repairing epochs:  58%|█████▊    | 142/246 [00:01<00:01, 99.46it/s]
#
# Repairing epochs:  62%|██████▏   | 153/246 [00:01<00:00, 100.21it/s]
#
# Repairing epochs:  66%|██████▋   | 163/246 [00:01<00:00, 97.96it/s]
#
# Repairing epochs:  70%|███████   | 173/246 [00:01<00:00, 96.17it/s]
#
# Repairing epochs:  74%|███████▍  | 183/246 [00:01<00:00, 93.70it/s]
#
# Repairing epochs:  78%|███████▊  | 193/246 [00:01<00:00, 92.38it/s]
#
# Repairing epochs:  83%|████████▎ | 203/246 [00:02<00:00, 91.92it/s]
#
# Repairing epochs:  87%|████████▋ | 213/246 [00:02<00:00, 91.42it/s]
#
# Repairing epochs:  91%|█████████ | 223/246 [00:02<00:00, 93.60it/s]
#
# Repairing epochs:  95%|█████████▌| 234/246 [00:02<00:00, 96.52it/s]
#
# Repairing epochs: 100%|██████████| 246/246 [00:02<00:00, 98.23it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:02,  3.35it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:02,  3.37it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:02,  3.38it/s]
#
#
# Fold:  40%|████      | 4/10 [00:01<00:01,  3.42it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:01<00:01,  3.44it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:01,  3.45it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:02<00:00,  3.38it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:02<00:00,  3.35it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:02<00:00,  3.34it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:02<00:00,  3.37it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:05<00:11,  5.69s/it]
#
# Repairing epochs:   0%|          | 0/246 [00:00<?, ?it/s]
#
# Repairing epochs:   4%|▍         | 11/246 [00:00<00:02, 101.17it/s]
#
# Repairing epochs:   9%|▊         | 21/246 [00:00<00:02, 100.23it/s]
#
# Repairing epochs:  12%|█▏        | 29/246 [00:00<00:02, 92.31it/s]
#
# Repairing epochs:  16%|█▌        | 39/246 [00:00<00:02, 93.73it/s]
#
# Repairing epochs:  20%|█▉        | 49/246 [00:00<00:02, 95.25it/s]
#
# Repairing epochs:  25%|██▍       | 61/246 [00:00<00:01, 99.99it/s]
#
# Repairing epochs:  28%|██▊       | 70/246 [00:00<00:01, 92.54it/s]
#
# Repairing epochs:  32%|███▏      | 79/246 [00:00<00:02, 79.82it/s]
#
# Repairing epochs:  36%|███▌      | 88/246 [00:00<00:01, 81.94it/s]
#
# Repairing epochs:  39%|███▉      | 97/246 [00:01<00:01, 76.29it/s]
#
# Repairing epochs:  44%|████▍     | 109/246 [00:01<00:01, 84.91it/s]
#
# Repairing epochs:  48%|████▊     | 119/246 [00:01<00:01, 88.58it/s]
#
# Repairing epochs:  52%|█████▏    | 129/246 [00:01<00:01, 90.99it/s]
#
# Repairing epochs:  57%|█████▋    | 141/246 [00:01<00:01, 96.22it/s]
#
# Repairing epochs:  61%|██████▏   | 151/246 [00:01<00:00, 96.56it/s]
#
# Repairing epochs:  65%|██████▌   | 161/246 [00:01<00:00, 97.41it/s]
#
# Repairing epochs:  70%|██████▉   | 172/246 [00:01<00:00, 99.56it/s]
#
# Repairing epochs:  74%|███████▍  | 183/246 [00:01<00:00, 100.01it/s]
#
# Repairing epochs:  79%|███████▉  | 194/246 [00:02<00:00, 97.43it/s]
#
# Repairing epochs:  83%|████████▎ | 205/246 [00:02<00:00, 99.42it/s]
#
# Repairing epochs:  87%|████████▋ | 215/246 [00:02<00:00, 99.04it/s]
#
# Repairing epochs:  91%|█████████▏| 225/246 [00:02<00:00, 97.71it/s]
#
# Repairing epochs: 100%|██████████| 246/246 [00:02<00:00, 94.64it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:02,  3.63it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:02,  3.57it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  3.50it/s]
#
#
# Fold:  40%|████      | 4/10 [00:01<00:01,  3.47it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:01<00:01,  3.49it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:01,  3.48it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:02<00:00,  3.46it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:02<00:00,  3.47it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:02<00:00,  3.48it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:02<00:00,  3.46it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:11<00:05,  5.68s/it]
#
# Repairing epochs:   0%|          | 0/246 [00:00<?, ?it/s]
#
# Repairing epochs:   4%|▍         | 10/246 [00:00<00:02, 98.81it/s]
#
# Repairing epochs:   8%|▊         | 20/246 [00:00<00:02, 97.28it/s]
#
# Repairing epochs:  12%|█▏        | 30/246 [00:00<00:02, 96.83it/s]
#
# Repairing epochs:  17%|█▋        | 41/246 [00:00<00:02, 98.30it/s]
#
# Repairing epochs:  21%|██        | 51/246 [00:00<00:02, 97.31it/s]
#
# Repairing epochs:  26%|██▌       | 63/246 [00:00<00:01, 100.97it/s]
#
# Repairing epochs:  30%|███       | 74/246 [00:00<00:01, 101.53it/s]
#
# Repairing epochs:  34%|███▍      | 84/246 [00:00<00:01, 95.01it/s]
#
# Repairing epochs:  38%|███▊      | 94/246 [00:00<00:01, 95.64it/s]
#
# Repairing epochs:  43%|████▎     | 107/246 [00:01<00:01, 101.92it/s]
#
# Repairing epochs:  48%|████▊     | 118/246 [00:01<00:01, 102.38it/s]
#
# Repairing epochs:  52%|█████▏    | 129/246 [00:01<00:01, 102.03it/s]
#
# Repairing epochs:  57%|█████▋    | 141/246 [00:01<00:01, 104.77it/s]
#
# Repairing epochs:  62%|██████▏   | 152/246 [00:01<00:00, 99.67it/s]
#
# Repairing epochs:  66%|██████▋   | 163/246 [00:01<00:00, 95.34it/s]
#
# Repairing epochs:  70%|███████   | 173/246 [00:01<00:00, 93.64it/s]
#
# Repairing epochs:  74%|███████▍  | 183/246 [00:01<00:00, 92.17it/s]
#
# Repairing epochs:  78%|███████▊  | 193/246 [00:01<00:00, 94.37it/s]
#
# Repairing epochs:  83%|████████▎ | 203/246 [00:02<00:00, 95.92it/s]
#
# Repairing epochs:  87%|████████▋ | 213/246 [00:02<00:00, 96.14it/s]
#
# Repairing epochs:  91%|█████████ | 223/246 [00:02<00:00, 95.24it/s]
#
# Repairing epochs:  95%|█████████▍| 233/246 [00:02<00:00, 96.20it/s]
#
# Repairing epochs: 100%|██████████| 246/246 [00:02<00:00, 97.40it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  6.55it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  6.51it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  6.50it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  6.53it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  6.47it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  6.48it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  6.43it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  6.38it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  6.33it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  6.38it/s]
#
# n_interp: 100%|██████████| 3/3 [00:15<00:00,  5.16s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 3 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
#
#
# Repairing epochs:   0%|          | 0/246 [00:00<?, ?it/s]
#
# Repairing epochs:   4%|▍         | 10/246 [00:00<00:02, 99.17it/s]
# Estimated consensus=0.60 and n_interpolate=32
# Repairing epochs:   8%|▊         | 20/246 [00:00<00:02, 98.67it/s]
#
# Repairing epochs:  13%|█▎        | 31/246 [00:00<00:02, 100.80it/s]
#
# Repairing epochs:  17%|█▋        | 41/246 [00:00<00:02, 100.35it/s]
#
# Repairing epochs:  21%|██        | 52/246 [00:00<00:01, 102.60it/s]
#
# Repairing epochs:  26%|██▌       | 63/246 [00:00<00:01, 103.33it/s]
#
# Repairing epochs:  30%|██▉       | 73/246 [00:00<00:01, 101.86it/s]
#
# Repairing epochs:  34%|███▍      | 84/246 [00:00<00:01, 103.20it/s]
#
# Repairing epochs:  38%|███▊      | 94/246 [00:00<00:01, 99.83it/s]
#
# Repairing epochs:  43%|████▎     | 105/246 [00:01<00:01, 101.38it/s]
#
# Repairing epochs:  47%|████▋     | 115/246 [00:01<00:01, 98.88it/s]
#
# Repairing epochs:  51%|█████     | 126/246 [00:01<00:01, 100.05it/s]
#
# Repairing epochs:  56%|█████▌    | 138/246 [00:01<00:01, 104.55it/s]
#
# Repairing epochs:  61%|██████    | 149/246 [00:01<00:00, 102.73it/s]
#
# Repairing epochs:  65%|██████▌   | 160/246 [00:01<00:00, 99.54it/s]
#
# Repairing epochs:  69%|██████▉   | 170/246 [00:01<00:00, 97.37it/s]
#
# Repairing epochs:  74%|███████▎  | 181/246 [00:01<00:00, 98.61it/s]
#
# Repairing epochs:  78%|███████▊  | 192/246 [00:01<00:00, 99.56it/s]
#
# Repairing epochs:  82%|████████▏ | 202/246 [00:02<00:00, 96.92it/s]
#
# Repairing epochs:  87%|████████▋ | 213/246 [00:02<00:00, 99.59it/s]
#
# Repairing epochs:  91%|█████████ | 224/246 [00:02<00:00, 101.20it/s]
#
# Repairing epochs:  96%|█████████▌| 235/246 [00:02<00:00, 102.87it/s]
#
# Repairing epochs: 100%|██████████| 246/246 [00:02<00:00, 100.75it/s]
# No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Overwriting existing file.
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP10/VP10filt_raw.fif...
#     Range : 0 ... 1046095 =      0.000 ...  4184.380 secs
# Ready.
# Reading 0 ... 1046095  =      0.000 ...  4184.380 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '12', '17', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '243', '251', '252', '253', '255', '3', '4', '5', '6', '62', '68', '7', '74', '80', '86', '9', '92', '98', '99']
# Overwriting existing file.
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 3 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:  11%|█▏        | 7/61 [00:00<00:00, 67.40it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 61/61 [00:00<00:00, 70.66it/s]
# Computing thresholds ...: 100%|██████████| 61/61 [00:10<00:00,  6.00it/s]
#
#
# Repairing epochs:   0%|          | 0/135 [00:00<?, ?it/s]
#
# Repairing epochs:  32%|███▏      | 43/135 [00:00<00:00, 426.99it/s]
#
# Repairing epochs:  63%|██████▎   | 85/135 [00:00<00:00, 422.64it/s]
#
# Repairing epochs: 100%|██████████| 135/135 [00:00<00:00, 410.67it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/135 [00:00<?, ?it/s]
#
# Repairing epochs:  10%|▉         | 13/135 [00:00<00:00, 124.87it/s]
#
# Repairing epochs:  20%|██        | 27/135 [00:00<00:00, 126.59it/s]
#
# Repairing epochs:  29%|██▉       | 39/135 [00:00<00:00, 123.80it/s]
#
# Repairing epochs:  39%|███▊      | 52/135 [00:00<00:00, 125.55it/s]
#
# Repairing epochs:  47%|████▋     | 64/135 [00:00<00:00, 120.72it/s]
#
# Repairing epochs:  56%|█████▌    | 75/135 [00:00<00:00, 115.04it/s]
#
# Repairing epochs:  65%|██████▌   | 88/135 [00:00<00:00, 117.68it/s]
#
# Repairing epochs:  73%|███████▎  | 99/135 [00:00<00:00, 115.08it/s]
#
# Repairing epochs:  82%|████████▏ | 111/135 [00:00<00:00, 115.20it/s]
#
# Repairing epochs:  91%|█████████ | 123/135 [00:01<00:00, 112.22it/s]
#
# Repairing epochs: 100%|██████████| 135/135 [00:01<00:00, 114.76it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  6.42it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  6.11it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  6.15it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  6.14it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  6.22it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  6.24it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  6.25it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  6.26it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  6.28it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  6.20it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:02<00:05,  2.89s/it]
#
# Repairing epochs:   0%|          | 0/135 [00:00<?, ?it/s]
#
# Repairing epochs:  10%|▉         | 13/135 [00:00<00:00, 129.07it/s]
#
# Repairing epochs:  19%|█▉        | 26/135 [00:00<00:00, 129.08it/s]
#
# Repairing epochs:  27%|██▋       | 37/135 [00:00<00:00, 120.96it/s]
#
# Repairing epochs:  38%|███▊      | 51/135 [00:00<00:00, 123.90it/s]
#
# Repairing epochs:  47%|████▋     | 63/135 [00:00<00:00, 119.85it/s]
#
# Repairing epochs:  54%|█████▍    | 73/135 [00:00<00:00, 111.81it/s]
#
# Repairing epochs:  63%|██████▎   | 85/135 [00:00<00:00, 112.30it/s]
#
# Repairing epochs:  72%|███████▏  | 97/135 [00:00<00:00, 112.08it/s]
#
# Repairing epochs:  81%|████████  | 109/135 [00:00<00:00, 113.92it/s]
#
# Repairing epochs:  89%|████████▉ | 120/135 [00:01<00:00, 111.92it/s]
#
# Repairing epochs: 100%|██████████| 135/135 [00:01<00:00, 112.81it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  6.63it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  6.62it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  6.53it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00,  6.50it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  6.44it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00,  6.42it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  6.44it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  6.42it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  6.36it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  6.40it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:05<00:02,  2.90s/it]
#
# Repairing epochs:   0%|          | 0/135 [00:00<?, ?it/s]
#
# Repairing epochs:  10%|█         | 14/135 [00:00<00:00, 130.92it/s]
#
# Repairing epochs:  20%|██        | 27/135 [00:00<00:00, 130.58it/s]
#
# Repairing epochs:  30%|██▉       | 40/135 [00:00<00:00, 127.82it/s]
#
# Repairing epochs:  40%|████      | 54/135 [00:00<00:00, 129.91it/s]
#
# Repairing epochs:  48%|████▊     | 65/135 [00:00<00:00, 120.49it/s]
#
# Repairing epochs:  56%|█████▋    | 76/135 [00:00<00:00, 114.93it/s]
#
# Repairing epochs:  65%|██████▌   | 88/135 [00:00<00:00, 114.52it/s]
#
# Repairing epochs:  73%|███████▎  | 99/135 [00:00<00:00, 110.85it/s]
#
# Repairing epochs:  82%|████████▏ | 111/135 [00:00<00:00, 113.06it/s]
#
# Repairing epochs:  90%|█████████ | 122/135 [00:01<00:00, 110.40it/s]
#
# Repairing epochs: 100%|██████████| 135/135 [00:01<00:00, 112.41it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:00, 13.13it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00, 12.90it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00, 12.84it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00, 12.53it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:00<00:00, 12.34it/s]
#
# n_interp: 100%|██████████| 3/3 [00:07<00:00,  2.63s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 3 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
#
#
# Repairing epochs:   0%|          | 0/135 [00:00<?, ?it/s]
#
# Repairing epochs:  10%|▉         | 13/135 [00:00<00:00, 124.88it/s]
# Estimated consensus=0.20 and n_interpolate=4
# Repairing epochs:  19%|█▊        | 25/135 [00:00<00:00, 122.26it/s]
#
# Repairing epochs:  28%|██▊       | 38/135 [00:00<00:00, 122.15it/s]
#
# Repairing epochs:  39%|███▊      | 52/135 [00:00<00:00, 125.95it/s]
#
# Repairing epochs:  47%|████▋     | 64/135 [00:00<00:00, 123.82it/s]
#
# Repairing epochs:  56%|█████▌    | 75/135 [00:00<00:00, 116.20it/s]
#
# Repairing epochs:  65%|██████▌   | 88/135 [00:00<00:00, 118.23it/s]
#
# Repairing epochs:  73%|███████▎  | 99/135 [00:00<00:00, 115.30it/s]
#
# Repairing epochs:  82%|████████▏ | 111/135 [00:00<00:00, 116.63it/s]
#
# Repairing epochs:  91%|█████████ | 123/135 [00:01<00:00, 114.06it/s]
#
# Repairing epochs: 100%|██████████| 135/135 [00:01<00:00, 116.10it/s]
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Overwriting existing file.
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP11/VP11filt_raw.fif...
#     Range : 0 ... 1018724 =      0.000 ...  4074.896 secs
# Ready.
# Reading 0 ... 1018724  =      0.000 ...  4074.896 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '12', '17', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '243', '251', '252', '253', '255', '3', '4', '5', '6', '62', '68', '7', '74', '8', '80', '86', '9', '92', '98', '99']
# Overwriting existing file.
# Creating augmented epochs:  12%|█▎        | 8/64 [00:00<00:00, 76.18it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 64/64 [00:00<00:00, 80.06it/s]
# Computing thresholds ...: 100%|██████████| 64/64 [00:10<00:00,  6.18it/s]
#
#
# Repairing epochs:   0%|          | 0/145 [00:00<?, ?it/s]
#
# Repairing epochs:  30%|██▉       | 43/145 [00:00<00:00, 423.12it/s]
#
# Repairing epochs:  59%|█████▊    | 85/145 [00:00<00:00, 421.26it/s]
#
# Repairing epochs: 100%|██████████| 145/145 [00:00<00:00, 412.26it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/145 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 11/145 [00:00<00:01, 102.47it/s]
#
# Repairing epochs:  16%|█▌        | 23/145 [00:00<00:01, 105.60it/s]
#
# Repairing epochs:  23%|██▎       | 34/145 [00:00<00:01, 105.05it/s]
#
# Repairing epochs:  31%|███       | 45/145 [00:00<00:00, 105.61it/s]
#
# Repairing epochs:  39%|███▊      | 56/145 [00:00<00:00, 105.03it/s]
#
# Repairing epochs:  46%|████▌     | 67/145 [00:00<00:00, 103.95it/s]
#
# Repairing epochs:  54%|█████▍    | 78/145 [00:00<00:00, 104.98it/s]
#
# Repairing epochs:  61%|██████    | 88/145 [00:00<00:00, 102.92it/s]
#
# Repairing epochs:  68%|██████▊   | 99/145 [00:00<00:00, 104.04it/s]
#
# Repairing epochs:  76%|███████▌  | 110/145 [00:01<00:00, 102.66it/s]
#
# Repairing epochs:  83%|████████▎ | 121/145 [00:01<00:00, 103.58it/s]
#
# Repairing epochs:  91%|█████████ | 132/145 [00:01<00:00, 103.36it/s]
#
# Repairing epochs: 100%|██████████| 145/145 [00:01<00:00, 102.26it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  5.98it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  5.97it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  5.95it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:01,  5.93it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  5.94it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:00,  5.88it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  5.87it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  5.85it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  5.78it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  5.84it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:03<00:06,  3.25s/it]
#
# Repairing epochs:   0%|          | 0/145 [00:00<?, ?it/s]
#
# Repairing epochs:   7%|▋         | 10/145 [00:00<00:01, 98.30it/s]
#
# Repairing epochs:  15%|█▌        | 22/145 [00:00<00:01, 101.72it/s]
#
# Repairing epochs:  22%|██▏       | 32/145 [00:00<00:01, 100.59it/s]
#
# Repairing epochs:  30%|██▉       | 43/145 [00:00<00:01, 101.10it/s]
#
# Repairing epochs:  37%|███▋      | 53/145 [00:00<00:00, 99.90it/s]
#
# Repairing epochs:  43%|████▎     | 63/145 [00:00<00:00, 99.30it/s]
#
# Repairing epochs:  50%|█████     | 73/145 [00:00<00:00, 97.84it/s]
#
# Repairing epochs:  57%|█████▋    | 82/145 [00:00<00:00, 93.09it/s]
#
# Repairing epochs:  63%|██████▎   | 92/145 [00:00<00:00, 94.07it/s]
#
# Repairing epochs:  70%|███████   | 102/145 [00:01<00:00, 95.58it/s]
#
# Repairing epochs:  78%|███████▊  | 113/145 [00:01<00:00, 97.03it/s]
#
# Repairing epochs:  85%|████████▍ | 123/145 [00:01<00:00, 96.55it/s]
#
# Repairing epochs:  92%|█████████▏| 133/145 [00:01<00:00, 95.54it/s]
#
# Repairing epochs: 100%|██████████| 145/145 [00:01<00:00, 96.57it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  6.08it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  6.06it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  6.01it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:01,  5.98it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  5.89it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:00,  5.64it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  5.64it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  5.65it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  5.70it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  5.74it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:06<00:03,  3.29s/it]
#
# Repairing epochs:   0%|          | 0/145 [00:00<?, ?it/s]
#
# Repairing epochs:   7%|▋         | 10/145 [00:00<00:01, 91.70it/s]
#
# Repairing epochs:  15%|█▌        | 22/145 [00:00<00:01, 98.27it/s]
#
# Repairing epochs:  22%|██▏       | 32/145 [00:00<00:01, 96.68it/s]
#
# Repairing epochs:  30%|██▉       | 43/145 [00:00<00:01, 99.50it/s]
#
# Repairing epochs:  37%|███▋      | 53/145 [00:00<00:00, 97.70it/s]
#
# Repairing epochs:  44%|████▍     | 64/145 [00:00<00:00, 100.04it/s]
#
# Repairing epochs:  52%|█████▏    | 75/145 [00:00<00:00, 101.07it/s]
#
# Repairing epochs:  59%|█████▊    | 85/145 [00:00<00:00, 99.84it/s]
#
# Repairing epochs:  66%|██████▌   | 95/145 [00:00<00:00, 94.62it/s]
#
# Repairing epochs:  72%|███████▏  | 105/145 [00:01<00:00, 80.32it/s]
#
# Repairing epochs:  80%|████████  | 116/145 [00:01<00:00, 86.31it/s]
#
# Repairing epochs:  86%|████████▌ | 125/145 [00:01<00:00, 86.49it/s]
#
# Repairing epochs:  93%|█████████▎| 135/145 [00:01<00:00, 89.64it/s]
#
# Repairing epochs: 100%|██████████| 145/145 [00:01<00:00, 93.59it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:00, 11.75it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00, 11.61it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00, 11.48it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00, 11.29it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:00<00:00, 11.23it/s]
#
# n_interp: 100%|██████████| 3/3 [00:09<00:00,  3.06s/it]
#
#
# Repairing epochs:   0%|          | 0/145 [00:00<?, ?it/s]
#
# Repairing epochs:   7%|▋         | 10/145 [00:00<00:01, 93.16it/s]
# Estimated consensus=0.80 and n_interpolate=32
# Repairing epochs:  14%|█▍        | 21/145 [00:00<00:01, 97.33it/s]
#
# Repairing epochs:  21%|██▏       | 31/145 [00:00<00:01, 97.04it/s]
#
# Repairing epochs:  29%|██▉       | 42/145 [00:00<00:01, 99.77it/s]
#
# Repairing epochs:  36%|███▌      | 52/145 [00:00<00:00, 99.19it/s]
#
# Repairing epochs:  43%|████▎     | 63/145 [00:00<00:00, 101.01it/s]
#
# Repairing epochs:  51%|█████     | 74/145 [00:00<00:00, 103.03it/s]
#
# Repairing epochs:  58%|█████▊    | 84/145 [00:00<00:00, 100.64it/s]
#
# Repairing epochs:  65%|██████▍   | 94/145 [00:00<00:00, 99.36it/s]
#
# Repairing epochs:  72%|███████▏  | 105/145 [00:01<00:00, 100.30it/s]
#
# Repairing epochs:  80%|████████  | 116/145 [00:01<00:00, 102.31it/s]
#
# Repairing epochs:  88%|████████▊ | 127/145 [00:01<00:00, 100.66it/s]
#
# Repairing epochs: 100%|██████████| 145/145 [00:01<00:00, 100.57it/s]
# No bad epochs were found for your data. Returning a copy of the data you wanted to clean. Interpolation may have been done.
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Overwriting existing file.
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP12/VP12filt_raw.fif...
#     Range : 0 ... 326222 =      0.000 ...  1304.888 secs
# Ready.
# Reading 0 ... 326222  =      0.000 ...  1304.888 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '111', '12', '168', '17', '177', '185', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '238', '239', '243', '251', '252', '253', '255', '3', '4', '5', '6', '74', '8', '80', '86', '9', '92', '99']
# Overwriting existing file.
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 3 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:  18%|█▊        | 11/61 [00:00<00:00, 107.13it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 61/61 [00:00<00:00, 107.03it/s]
# Computing thresholds ...: 100%|██████████| 61/61 [00:06<00:00,  8.76it/s]
#
#
# Repairing epochs:   0%|          | 0/45 [00:00<?, ?it/s]
#
# Repairing epochs: 100%|██████████| 45/45 [00:00<00:00, 393.35it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/45 [00:00<?, ?it/s]
#
# Repairing epochs:  31%|███       | 14/45 [00:00<00:00, 133.80it/s]
#
# Repairing epochs:  53%|█████▎    | 24/45 [00:00<00:00, 119.26it/s]
#
# Repairing epochs: 100%|██████████| 45/45 [00:00<00:00, 110.45it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:00, 25.43it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00, 24.71it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:00<00:00, 23.03it/s][A
#
# n_interp:  33%|███▎      | 1/3 [00:00<00:01,  1.12it/s]
#
# Repairing epochs:   0%|          | 0/45 [00:00<?, ?it/s]
#
# Repairing epochs:  27%|██▋       | 12/45 [00:00<00:00, 114.46it/s]
#
# Repairing epochs:  51%|█████     | 23/45 [00:00<00:00, 111.38it/s]
#
# Repairing epochs: 100%|██████████| 45/45 [00:00<00:00, 109.21it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:00, 25.19it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00, 24.45it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:00<00:00, 22.84it/s][A
#
# n_interp:  67%|██████▋   | 2/3 [00:01<00:00,  1.12it/s]
#
# Repairing epochs:   0%|          | 0/45 [00:00<?, ?it/s]
#
# Repairing epochs:  29%|██▉       | 13/45 [00:00<00:00, 128.61it/s]
#
# Repairing epochs:  53%|█████▎    | 24/45 [00:00<00:00, 119.17it/s]
#
# Repairing epochs: 100%|██████████| 45/45 [00:00<00:00, 111.96it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:00<00:00, 46.30it/s][A
#
# n_interp: 100%|██████████| 3/3 [00:02<00:00,  1.23it/s]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 3 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
#
#
# Repairing epochs:   0%|          | 0/45 [00:00<?, ?it/s]
#
# Repairing epochs:  29%|██▉       | 13/45 [00:00<00:00, 122.14it/s]
# Estimated consensus=0.20 and n_interpolate=4
# Repairing epochs:  51%|█████     | 23/45 [00:00<00:00, 111.77it/s]
#
# Repairing epochs: 100%|██████████| 45/45 [00:00<00:00, 108.19it/s]
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Overwriting existing file.
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP13/VP13filt_raw.fif...
#     Range : 0 ... 1297618 =      0.000 ...  5190.472 secs
# Ready.
# Reading 0 ... 1297618  =      0.000 ...  5190.472 secs...
# ...
#
# Repairing epochs:  50%|████▉     | 242/485 [00:02<00:02, 106.64it/s]
#
# Repairing epochs:  52%|█████▏    | 253/485 [00:02<00:02, 107.45it/s]
#
# Repairing epochs:  55%|█████▍    | 265/485 [00:02<00:02, 109.35it/s]
#
# Repairing epochs:  57%|█████▋    | 278/485 [00:02<00:01, 114.62it/s]
#
# Repairing epochs:  60%|██████    | 291/485 [00:02<00:01, 116.30it/s]
#
# Repairing epochs:  62%|██████▏   | 303/485 [00:02<00:01, 115.20it/s]
#
# Repairing epochs:  65%|██████▍   | 315/485 [00:02<00:01, 115.09it/s]
#
# Repairing epochs:  67%|██████▋   | 327/485 [00:02<00:01, 114.09it/s]
#
# Repairing epochs:  70%|██████▉   | 339/485 [00:03<00:01, 113.38it/s]
#
# Repairing epochs:  72%|███████▏  | 351/485 [00:03<00:01, 113.23it/s]
#
# Repairing epochs:  75%|███████▍  | 363/485 [00:03<00:01, 113.25it/s]
#
# Repairing epochs:  77%|███████▋  | 375/485 [00:03<00:00, 114.81it/s]
#
# Repairing epochs:  80%|███████▉  | 387/485 [00:03<00:00, 113.97it/s]
#
# Repairing epochs:  82%|████████▏ | 399/485 [00:03<00:00, 112.80it/s]
#
# Repairing epochs:  85%|████████▍ | 411/485 [00:03<00:00, 114.80it/s]
#
# Repairing epochs:  87%|████████▋ | 423/485 [00:03<00:00, 113.38it/s]
#
# Repairing epochs:  90%|████████▉ | 435/485 [00:03<00:00, 109.10it/s]
#
# Repairing epochs:  92%|█████████▏| 446/485 [00:04<00:00, 101.81it/s]
#
# Repairing epochs:  94%|█████████▍| 457/485 [00:04<00:00, 99.50it/s]
#
# Repairing epochs:  96%|█████████▋| 468/485 [00:04<00:00, 100.25it/s]
#
# Repairing epochs: 100%|██████████| 485/485 [00:04<00:00, 108.99it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:04,  1.82it/s]
#
#
# Fold:  20%|██        | 2/10 [00:01<00:04,  1.81it/s]
#
#
# Fold:  30%|███       | 3/10 [00:01<00:03,  1.80it/s]
#
#
# Fold:  40%|████      | 4/10 [00:02<00:03,  1.74it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:02<00:02,  1.76it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:03<00:02,  1.79it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:03<00:01,  1.81it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:04<00:01,  1.82it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:05<00:00,  1.83it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:05<00:00,  1.80it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:20<00:10, 10.10s/it]
#
# Repairing epochs:   0%|          | 0/485 [00:00<?, ?it/s]
#
# Repairing epochs:   2%|▏         | 12/485 [00:00<00:04, 112.38it/s]
#
# Repairing epochs:   5%|▍         | 24/485 [00:00<00:04, 112.39it/s]
#
# Repairing epochs:   7%|▋         | 36/485 [00:00<00:03, 112.40it/s]
#
# Repairing epochs:   9%|▉         | 44/485 [00:00<00:04, 92.29it/s]
#
# Repairing epochs:  11%|█         | 53/485 [00:00<00:04, 90.91it/s]
#
# Repairing epochs:  13%|█▎        | 65/485 [00:00<00:04, 96.36it/s]
#
# Repairing epochs:  16%|█▌        | 77/485 [00:00<00:04, 100.59it/s]
#
# Repairing epochs:  18%|█▊        | 89/485 [00:00<00:03, 103.44it/s]
#
# Repairing epochs:  21%|██        | 101/485 [00:00<00:03, 105.70it/s]
#
# Repairing epochs:  23%|██▎       | 112/485 [00:01<00:03, 106.19it/s]
#
# Repairing epochs:  25%|██▌       | 123/485 [00:01<00:03, 107.16it/s]
#
# Repairing epochs:  28%|██▊       | 135/485 [00:01<00:03, 108.33it/s]
#
# Repairing epochs:  30%|███       | 147/485 [00:01<00:03, 109.59it/s]
#
# Repairing epochs:  33%|███▎      | 158/485 [00:01<00:03, 106.51it/s]
#
# Repairing epochs:  35%|███▍      | 169/485 [00:01<00:02, 107.10it/s]
#
# Repairing epochs:  37%|███▋      | 181/485 [00:01<00:02, 109.17it/s]
#
# Repairing epochs:  40%|███▉      | 193/485 [00:01<00:02, 109.99it/s]
#
# Repairing epochs:  42%|████▏     | 205/485 [00:01<00:02, 110.41it/s]
#
# Repairing epochs:  45%|████▍     | 217/485 [00:02<00:02, 110.78it/s]
#
# Repairing epochs:  47%|████▋     | 229/485 [00:02<00:02, 110.08it/s]
#
# Repairing epochs:  50%|████▉     | 242/485 [00:02<00:02, 115.20it/s]
#
# Repairing epochs:  52%|█████▏    | 254/485 [00:02<00:02, 115.47it/s]
#
# Repairing epochs:  55%|█████▍    | 266/485 [00:02<00:01, 110.09it/s]
#
# Repairing epochs:  58%|█████▊    | 279/485 [00:02<00:01, 114.91it/s]
#
# Repairing epochs:  60%|██████    | 292/485 [00:02<00:01, 116.65it/s]
#
# Repairing epochs:  63%|██████▎   | 304/485 [00:02<00:01, 114.88it/s]
#
# Repairing epochs:  65%|██████▌   | 316/485 [00:02<00:01, 109.97it/s]
#
# Repairing epochs:  68%|██████▊   | 328/485 [00:03<00:01, 108.18it/s]
#
# Repairing epochs:  70%|██████▉   | 339/485 [00:03<00:01, 105.93it/s]
#
# Repairing epochs:  72%|███████▏  | 350/485 [00:03<00:01, 105.73it/s]
#
# Repairing epochs:  74%|███████▍  | 361/485 [00:03<00:01, 105.67it/s]
#
# Repairing epochs:  77%|███████▋  | 373/485 [00:03<00:01, 107.83it/s]
#
# Repairing epochs:  79%|███████▉  | 384/485 [00:03<00:00, 105.63it/s]
#
# Repairing epochs:  81%|████████▏ | 395/485 [00:03<00:00, 105.61it/s]
#
# Repairing epochs:  84%|████████▎ | 406/485 [00:03<00:00, 105.97it/s]
#
# Repairing epochs:  86%|████████▌ | 417/485 [00:03<00:00, 105.09it/s]
#
# Repairing epochs:  88%|████████▊ | 428/485 [00:03<00:00, 104.91it/s]
#
# Repairing epochs:  91%|█████████ | 439/485 [00:04<00:00, 94.20it/s]
#
# Repairing epochs:  93%|█████████▎| 449/485 [00:04<00:00, 94.23it/s]
#
# Repairing epochs:  95%|█████████▌| 461/485 [00:04<00:00, 99.28it/s]
#
# Repairing epochs:  97%|█████████▋| 472/485 [00:04<00:00, 102.00it/s]
#
# Repairing epochs: 100%|██████████| 485/485 [00:04<00:00, 106.72it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:02,  3.94it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:02,  3.93it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  3.93it/s]
#
#
# Fold:  40%|████      | 4/10 [00:01<00:01,  3.91it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:01<00:01,  3.92it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:01,  3.88it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  3.83it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:02<00:00,  3.80it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:02<00:00,  3.80it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:02<00:00,  3.82it/s]
#
# n_interp: 100%|██████████| 3/3 [00:27<00:00,  9.17s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 5 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Estimated consensus=0.20 and n_interpolate=4
# Repairing epochs:   0%|          | 0/485 [00:00<?, ?it/s]
#
# Repairing epochs:   2%|▏         | 12/485 [00:00<00:04, 115.28it/s]
#
# Repairing epochs:   5%|▍         | 24/485 [00:00<00:04, 114.23it/s]
#
# Repairing epochs:   7%|▋         | 36/485 [00:00<00:03, 113.76it/s]
#
# Repairing epochs:  10%|▉         | 47/485 [00:00<00:03, 111.88it/s]
#
# Repairing epochs:  12%|█▏        | 58/485 [00:00<00:03, 111.21it/s]
#
# Repairing epochs:  14%|█▍        | 69/485 [00:00<00:03, 110.36it/s]
#
# Repairing epochs:  16%|█▋        | 80/485 [00:00<00:03, 109.69it/s]
#
# Repairing epochs:  19%|█▉        | 91/485 [00:00<00:03, 108.88it/s]
#
# Repairing epochs:  21%|██        | 103/485 [00:00<00:03, 109.87it/s]
#
# Repairing epochs:  24%|██▎       | 114/485 [00:01<00:03, 109.90it/s]
#
# Repairing epochs:  26%|██▌       | 126/485 [00:01<00:03, 110.58it/s]
#
# Repairing epochs:  28%|██▊       | 138/485 [00:01<00:03, 110.74it/s]
#
# Repairing epochs:  31%|███       | 150/485 [00:01<00:03, 111.37it/s]
#
# Repairing epochs:  33%|███▎      | 162/485 [00:01<00:02, 112.54it/s]
#
# Repairing epochs:  36%|███▌      | 174/485 [00:01<00:02, 112.46it/s]
#
# Repairing epochs:  38%|███▊      | 186/485 [00:01<00:02, 111.72it/s]
#
# Repairing epochs:  41%|████      | 198/485 [00:01<00:02, 111.98it/s]
#
# Repairing epochs:  43%|████▎     | 210/485 [00:01<00:02, 112.81it/s]
#
# Repairing epochs:  46%|████▌     | 222/485 [00:01<00:02, 111.96it/s]
#
# Repairing epochs:  48%|████▊     | 234/485 [00:02<00:02, 112.21it/s]
#
# Repairing epochs:  51%|█████     | 247/485 [00:02<00:02, 116.28it/s]
#
# Repairing epochs:  53%|█████▎    | 259/485 [00:02<00:01, 115.89it/s]
#
# Repairing epochs:  56%|█████▌    | 272/485 [00:02<00:01, 117.18it/s]
#
# Repairing epochs:  59%|█████▉    | 286/485 [00:02<00:01, 120.87it/s]
#
# Repairing epochs:  62%|██████▏   | 299/485 [00:02<00:01, 118.01it/s]
#
# Repairing epochs:  64%|██████▍   | 311/485 [00:02<00:01, 116.74it/s]
#
# Repairing epochs:  67%|██████▋   | 323/485 [00:02<00:01, 116.05it/s]
#
# Repairing epochs:  69%|██████▉   | 335/485 [00:02<00:01, 114.15it/s]
#
# Repairing epochs:  72%|███████▏  | 347/485 [00:03<00:01, 113.13it/s]
#
# Repairing epochs:  74%|███████▍  | 359/485 [00:03<00:01, 86.50it/s]
#
# Repairing epochs:  77%|███████▋  | 372/485 [00:03<00:01, 94.53it/s]
#
# Repairing epochs:  79%|███████▉  | 384/485 [00:03<00:01, 99.12it/s]
#
# Repairing epochs:  82%|████████▏ | 396/485 [00:03<00:00, 102.78it/s]
#
# Repairing epochs:  84%|████████▍ | 409/485 [00:03<00:00, 107.32it/s]
#
# Repairing epochs:  87%|████████▋ | 421/485 [00:03<00:00, 109.36it/s]
#
# Repairing epochs:  89%|████████▉ | 433/485 [00:03<00:00, 109.88it/s]
#
# Repairing epochs:  92%|█████████▏| 445/485 [00:04<00:00, 110.23it/s]
#
# Repairing epochs:  94%|█████████▍| 457/485 [00:04<00:00, 110.68it/s]
#
# Repairing epochs:  97%|█████████▋| 469/485 [00:04<00:00, 111.10it/s]
#
# Repairing epochs: 100%|██████████| 485/485 [00:04<00:00, 110.59it/s]
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Overwriting existing file.
# Opening raw data file /Users/nicobruno/ownCloud/MW_eeg_data/minmarker/VP24/VP24filt_raw.fif...
#     Range : 0 ... 970042 =      0.000 ...  3880.168 secs
# Ready.
# Reading 0 ... 970042  =      0.000 ...  3880.168 secs...
# Used Annotations descriptions: ['-999', '1', '101', '102', '103', '104', '105', '106', '107', '108', '109', '11', '111', '12', '167', '169', '17', '170', '171', '172', '175', '176', '177', '179', '182', '191', '2', '201', '202', '203', '204', '205', '206', '207', '208', '232', '233', '234', '237', '238', '239', '251', '252', '253', '255', '3', '4', '5', '6', '62', '68', '80', '9', '92', '98', '99']
# Overwriting existing file.
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 5 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
# Creating augmented epochs:  12%|█▏        | 7/59 [00:00<00:00, 62.23it/s]
# Running autoreject on ch_type=eeg
# Creating augmented epochs: 100%|██████████| 59/59 [00:00<00:00, 70.49it/s]
# Computing thresholds ...: 100%|██████████| 59/59 [00:10<00:00,  5.59it/s]
#
#
# Repairing epochs:   0%|          | 0/165 [00:00<?, ?it/s]
#
# Repairing epochs:  21%|██        | 35/165 [00:00<00:00, 343.38it/s]
#
# Repairing epochs:  43%|████▎     | 71/165 [00:00<00:00, 348.18it/s]
#
# Repairing epochs:  71%|███████   | 117/165 [00:00<00:00, 373.96it/s]
#
# Repairing epochs: 100%|██████████| 165/165 [00:00<00:00, 393.87it/s]
#
# n_interp:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Repairing epochs:   0%|          | 0/165 [00:00<?, ?it/s]
#
# Repairing epochs:   7%|▋         | 11/165 [00:00<00:01, 103.26it/s]
#
# Repairing epochs:  14%|█▍        | 23/165 [00:00<00:01, 107.30it/s]
#
# Repairing epochs:  25%|██▍       | 41/165 [00:00<00:01, 119.14it/s]
#
# Repairing epochs:  33%|███▎      | 55/165 [00:00<00:00, 121.92it/s]
#
# Repairing epochs:  42%|████▏     | 69/165 [00:00<00:00, 124.56it/s]
#
# Repairing epochs:  52%|█████▏    | 85/165 [00:00<00:00, 132.97it/s]
#
# Repairing epochs:  60%|██████    | 99/165 [00:00<00:00, 132.28it/s]
#
# Repairing epochs:  70%|███████   | 116/165 [00:00<00:00, 141.67it/s]
#
# Repairing epochs:  81%|████████  | 133/165 [00:00<00:00, 146.13it/s]
#
# Repairing epochs:  91%|█████████ | 150/165 [00:01<00:00, 150.30it/s]
#
# Repairing epochs: 100%|██████████| 165/165 [00:01<00:00, 141.83it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  5.59it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  5.65it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  5.68it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:01,  5.71it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  5.69it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:00,  5.56it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  5.52it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  5.48it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  5.51it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  5.57it/s]
#
# n_interp:  33%|███▎      | 1/3 [00:03<00:06,  3.04s/it]
#
# Repairing epochs:   0%|          | 0/165 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 14/165 [00:00<00:01, 139.60it/s]
#
# Repairing epochs:  19%|█▉        | 32/165 [00:00<00:00, 148.72it/s]
#
# Repairing epochs:  29%|██▉       | 48/165 [00:00<00:00, 151.76it/s]
#
# Repairing epochs:  39%|███▉      | 65/165 [00:00<00:00, 155.91it/s]
#
# Repairing epochs:  49%|████▉     | 81/165 [00:00<00:00, 154.94it/s]
#
# Repairing epochs:  58%|█████▊    | 95/165 [00:00<00:00, 149.76it/s]
#
# Repairing epochs:  68%|██████▊   | 112/165 [00:00<00:00, 152.65it/s]
#
# Repairing epochs:  78%|███████▊  | 128/165 [00:00<00:00, 154.46it/s]
#
# Repairing epochs:  88%|████████▊ | 146/165 [00:00<00:00, 158.73it/s]
#
# Repairing epochs: 100%|██████████| 165/165 [00:01<00:00, 154.61it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  10%|█         | 1/10 [00:00<00:01,  5.99it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:01,  5.94it/s]
#
#
# Fold:  30%|███       | 3/10 [00:00<00:01,  5.88it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:01,  5.83it/s]
#
#
# Fold:  50%|█████     | 5/10 [00:00<00:00,  5.80it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:01<00:00,  5.77it/s]
#
#
# Fold:  70%|███████   | 7/10 [00:01<00:00,  5.74it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:01<00:00,  5.70it/s]
#
#
# Fold:  90%|█████████ | 9/10 [00:01<00:00,  5.69it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:01<00:00,  5.72it/s]
#
# n_interp:  67%|██████▋   | 2/3 [00:05<00:02,  2.99s/it]
#
# Repairing epochs:   0%|          | 0/165 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 14/165 [00:00<00:01, 137.91it/s]
#
# Repairing epochs:  19%|█▉        | 32/165 [00:00<00:00, 147.86it/s]
#
# Repairing epochs:  30%|██▉       | 49/165 [00:00<00:00, 151.63it/s]
#
# Repairing epochs:  40%|████      | 66/165 [00:00<00:00, 156.23it/s]
#
# Repairing epochs:  50%|████▉     | 82/165 [00:00<00:00, 155.06it/s]
#
# Repairing epochs:  59%|█████▉    | 97/165 [00:00<00:00, 150.25it/s]
#
# Repairing epochs:  69%|██████▉   | 114/165 [00:00<00:00, 153.60it/s]
#
# Repairing epochs:  79%|███████▉  | 131/165 [00:00<00:00, 155.10it/s]
#
# Repairing epochs:  90%|████████▉ | 148/165 [00:00<00:00, 158.33it/s]
#
# Repairing epochs: 100%|██████████| 165/165 [00:01<00:00, 147.96it/s]
#
#
#
# Fold:   0%|          | 0/10 [00:00<?, ?it/s]
#
#
# Fold:  20%|██        | 2/10 [00:00<00:00, 11.99it/s]
#
#
# Fold:  40%|████      | 4/10 [00:00<00:00, 11.77it/s]
#
#
# Fold:  60%|██████    | 6/10 [00:00<00:00, 11.56it/s]
#
#
# Fold:  80%|████████  | 8/10 [00:00<00:00, 11.36it/s]
#
#
# Fold: 100%|██████████| 10/10 [00:00<00:00, 11.20it/s]
#
# n_interp: 100%|██████████| 3/3 [00:07<00:00,  2.66s/it]
# /Users/nicobruno/opt/anaconda3/lib/python3.8/site-packages/autoreject/utils.py:63: UserWarning: 5 channels are marked as bad. These will be ignored. If you want them to be considered by autoreject please remove them from epochs.info["bads"].
#   warnings.warn(
#
#
# Repairing epochs:   0%|          | 0/165 [00:00<?, ?it/s]
#
# Repairing epochs:   8%|▊         | 14/165 [00:00<00:01, 134.12it/s]
# Estimated consensus=0.10 and n_interpolate=4
# Repairing epochs:  19%|█▉        | 32/165 [00:00<00:00, 143.06it/s]
#
# Repairing epochs:  30%|██▉       | 49/165 [00:00<00:00, 147.94it/s]
#
# Repairing epochs:  40%|████      | 66/165 [00:00<00:00, 152.85it/s]
#
# Repairing epochs:  50%|████▉     | 82/165 [00:00<00:00, 151.81it/s]
#
# Repairing epochs:  58%|█████▊    | 96/165 [00:00<00:00, 147.55it/s]
#
# Repairing epochs:  68%|██████▊   | 113/165 [00:00<00:00, 150.40it/s]
#
# Repairing epochs:  79%|███████▉  | 130/165 [00:00<00:00, 153.96it/s]
#
# Repairing epochs:  89%|████████▉ | 147/165 [00:00<00:00, 156.90it/s]
#
# Repairing epochs: 100%|██████████| 165/165 [00:01<00:00, 153.23it/s]
# Estimating rejection dictionary for eeg
# Estimating rejection dictionary for eog
# Overwriting existing file.
# [5.384615384615385, 23.25056433408578, 0.0, 27.40740740740741, 0.0, 28.88888888888889, 7.1258907363420425, 10.677083333333334, 0.0, 13.213213213213214, 26.685393258426966, 9.484536082474227, 19.393939393939394]
